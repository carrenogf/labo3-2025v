# %%
study_name = "lightgbm_colab_share"
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import gc
import numpy as np
from sklearn.preprocessing import LabelEncoder
from scipy.stats import linregress
from statsmodels.tsa.seasonal import seasonal_decompose

def add_decomposition_columns(df, value_col='tn', group_col='product_id', period=12):
    """
    Añade columnas de descomposición directamente al DataFrame original
    """
    df = df.copy()
    df['trend'] = np.nan
    df['seasonal'] = np.nan
    df['resid'] = np.nan
    
    for product_id, group in df.groupby(group_col):
        idx = group.index
        clean_series = group[value_col].dropna()
        
        if len(clean_series) >= 2 * period:
            try:
                decomp = seasonal_decompose(clean_series, model='additive', period=period)
                df.loc[idx, 'trend_s'] = decomp.trend.reindex(idx)
                df.loc[idx, 'seasonal_s'] = decomp.seasonal.reindex(idx)
                df.loc[idx, 'resid_s'] = decomp.resid.reindex(idx)
            except:
                continue
                
    return df



sellin = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/sell-in.txt.gz", sep="\t")
productos = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/tb_productos.txt", sep="\t")
stocks = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/tb_stocks.txt", sep="\t")
productos = productos.drop_duplicates(subset=["product_id"],keep="first")  # Eliminar duplicados por si acaso
productos_ok = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/product_id_apredecir201912.txt", sep="\t")
df = sellin[sellin["product_id"].isin(productos_ok["product_id"])]
df = df.groupby(by=["periodo","product_id"]).agg({
    "tn":"sum",
    "plan_precios_cuidados":"first",
    "customer_id":"nunique",

    }).reset_index()


productos_list = df['product_id'].unique()
periodos = df['periodo'].unique()
idx = pd.MultiIndex.from_product([productos_list, periodos], names=['product_id', 'periodo'])
completo = idx.to_frame(index=False)
# 4 filtrar combinaciones periodo_producto
completo = completo.merge(df, on=['periodo', 'product_id'], how='left')
nacimiento_producto = df.groupby('product_id')['periodo'].min().rename('nacimiento_producto')

completo = completo.merge(nacimiento_producto, on='product_id', how='left')
completo = completo[completo['periodo'] >= completo['nacimiento_producto']]



df = pd.merge(completo, productos, how="left", on="product_id")
df = df.merge(stocks, how="left", on=["product_id", "periodo"])

df["periodo"] = pd.to_datetime(df["periodo"], format="%Y%m")

df["mes"] = df["periodo"].dt.month
df["year"] = df["periodo"].dt.year
df["quarter"] = df["periodo"].dt.quarter

# total periodo general
df["tn_total"] = df.groupby("periodo")["tn"].transform("sum")

# totales por cat1 por periodo
df["cat1_total"] = df.groupby(["periodo", "cat1"])["tn"].transform("sum")
df["i_cat1_total"] = df["cat1_total"] / df["tn_total"]
df["cat1_mean"] = df.groupby(["periodo", "cat1"])["tn"].transform("mean")
df["cat1_mean_12"] = df.groupby(["periodo", "cat1"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat1_customers"] = df.groupby(["periodo", "cat1"])["customer_id"].transform("nunique")
# totales por cat2 por periodo
df["cat2_total"] = df.groupby(["periodo", "cat2"])["tn"].transform("sum")
df["i_cat2_total"] =  df["cat2_total"] / df["tn_total"]
df["cat2_mean"] = df.groupby(["periodo", "cat2"])["tn"].transform("mean")
df["cat2_mean_12"] = df.groupby(["periodo", "cat2"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat2_customers"] = df.groupby(["periodo", "cat2"])["customer_id"].transform("nunique")
# totales por cat3 por periodo
df["cat3_total"] = df.groupby(["periodo", "cat3"])["tn"].transform("sum")
df["i_cat3_total"] = df["cat3_total"] / df["tn_total"]
df["cat3_mean"] = df.groupby(["periodo", "cat3"])["tn"].transform("mean")
df["cat3_mean_12"] = df.groupby(["periodo", "cat3"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat3_customers"] = df.groupby(["periodo", "cat3"])["customer_id"].transform("nunique")
# totales por brand
df["brand_total"] = df.groupby(["periodo", "brand"])["tn"].transform("sum")
df["i_brand_total"] = df["brand_total"] / df["tn_total"]
df["brand_mean"] = df.groupby(["periodo", "brand"])["tn"].transform("mean")
df["brand_mean_12"] = df.groupby(["periodo", "brand"])["tn"].transform(lambda x: x.rolling(12).mean())
df["brand_customers"] = df.groupby(["periodo", "brand"])["customer_id"].transform("nunique")


df['media_movil_3m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(3).mean())
df['media_movil_6m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(6).mean())
df['media_movil_12m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(12).mean())
df['i_media_3_6'] = df['media_movil_3m'] / df['media_movil_6m']
df['i_media_6_12'] = df['media_movil_6m'] / df['media_movil_12m']
df['i_media_3_12'] = df['media_movil_3m'] / df['media_movil_12m']
df["trend_corta"] = (df["i_media_3_6"]>1).astype(int)
df["trend_larga"] = (df["i_media_6_12"]>1).astype(int)
df["trend_media"] = (df["i_media_3_12"]>1).astype(int)
df["trend"] = df["trend_corta"] + df["trend_larga"] + df["trend_media"]

df["producto_grande"] = (df["product_id"].isin(list(productos_list)[:150])).astype(int)
df = add_decomposition_columns(df)

# shift t-1 a t12
meses = ["tn"]
for i in range(1, 13):
    df[f"tn_t{i}"] = df.groupby("product_id")["tn"].shift(i)
    df[f"delta_t{i}"] = df[f"tn"] / df[f"tn_t{i}"]
    df[f"diff_t{i}"] = df[f"tn"] - df[f"tn_t{i}"]
    meses.append(f"tn_t{i}")
    df[f"cat1_t{i}"] = df.groupby("product_id")["cat1_total"].shift(i)
    df[f"cat2_t{i}"] = df.groupby("product_id")["cat2_total"].shift(i)
    df[f"cat3_t{i}"] = df.groupby("product_id")["cat3_total"].shift(i)
    df[f"customer_id_t{i}"] = df.groupby("product_id")["customer_id"].shift(i)
    df[f"trend_{i}"] = df.groupby("product_id")["trend"].shift(i)
    # brand
    df[f"brand_t{i}"] = df.groupby("product_id")["brand_total"].shift(i)
    df[f"brand_cust_t{i}"] = df.groupby("product_id")["brand_customers"].shift(i)
    df[f"trend_s_t{i}"] = df.groupby("product_id")["trend_s"].shift(i)
    df[f"seasonal_s_t{i}"] = df.groupby("product_id")["seasonal_s"].shift(i)
    df[f"resid_s_t{i}"] = df.groupby("product_id")["resid_s"].shift(i)

df[f"tn_t13"] = df.groupby("product_id")["tn"].shift(13)

df[f"delta_t12_t13"] = df[f"tn_t12"] / df[f"tn_t13"]
df[f"diff_t12_13"] = df[f"tn_t12"] - df[f"tn_t13"]

df["i_tn_t12"] = df["tn"] / df["tn_t12"]
df["i_tn_t6"] = df["tn"] / df["tn_t6"]
df["i_tn_t3"] = df["tn"] / df["tn_t3"]

df["i_tn_customers"] = df["tn"] / df["customer_id"]

df["promedio_t12"] = df[meses].mean(axis=1)
df["promedio_t6"] = df[meses[:6]].mean(axis=1)
df["promedio_t3"] = df[meses[:3]].mean(axis=1)

df["mediana_t12"] = df[meses].median(axis=1)
df["mediana_t6"] = df[meses[:6]].median(axis=1)
df["mediana_t3"] = df[meses[:3]].median(axis=1)

df["maximo_t12"] = df[meses].max(axis=1)
df["maximo_t6"] = df[meses[:6]].max(axis=1)
df["maximo_t3"] = df[meses[:3]].max(axis=1)

df["i_tn_maximo_t12"] = df["tn"] / df["maximo_t12"]
df["i_tn_maximo_t6"] = df["tn"] / df["maximo_t6"]
df["i_tn_maximo_t3"] = df["tn"] / df["maximo_t3"]

df["minimo_t12"] = df[meses].min(axis=1)
df["minimo_t6"] = df[meses[:6]].min(axis=1)
df["minimo_t3"] = df[meses[:3]].min(axis=1)

df["std_t12"] = df[meses].std(axis=1)
df["std_t6"] = df[meses[:6]].std(axis=1)
df["std_t3"] = df[meses[:3]].std(axis=1)

df["variacion_12"] = df["std_t12"]/df["promedio_t12"]
df["variacion_6"] = df["std_t6"]/df["promedio_t6"]
df["variacion_3"] = df["std_t3"]/df["promedio_t3"]

# interaccion desvio, promedio, tendencia
df["trend_var_12"] = df["trend"] * df["variacion_12"]
df["trend_var_6"] = df["trend"] * df["variacion_6"]
df["trend_var_3"] = df["trend"] * df["variacion_3"]

df["i_tn_minimo_t12"] = df["tn"] / df["minimo_t12"]
df["i_tn_minimo_t6"] = df["tn"] / df["minimo_t6"]
df["i_tn_minimo_t3"] = df["tn"] / df["minimo_t3"]

df["rango_t12"] = df["maximo_t12"] - df["minimo_t12"]
df["rango_t6"] = df["maximo_t6"] - df["minimo_t6"]
df["rango_t3"] = df["maximo_t3"] - df["minimo_t3"]

df["antiguedad"] = (df["periodo"] - pd.to_datetime(df["nacimiento_producto"], format="%Y%m")).dt.days


# Función para calcular la pendiente de una serie temporal
def calcular_pendiente(serie):
    datos = serie.dropna().values
    if len(datos) < 2:  # Mínimo 2 puntos para una regresión
        return np.nan
    x = np.arange(len(datos))  # [0, 1, 2, ..., n-1] (representa el tiempo)
    slope, _, _, _, _ = linregress(x, datos)
    return slope

# Aplicamos la función por grupo (producto) y reindexamos para alinear con df
df["pendiente_reg_12"] = (
    df.groupby("product_id")[meses]
    .apply(lambda grupo: grupo.apply(calcular_pendiente, axis=1))
    .reset_index(level=0, drop=True)  # Eliminamos el nivel de grupo para alinear índices
)
df["tn_pendiente"] = df["tn"] * df["pendiente_reg_12"]


df["diff_tn_mm3"] = df["tn"] - df['media_movil_3m']
df["diff_tn_mm6"] = df["tn"] - df['media_movil_6m']
df["diff_tn_mm12"] = df["tn"] - df['media_movil_12m']
df["i_tn_mm3"] = df["tn"] / df['media_movil_3m']
df["i_tn_mm6"] = df["tn"] / df['media_movil_6m']
df["i_tn_mm12"] = df["tn"] / df['media_movil_12m']

from scipy.stats import mode
def rolling_mode(x):
    return x.shift(1).rolling(6, min_periods=1).apply(lambda x: mode(x, keepdims=True)[0][0], raw=False)
#Moda o patrón de cantidad
df['modo_6m'] = df.groupby(['product_id'])['tn'].transform(rolling_mode)
df['modo_diff'] = df['tn'] - df['modo_6m']

# sku_size
df["sku_size_cat1"] = df.groupby("cat1")["sku_size"].transform("mean")
df["sku_size_cat2"] = df.groupby("cat2")["sku_size"].transform("mean")
df["sku_size_cat3"] = df.groupby("cat3")["sku_size"].transform("mean")
df["i_tn_sku_size"] = df["tn"] / (df["sku_size"]+0.00001)
df['tn_diff1'] = df.groupby('product_id')['tn'].transform(lambda x: x.diff())
# target t+2
df["target"] = df.groupby("product_id")["tn"].shift(-2)
df["target"] = df["target"]/df["tn_total"]



cat_cols = ['cat1', 'cat2', 'cat3', 'brand', 'descripcion']
for col in cat_cols:
    if col in df.columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))

del completo, productos, stocks
gc.collect()
df
# Out:
#        product_id    periodo          tn  plan_precios_cuidados  customer_id  \
# 0           20001 2017-01-01   934.77222                    0.0        186.0
# 1           20001 2017-02-01   798.01620                    0.0        185.0
# 2           20001 2017-03-01  1303.35771                    0.0        188.0
# 3           20001 2017-04-01  1069.96130                    0.0        104.0
# 4           20001 2017-05-01  1502.20132                    0.0        238.0
# ...           ...        ...         ...                    ...          ...
# 22370       21087 2019-12-01     1.02205                    0.0         51.0
# 22371       21214 2019-09-01     0.34250                    0.0          2.0
# 22372       21214 2019-10-01     0.21735                    0.0         38.0
# 22373       21214 2019-11-01     0.84012                    0.0         43.0
# 22374       21214 2019-12-01     0.24428                    0.0         37.0
#
#        nacimiento_producto  cat1  cat2  cat3  brand  ...  i_tn_mm6  i_tn_mm12  \
# 0                   201701     1    10    47      0  ...       NaN        NaN
# 1                   201701     1    10    47      0  ...       NaN        NaN
# 2                   201701     1    10    47      0  ...       NaN        NaN
# 3                   201701     1    10    47      0  ...       NaN        NaN
# 4                   201701     1    10    47      0  ...       NaN        NaN
# ...                    ...   ...   ...   ...    ...  ...       ...        ...
# 22370               201909     2     3     3     23  ...       NaN        NaN
# 22371               201909     2     3    65     23  ...       NaN        NaN
# 22372               201909     2     3    65     23  ...       NaN        NaN
# 22373               201909     2     3    65     23  ...       NaN        NaN
# 22374               201909     2     3    65     23  ...       NaN        NaN
#
#          modo_6m  modo_diff  sku_size_cat1  sku_size_cat2  sku_size_cat3  \
# 0            NaN        NaN    1125.478324    1511.526419    1354.321551
# 1      934.77222 -136.75602    1125.478324    1511.526419    1354.321551
# 2      798.01620  505.34151    1125.478324    1511.526419    1354.321551
# 3      798.01620  271.94510    1125.478324    1511.526419    1354.321551
# 4      798.01620  704.18512    1125.478324    1511.526419    1354.321551
# ...          ...        ...            ...            ...            ...
# 22370    0.29997    0.72208     257.042527      80.280617      89.154032
# 22371        NaN        NaN     257.042527      80.280617      50.000000
# 22372    0.34250   -0.12515     257.042527      80.280617      50.000000
# 22373    0.21735    0.62277     257.042527      80.280617      50.000000
# 22374    0.21735    0.02693     257.042527      80.280617      50.000000
#
#        i_tn_sku_size   tn_diff1    target
# 0           0.311591        NaN  0.047919
# 1           0.266005 -136.75602  0.039187
# 2           0.434453  505.34151  0.040980
# 3           0.356654 -233.39641  0.048914
# 4           0.500734  432.24002  0.028783
# ...              ...        ...       ...
# 22370       0.015724   -0.37760       NaN
# 22371       0.006850        NaN  0.000026
# 22372       0.004347   -0.12515  0.000007
# 22373       0.016802    0.62277       NaN
# 22374       0.004886   -0.59584       NaN
#
# [22375 rows x 263 columns]

# %%
df_kgl = df[df["periodo"] == "2019-12-01"]
df_kgl["periodo"] = df_kgl["periodo"].astype(int)
df = df[~df["periodo"].isin(["2019-11-01", "2019-12-01"])]

# %%
# Separar features y target
X = df.drop(columns=["target"])
y = df["target"]
pediodo_train = '2019-07-01'
periodo_val = '2019-09-01'
X_train = X[X["periodo"] <= pediodo_train]
X_train["periodo"] = X_train["periodo"].astype(int)
y_train = y[X["periodo"] <= pediodo_train].fillna(0)

X_val = X[(X["periodo"] >= periodo_val)]
X_val["periodo"] = X_val["periodo"].astype(int)
y_val = y[(X["periodo"] >= periodo_val)]

# %%
import lightgbm as lgb
import optuna
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os
from optuna.integration import BoTorchSampler

def custom_mape_loss(y_true, y_pred):
    numerator = np.sum(np.abs(y_true - y_pred))
    denominator = np.sum(np.abs(y_true))
    epsilon = np.finfo(float).eps  # Valor muy pequeño para evitar división por cero
    return numerator / (denominator + epsilon)

# === 2. Definición del objetivo para Optuna ===
def objective(trial):
    params = {
        "sample_weight": X_train["tn"].to_list(),
        "objective": "huber",
        "metric": ["mae","rmse"],
        "boosting_type": "gbdt",
        "verbosity": -1,
        "n_jobs": -1,
        "seed": 42,
        "num_leaves": trial.suggest_int("num_leaves", 20, 100),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.7, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.7, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 5),
        "min_child_samples": trial.suggest_int("min_child_samples", 10, 100),
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-3, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-3, 10.0, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "max_bin": trial.suggest_int("max_bin", 10, 6000),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 100),
        "extra_trees": True,
        "path_smooth": trial.suggest_float("path_smooth", 0, 1),  # Nuevo parámetro útil
        "min_child_weight": trial.suggest_float("min_child_weight",1,10)
    }

    model = lgb.train(
        params,
        lgb.Dataset(X_train, label=y_train),
        valid_sets=[lgb.Dataset(X_val, label=y_val)],
        callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)],
        num_boost_round = 500
    )

    preds = model.predict(X_val)



    mape = custom_mape_loss(y_val, preds)
    # rmse = mean_squared_error(y_val, preds)
    # rmse = np.sqrt(rmse)

    #rmse = mean_squared_error(y_val, preds, squared=False)
    return mape

# === 3. Configurar almacenamiento SQLite para Optuna ===
os.makedirs("optuna_storage", exist_ok=True)
DB_PATH = "optuna_storage/optuna.db"
STUDY_NAME = study_name
storage_url = f"sqlite:///{DB_PATH}"

# === 4. Crear o cargar estudio ===
study = optuna.create_study(
    study_name=STUDY_NAME,
    storage=storage_url,
    direction="minimize",
    load_if_exists=True,
    sampler=BoTorchSampler() ,
)

# === 5. Ejecutar optimización ===
study.optimize(objective, n_trials=200)

# === 6. Mostrar resultados ===
print("Mejores hiperparámetros encontrados:")
print(study.best_params)
print(f"Mejor MAE: {study.best_value:.4f}")
# Out:
# [I 2025-07-16 19:29:16,970] A new study created in RDB with name: lightgbm_colab_share
# [I 2025-07-16 19:29:19,790] Trial 0 finished with value: 0.4250696146449314 and parameters: {'num_leaves': 56, 'learning_rate': 0.27426915615687103, 'feature_fraction': 0.9496748952451097, 'bagging_fraction': 0.8190398125619409, 'bagging_freq': 5, 'min_child_samples': 53, 'lambda_l1': 1.1260921578332932, 'lambda_l2': 0.0026802898533254036, 'max_depth': 5, 'max_bin': 3344, 'min_data_in_leaf': 38, 'path_smooth': 0.15513015217063664, 'min_child_weight': 8.333243680799583}. Best is trial 0 with value: 0.4250696146449314.
# [I 2025-07-16 19:29:21,986] Trial 1 finished with value: 0.32486569765070483 and parameters: {'num_leaves': 36, 'learning_rate': 0.2636396209462179, 'feature_fraction': 0.8133502849448847, 'bagging_fraction': 0.7880678850008933, 'bagging_freq': 4, 'min_child_samples': 100, 'lambda_l1': 0.0323701843902242, 'lambda_l2': 0.06277110808914528, 'max_depth': 3, 'max_bin': 626, 'min_data_in_leaf': 12, 'path_smooth': 0.25531505600814586, 'min_child_weight': 1.5114025751885882}. Best is trial 1 with value: 0.32486569765070483.
# [I 2025-07-16 19:29:24,707] Trial 2 finished with value: 0.29493417174833336 and parameters: {'num_leaves': 32, 'learning_rate': 0.19835875999225, 'feature_fraction': 0.7895494849507491, 'bagging_fraction': 0.9441401640224577, 'bagging_freq': 2, 'min_child_samples': 94, 'lambda_l1': 0.0030237106163386062, 'lambda_l2': 0.0022352696071791674, 'max_depth': 5, 'max_bin': 1505, 'min_data_in_leaf': 47, 'path_smooth': 0.6446316604955552, 'min_child_weight': 3.4701746910933693}. Best is trial 2 with value: 0.29493417174833336.
# [I 2025-07-16 19:29:27,480] Trial 3 finished with value: 0.4502780703989366 and parameters: {'num_leaves': 50, 'learning_rate': 0.2698430227496544, 'feature_fraction': 0.7043202045826686, 'bagging_fraction': 0.988368475782667, 'bagging_freq': 5, 'min_child_samples': 49, 'lambda_l1': 1.771637539612346, 'lambda_l2': 0.010025134872332048, 'max_depth': 9, 'max_bin': 2189, 'min_data_in_leaf': 50, 'path_smooth': 0.6287394248840232, 'min_child_weight': 6.6057501594276555}. Best is trial 2 with value: 0.29493417174833336.
# [I 2025-07-16 19:29:30,334] Trial 4 finished with value: 0.2998526416845055 and parameters: {'num_leaves': 67, 'learning_rate': 0.2387988449833992, 'feature_fraction': 0.7129589942625184, 'bagging_fraction': 0.9492325404159133, 'bagging_freq': 5, 'min_child_samples': 52, 'lambda_l1': 0.007735004612471145, 'lambda_l2': 0.36231578048637775, 'max_depth': 3, 'max_bin': 3197, 'min_data_in_leaf': 54, 'path_smooth': 0.6536877728804997, 'min_child_weight': 2.556645006446067}. Best is trial 2 with value: 0.29493417174833336.
# [I 2025-07-16 19:29:33,920] Trial 5 finished with value: 0.2828140470287038 and parameters: {'num_leaves': 28, 'learning_rate': 0.05141175401339424, 'feature_fraction': 0.9670533916052111, 'bagging_fraction': 0.9108386814382369, 'bagging_freq': 2, 'min_child_samples': 17, 'lambda_l1': 0.029852766564110712, 'lambda_l2': 0.14316537642374041, 'max_depth': 3, 'max_bin': 2055, 'min_data_in_leaf': 92, 'path_smooth': 0.0015294815656478056, 'min_child_weight': 6.00665080897159}. Best is trial 5 with value: 0.2828140470287038.
# [I 2025-07-16 19:29:36,507] Trial 6 finished with value: 0.27846851964655767 and parameters: {'num_leaves': 89, 'learning_rate': 0.20746463755130837, 'feature_fraction': 0.7631527439228224, 'bagging_fraction': 0.7574740380084097, 'bagging_freq': 4, 'min_child_samples': 51, 'lambda_l1': 0.04295579726497244, 'lambda_l2': 0.00378897803370105, 'max_depth': 10, 'max_bin': 1842, 'min_data_in_leaf': 43, 'path_smooth': 0.3158639590661906, 'min_child_weight': 7.416762922748021}. Best is trial 6 with value: 0.27846851964655767.
# [I 2025-07-16 19:29:39,980] Trial 7 finished with value: 0.30196419107580186 and parameters: {'num_leaves': 79, 'learning_rate': 0.15387971450394014, 'feature_fraction': 0.8016257698732673, 'bagging_fraction': 0.8835866982892454, 'bagging_freq': 3, 'min_child_samples': 73, 'lambda_l1': 0.028966249350859907, 'lambda_l2': 8.985921460470003, 'max_depth': 3, 'max_bin': 5402, 'min_data_in_leaf': 62, 'path_smooth': 0.25349813314310743, 'min_child_weight': 9.04212266645811}. Best is trial 6 with value: 0.27846851964655767.
# [I 2025-07-16 19:29:42,433] Trial 8 finished with value: 0.29889984905018113 and parameters: {'num_leaves': 58, 'learning_rate': 0.2848696486726271, 'feature_fraction': 0.8959458809062684, 'bagging_fraction': 0.9249478495262786, 'bagging_freq': 5, 'min_child_samples': 27, 'lambda_l1': 0.28236952177329355, 'lambda_l2': 4.886059308019007, 'max_depth': 9, 'max_bin': 3816, 'min_data_in_leaf': 69, 'path_smooth': 0.6348877122096261, 'min_child_weight': 5.946567056605002}. Best is trial 6 with value: 0.27846851964655767.
# [I 2025-07-16 19:29:46,974] Trial 9 finished with value: 0.2849808305293383 and parameters: {'num_leaves': 86, 'learning_rate': 0.14262244300213117, 'feature_fraction': 0.9198459159045645, 'bagging_fraction': 0.783849609223708, 'bagging_freq': 1, 'min_child_samples': 61, 'lambda_l1': 0.009805861351147157, 'lambda_l2': 0.459950836641252, 'max_depth': 6, 'max_bin': 4987, 'min_data_in_leaf': 78, 'path_smooth': 0.35070346785824524, 'min_child_weight': 6.585654559379456}. Best is trial 6 with value: 0.27846851964655767.
# [I 2025-07-16 19:29:52,572] Trial 10 finished with value: 0.27742779057743605 and parameters: {'num_leaves': 81, 'learning_rate': 0.2326216488300128, 'feature_fraction': 0.9658036173049888, 'bagging_fraction': 0.8124533854803135, 'bagging_freq': 4, 'min_child_samples': 10, 'lambda_l1': 0.037556529137730735, 'lambda_l2': 0.25577060938949187, 'max_depth': 10, 'max_bin': 3062, 'min_data_in_leaf': 87, 'path_smooth': 0.6271113888221901, 'min_child_weight': 7.217997870413699}. Best is trial 10 with value: 0.27742779057743605.
# [I 2025-07-16 19:29:58,412] Trial 11 finished with value: 0.2699877411183119 and parameters: {'num_leaves': 92, 'learning_rate': 0.07963593591560988, 'feature_fraction': 0.7567966888836627, 'bagging_fraction': 0.8050814826368424, 'bagging_freq': 2, 'min_child_samples': 29, 'lambda_l1': 0.012350784409011351, 'lambda_l2': 0.0022787521516983013, 'max_depth': 10, 'max_bin': 2912, 'min_data_in_leaf': 68, 'path_smooth': 0.11277269804338798, 'min_child_weight': 8.712499406543406}. Best is trial 11 with value: 0.2699877411183119.
# [I 2025-07-16 19:30:06,886] Trial 12 finished with value: 1.0503829254469121 and parameters: {'num_leaves': 100, 'learning_rate': 0.001, 'feature_fraction': 0.7, 'bagging_fraction': 0.9015052660249595, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.07829032517464135, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 3268, 'min_data_in_leaf': 100, 'path_smooth': 0.35995000900393265, 'min_child_weight': 8.357768170572154}. Best is trial 11 with value: 0.2699877411183119.
# [I 2025-07-16 19:30:12,307] Trial 13 finished with value: 0.2753520136218107 and parameters: {'num_leaves': 93, 'learning_rate': 0.12230135275080298, 'feature_fraction': 0.8000350211155869, 'bagging_fraction': 0.7297808934278796, 'bagging_freq': 3, 'min_child_samples': 17, 'lambda_l1': 0.0010847300298604656, 'lambda_l2': 0.003286258253282838, 'max_depth': 10, 'max_bin': 1802, 'min_data_in_leaf': 58, 'path_smooth': 0.09842208336124583, 'min_child_weight': 5.943414951919972}. Best is trial 11 with value: 0.2699877411183119.
# [I 2025-07-16 19:30:17,825] Trial 14 finished with value: 0.27426624322892407 and parameters: {'num_leaves': 27, 'learning_rate': 0.10935841605104192, 'feature_fraction': 0.9635696198612984, 'bagging_fraction': 0.8675185573085014, 'bagging_freq': 3, 'min_child_samples': 12, 'lambda_l1': 0.03652094270679392, 'lambda_l2': 0.006353254289824038, 'max_depth': 7, 'max_bin': 649, 'min_data_in_leaf': 76, 'path_smooth': 0.0, 'min_child_weight': 8.62542280776141}. Best is trial 11 with value: 0.2699877411183119.
# [I 2025-07-16 19:30:25,643] Trial 15 finished with value: 0.2674001315004593 and parameters: {'num_leaves': 100, 'learning_rate': 0.052647924969792315, 'feature_fraction': 0.7210350003825878, 'bagging_fraction': 0.7051626104814616, 'bagging_freq': 1, 'min_child_samples': 86, 'lambda_l1': 0.005639772797904737, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2553, 'min_data_in_leaf': 56, 'path_smooth': 0.2851627623942458, 'min_child_weight': 8.67358859257756}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:30:31,176] Trial 16 finished with value: 0.32535071987751213 and parameters: {'num_leaves': 100, 'learning_rate': 0.29999999999999993, 'feature_fraction': 0.7968879989381811, 'bagging_fraction': 0.7510094731300428, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.021218382021268013, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 603, 'min_data_in_leaf': 61, 'path_smooth': 0.5059954689440221, 'min_child_weight': 8.214732417756903}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:30:37,661] Trial 17 finished with value: 0.26999753046493025 and parameters: {'num_leaves': 100, 'learning_rate': 0.08251941538480394, 'feature_fraction': 0.7515506055042356, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 80, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.029241971867581113, 'max_depth': 6, 'max_bin': 2658, 'min_data_in_leaf': 33, 'path_smooth': 0.1020117350730637, 'min_child_weight': 2.912762688332469}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:31:04,947] Trial 18 finished with value: 1.028911585382803 and parameters: {'num_leaves': 85, 'learning_rate': 0.001, 'feature_fraction': 0.7440288814010605, 'bagging_fraction': 0.8634674647165308, 'bagging_freq': 5, 'min_child_samples': 61, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 61, 'path_smooth': 0.0, 'min_child_weight': 2.037198322750581}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:31:10,684] Trial 19 finished with value: 0.3689104935276822 and parameters: {'num_leaves': 20, 'learning_rate': 0.06473303528708749, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 1.6199673190559278, 'max_depth': 3, 'max_bin': 10, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:31:16,956] Trial 20 finished with value: 0.37696140016277424 and parameters: {'num_leaves': 88, 'learning_rate': 0.15376271501963185, 'feature_fraction': 0.7734483605816017, 'bagging_fraction': 0.8044363009498311, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.013199968066707077, 'lambda_l2': 0.23907942084584052, 'max_depth': 9, 'max_bin': 10, 'min_data_in_leaf': 83, 'path_smooth': 0.46313680523805656, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:31:22,652] Trial 21 finished with value: 0.4436743989151749 and parameters: {'num_leaves': 20, 'learning_rate': 0.29999999999999993, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 10, 'min_data_in_leaf': 10, 'path_smooth': 0.4122544252248846, 'min_child_weight': 1.0}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:31:29,703] Trial 22 finished with value: 0.36100704889102925 and parameters: {'num_leaves': 20, 'learning_rate': 0.23325580019243064, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 9.999999999999998, 'max_depth': 7, 'max_bin': 10, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:31:45,292] Trial 23 finished with value: 1.036633458644637 and parameters: {'num_leaves': 100, 'learning_rate': 0.001, 'feature_fraction': 0.8122316632778463, 'bagging_fraction': 0.7727725309340535, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.0036520144178949056, 'lambda_l2': 0.002067307854378088, 'max_depth': 10, 'max_bin': 3818, 'min_data_in_leaf': 98, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:31:53,398] Trial 24 finished with value: 0.3338490983413658 and parameters: {'num_leaves': 100, 'learning_rate': 0.06440183600860724, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.6342170091438911, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 6000, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:31:59,624] Trial 25 finished with value: 0.27384735508431585 and parameters: {'num_leaves': 100, 'learning_rate': 0.14224564533537437, 'feature_fraction': 0.8634692466142587, 'bagging_fraction': 0.7, 'bagging_freq': 2, 'min_child_samples': 10, 'lambda_l1': 0.004808276121197445, 'lambda_l2': 0.010249167975571832, 'max_depth': 10, 'max_bin': 1821, 'min_data_in_leaf': 58, 'path_smooth': 0.0, 'min_child_weight': 9.454773922272658}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:32:07,178] Trial 26 finished with value: 0.2967120347645285 and parameters: {'num_leaves': 29, 'learning_rate': 0.1325386325339193, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.020326151131986145, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 6.3944789421255335}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:32:15,756] Trial 27 finished with value: 0.31035509772317277 and parameters: {'num_leaves': 100, 'learning_rate': 0.2722590828803682, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.0020215933340913617, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 100, 'path_smooth': 0.9999999999999999, 'min_child_weight': 6.604787446477086}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:32:24,558] Trial 28 finished with value: 0.3645402712534414 and parameters: {'num_leaves': 100, 'learning_rate': 0.06426610435072631, 'feature_fraction': 0.7332448984345651, 'bagging_fraction': 0.9402513209002487, 'bagging_freq': 3, 'min_child_samples': 58, 'lambda_l1': 0.0013042313425984634, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 10, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:32:31,881] Trial 29 finished with value: 0.2756274539092435 and parameters: {'num_leaves': 100, 'learning_rate': 0.12055894436154221, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.2825675711571143, 'lambda_l2': 1.0205488479288285, 'max_depth': 7, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:32:38,783] Trial 30 finished with value: 0.2710870819368496 and parameters: {'num_leaves': 100, 'learning_rate': 0.09450402849986439, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.0347297423012983, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:32:44,400] Trial 31 finished with value: 0.3735441240173245 and parameters: {'num_leaves': 100, 'learning_rate': 0.09613144686553321, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 10, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:32:51,634] Trial 32 finished with value: 1.0306333882670393 and parameters: {'num_leaves': 67, 'learning_rate': 0.062368755533348544, 'feature_fraction': 0.9567423192877778, 'bagging_fraction': 0.7, 'bagging_freq': 2, 'min_child_samples': 10, 'lambda_l1': 7.235160725544375, 'lambda_l2': 0.0010897192351370687, 'max_depth': 6, 'max_bin': 6000, 'min_data_in_leaf': 36, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:32:57,028] Trial 33 finished with value: 0.29698869321586135 and parameters: {'num_leaves': 70, 'learning_rate': 0.12904571033108542, 'feature_fraction': 0.990304889287285, 'bagging_fraction': 0.7427273654365498, 'bagging_freq': 2, 'min_child_samples': 67, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.3540734696537677, 'max_depth': 3, 'max_bin': 2789, 'min_data_in_leaf': 73, 'path_smooth': 0.2446027776837609, 'min_child_weight': 4.152193835994437}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:33:03,177] Trial 34 finished with value: 0.2999220853859738 and parameters: {'num_leaves': 96, 'learning_rate': 0.21519093274748016, 'feature_fraction': 0.7, 'bagging_fraction': 0.9576912549354668, 'bagging_freq': 4, 'min_child_samples': 77, 'lambda_l1': 0.00695220946862354, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 4845, 'min_data_in_leaf': 68, 'path_smooth': 0.43061856789127595, 'min_child_weight': 9.89602085248662}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:33:10,783] Trial 35 finished with value: 0.2907168568131141 and parameters: {'num_leaves': 86, 'learning_rate': 0.06740872785706095, 'feature_fraction': 0.7762928893913806, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.024299030173442513, 'lambda_l2': 0.402271830016294, 'max_depth': 3, 'max_bin': 5429, 'min_data_in_leaf': 88, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:33:18,043] Trial 36 finished with value: 0.2835185709083283 and parameters: {'num_leaves': 100, 'learning_rate': 0.07741729499660016, 'feature_fraction': 0.9695262940026357, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 88, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.0027234632398117783, 'max_depth': 7, 'max_bin': 1178, 'min_data_in_leaf': 32, 'path_smooth': 0.0, 'min_child_weight': 7.492459383023801}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:33:25,628] Trial 37 finished with value: 0.27225960890173995 and parameters: {'num_leaves': 100, 'learning_rate': 0.12067737994189091, 'feature_fraction': 0.8788917056127566, 'bagging_fraction': 0.7421146982789464, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.012005792108579699, 'lambda_l2': 9.999999999999998, 'max_depth': 5, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 8.970043040558895}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:33:33,831] Trial 38 finished with value: 0.28273320436770055 and parameters: {'num_leaves': 100, 'learning_rate': 0.11897928486237236, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 4, 'min_child_samples': 100, 'lambda_l1': 0.03004649973295635, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 47, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:33:40,801] Trial 39 finished with value: 0.3454411818555088 and parameters: {'num_leaves': 100, 'learning_rate': 0.12003265506144328, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.025626306945893206, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 10, 'min_data_in_leaf': 34, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:33:49,094] Trial 40 finished with value: 0.28058802057086657 and parameters: {'num_leaves': 85, 'learning_rate': 0.0678064761235565, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 25, 'lambda_l1': 0.009813212985052005, 'lambda_l2': 0.0010000000000000002, 'max_depth': 4, 'max_bin': 548, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 5.989343049086302}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:33:59,386] Trial 41 finished with value: 0.2805347821045251 and parameters: {'num_leaves': 20, 'learning_rate': 0.12593668545787656, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.009784448965245097, 'lambda_l2': 0.0010000000000000002, 'max_depth': 9, 'max_bin': 6000, 'min_data_in_leaf': 57, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:34:10,328] Trial 42 finished with value: 0.2766330547960832 and parameters: {'num_leaves': 43, 'learning_rate': 0.06425685993516092, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.013955401787733026, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 92, 'path_smooth': 0.0, 'min_child_weight': 7.090869018239796}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:34:16,971] Trial 43 finished with value: 0.2697608139160453 and parameters: {'num_leaves': 87, 'learning_rate': 0.08171509535780436, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 4, 'min_child_samples': 48, 'lambda_l1': 0.14339154493621742, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 1740, 'min_data_in_leaf': 100, 'path_smooth': 0.06848888629465995, 'min_child_weight': 8.904434681863197}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:34:27,383] Trial 44 finished with value: 0.324395145872431 and parameters: {'num_leaves': 100, 'learning_rate': 0.08299172148371514, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.0017579121416987067, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:34:36,092] Trial 45 finished with value: 0.4086554596983473 and parameters: {'num_leaves': 100, 'learning_rate': 0.06534844371651438, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.04909772374282428, 'lambda_l2': 0.08595525356760066, 'max_depth': 3, 'max_bin': 10, 'min_data_in_leaf': 100, 'path_smooth': 0.7113500574417191, 'min_child_weight': 5.3395326797325495}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:34:46,145] Trial 46 finished with value: 0.2781466147428502 and parameters: {'num_leaves': 100, 'learning_rate': 0.18309751070285754, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9150460174051877, 'bagging_freq': 3, 'min_child_samples': 42, 'lambda_l1': 0.005571342012911163, 'lambda_l2': 2.0846609390419477, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 71, 'path_smooth': 0.0, 'min_child_weight': 2.3415477010195858}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:34:52,826] Trial 47 finished with value: 0.2981161163277299 and parameters: {'num_leaves': 52, 'learning_rate': 0.10792361224395787, 'feature_fraction': 0.7226890730011916, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 41, 'lambda_l1': 0.11498546550742343, 'lambda_l2': 0.003490849454439017, 'max_depth': 3, 'max_bin': 6000, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 15 with value: 0.2674001315004593.
# [I 2025-07-16 19:35:03,590] Trial 48 finished with value: 0.2649504363091141 and parameters: {'num_leaves': 100, 'learning_rate': 0.07359232614253824, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.07681841132386126, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 2222, 'min_data_in_leaf': 56, 'path_smooth': 0.0, 'min_child_weight': 4.677136301448023}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:35:12,676] Trial 49 finished with value: 0.30581063262693126 and parameters: {'num_leaves': 20, 'learning_rate': 0.2731323114841698, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 33, 'lambda_l1': 0.030084638609804756, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 100, 'path_smooth': 0.7292063084501611, 'min_child_weight': 8.88256767183814}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:35:22,165] Trial 50 finished with value: 0.37070209607931465 and parameters: {'num_leaves': 54, 'learning_rate': 0.06477011255067183, 'feature_fraction': 0.9556684857993778, 'bagging_fraction': 0.7, 'bagging_freq': 2, 'min_child_samples': 73, 'lambda_l1': 0.009496222698298636, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 10, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:35:31,287] Trial 51 finished with value: 0.27207620819811706 and parameters: {'num_leaves': 100, 'learning_rate': 0.1109941526024614, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.09062944296041645, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 3006, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 8.324982171395089}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:35:39,483] Trial 52 finished with value: 0.2871878589959983 and parameters: {'num_leaves': 100, 'learning_rate': 0.06435856443380307, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 30, 'lambda_l1': 0.027365644937103174, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 3625, 'min_data_in_leaf': 75, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:35:46,563] Trial 53 finished with value: 0.2994491706942238 and parameters: {'num_leaves': 20, 'learning_rate': 0.07679587289655751, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.8108390760444167, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.022374987934995164, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 2038, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:35:59,604] Trial 54 finished with value: 0.2744097067298756 and parameters: {'num_leaves': 100, 'learning_rate': 0.09042008195018836, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.041583414418223025, 'lambda_l2': 0.7271547001981531, 'max_depth': 8, 'max_bin': 1354, 'min_data_in_leaf': 55, 'path_smooth': 0.0, 'min_child_weight': 5.481038824418097}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:36:10,473] Trial 55 finished with value: 0.28684612272145055 and parameters: {'num_leaves': 100, 'learning_rate': 0.2825009517289371, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.0341384530065583, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 614, 'min_data_in_leaf': 100, 'path_smooth': 0.6194961750335398, 'min_child_weight': 1.0}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:36:25,584] Trial 56 finished with value: 0.28905505772827267 and parameters: {'num_leaves': 100, 'learning_rate': 0.06697560922243753, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 92, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 4146, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 7.2375124927256245}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:36:37,939] Trial 57 finished with value: 0.28629946388896377 and parameters: {'num_leaves': 100, 'learning_rate': 0.06802931155771803, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2379, 'min_data_in_leaf': 20, 'path_smooth': 0.40565826876882755, 'min_child_weight': 5.43086145593022}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:36:50,915] Trial 58 finished with value: 0.2795678866094914 and parameters: {'num_leaves': 100, 'learning_rate': 0.1594077744053272, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.005354399289362094, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 6000, 'min_data_in_leaf': 34, 'path_smooth': 0.0, 'min_child_weight': 3.185376500430717}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:37:01,011] Trial 59 finished with value: 0.28432292384290914 and parameters: {'num_leaves': 58, 'learning_rate': 0.06273638956835374, 'feature_fraction': 0.7, 'bagging_fraction': 0.7175520504138917, 'bagging_freq': 2, 'min_child_samples': 10, 'lambda_l1': 0.0027720907551445468, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 5038, 'min_data_in_leaf': 55, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:37:11,445] Trial 60 finished with value: 0.2797620288060446 and parameters: {'num_leaves': 20, 'learning_rate': 0.2143532569067998, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.018285992732873343, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 85, 'path_smooth': 0.16736123280943843, 'min_child_weight': 2.96803302574895}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:37:21,235] Trial 61 finished with value: 0.2660963269094076 and parameters: {'num_leaves': 100, 'learning_rate': 0.10707642907731867, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.06071069797143522, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 6000, 'min_data_in_leaf': 42, 'path_smooth': 0.0, 'min_child_weight': 9.856684208924843}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:37:30,128] Trial 62 finished with value: 0.28487839829197426 and parameters: {'num_leaves': 100, 'learning_rate': 0.2832669561585617, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.03009888234579015, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 46, 'path_smooth': 0.9999999999999999, 'min_child_weight': 3.550095554193633}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:37:43,667] Trial 63 finished with value: 0.26701223540122426 and parameters: {'num_leaves': 100, 'learning_rate': 0.062182910160337855, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.010772638094148157, 'lambda_l2': 0.0162345265611977, 'max_depth': 7, 'max_bin': 1361, 'min_data_in_leaf': 64, 'path_smooth': 0.0, 'min_child_weight': 5.346976596625832}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:37:53,025] Trial 64 finished with value: 0.28879111965706167 and parameters: {'num_leaves': 100, 'learning_rate': 0.06388545016886843, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.015132934143594332, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 4120, 'min_data_in_leaf': 63, 'path_smooth': 0.0, 'min_child_weight': 5.261765831324662}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:38:02,178] Trial 65 finished with value: 0.27062131449532856 and parameters: {'num_leaves': 100, 'learning_rate': 0.10716427698797913, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.05520792463307582, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 1307, 'min_data_in_leaf': 30, 'path_smooth': 0.3183438811525324, 'min_child_weight': 9.999999999999998}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:38:11,796] Trial 66 finished with value: 0.3560767553806818 and parameters: {'num_leaves': 100, 'learning_rate': 0.06048871602789501, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.0048931910126327124, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 10, 'min_data_in_leaf': 40, 'path_smooth': 0.0, 'min_child_weight': 3.844669072112289}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:38:23,580] Trial 67 finished with value: 0.26899786973525863 and parameters: {'num_leaves': 20, 'learning_rate': 0.0814646258572894, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 2, 'min_child_samples': 100, 'lambda_l1': 0.16351910722718896, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 5510, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:38:35,335] Trial 68 finished with value: 0.2705164838909735 and parameters: {'num_leaves': 20, 'learning_rate': 0.0671193512426302, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.08394552150822665, 'lambda_l2': 0.0010000000000000002, 'max_depth': 4, 'max_bin': 6000, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:38:46,256] Trial 69 finished with value: 0.27841031031140895 and parameters: {'num_leaves': 84, 'learning_rate': 0.1049164018761126, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.004670796322529963, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2572, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:39:00,783] Trial 70 finished with value: 0.27265120925988107 and parameters: {'num_leaves': 30, 'learning_rate': 0.0484815312578714, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.006403692597599121, 'lambda_l2': 0.0012868753300445124, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 8.024958648641011}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:39:09,889] Trial 71 finished with value: 0.2784812382064168 and parameters: {'num_leaves': 100, 'learning_rate': 0.09405601744634869, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.08911873365253531, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 3471, 'min_data_in_leaf': 11, 'path_smooth': 0.0, 'min_child_weight': 6.589713924876186}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:39:22,229] Trial 72 finished with value: 0.2707825696426213 and parameters: {'num_leaves': 100, 'learning_rate': 0.09553533292090173, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.017699709454362406, 'min_child_weight': 2.719357713949104}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:39:34,141] Trial 73 finished with value: 0.2665534324869011 and parameters: {'num_leaves': 100, 'learning_rate': 0.20598030957094285, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.018041014692192305, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.6347812540956308, 'min_child_weight': 4.156549584861564}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:39:47,117] Trial 74 finished with value: 0.2712793091816654 and parameters: {'num_leaves': 35, 'learning_rate': 0.06305971601097451, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.017458050013652287, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 6.47832905651264}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:39:56,598] Trial 75 finished with value: 0.28680723326221447 and parameters: {'num_leaves': 100, 'learning_rate': 0.21234474318799404, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7404879884066248, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.012677456764105812, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 1669, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 3.7829370730992924}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:40:13,775] Trial 76 finished with value: 0.29465718203553587 and parameters: {'num_leaves': 100, 'learning_rate': 0.15742152295552347, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.002019079901560573, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.244261012258757}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:40:22,566] Trial 77 finished with value: 0.3827425070683585 and parameters: {'num_leaves': 20, 'learning_rate': 0.21701884453881296, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.015650784934795662, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 10, 'min_data_in_leaf': 100, 'path_smooth': 0.9037621405031295, 'min_child_weight': 4.483443478826318}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:40:33,610] Trial 78 finished with value: 0.27435122327835976 and parameters: {'num_leaves': 20, 'learning_rate': 0.07506234391996826, 'feature_fraction': 0.917551864585618, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 96, 'lambda_l1': 0.15845867221435916, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 98, 'path_smooth': 0.0, 'min_child_weight': 1.048545954678072}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:40:43,856] Trial 79 finished with value: 0.27798072007641156 and parameters: {'num_leaves': 100, 'learning_rate': 0.2129001961095859, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 11, 'lambda_l1': 0.07260379091234255, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 5927, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 7.6653653253390805}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:40:54,912] Trial 80 finished with value: 0.28744496158171995 and parameters: {'num_leaves': 100, 'learning_rate': 0.19418921097242853, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.011852627179303443, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 4502, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 5.001832080433919}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:41:07,290] Trial 81 finished with value: 0.29877123829881935 and parameters: {'num_leaves': 80, 'learning_rate': 0.060642568671611496, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.002893856555141745, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 6000, 'min_data_in_leaf': 100, 'path_smooth': 0.3344509162410542, 'min_child_weight': 7.566616355951288}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:41:17,525] Trial 82 finished with value: 0.32892710588829993 and parameters: {'num_leaves': 20, 'learning_rate': 0.09734347331691068, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2957, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.8098361646383356}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:41:30,411] Trial 83 finished with value: 0.2787217795191377 and parameters: {'num_leaves': 100, 'learning_rate': 0.08939258004234298, 'feature_fraction': 0.7823098524141018, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 4, 'min_child_samples': 93, 'lambda_l1': 0.045767060438117305, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 4573, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 7.844041761820073}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:41:39,707] Trial 84 finished with value: 0.27120549383064896 and parameters: {'num_leaves': 100, 'learning_rate': 0.22016470574313513, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 93, 'lambda_l1': 0.046025132431539266, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 4265, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:41:46,033] Trial 85 finished with value: 0.29209462595327146 and parameters: {'num_leaves': 100, 'learning_rate': 0.16666385588726246, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.0010999058570173134, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 1088, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:41:53,943] Trial 86 finished with value: 0.26517578766739275 and parameters: {'num_leaves': 100, 'learning_rate': 0.06928247620807598, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.17048824591699765, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 5749, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:42:03,084] Trial 87 finished with value: 0.26619371204173903 and parameters: {'num_leaves': 20, 'learning_rate': 0.057071905212205475, 'feature_fraction': 0.7776439026336917, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.009649645208989576, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 3883, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 48 with value: 0.2649504363091141.
# [I 2025-07-16 19:42:19,290] Trial 88 finished with value: 0.2554160351450552 and parameters: {'num_leaves': 100, 'learning_rate': 0.05903574495153758, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.005950599787956933, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 3722, 'min_data_in_leaf': 10, 'path_smooth': 0.7676024063227341, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:42:31,092] Trial 89 finished with value: 0.32533173336079696 and parameters: {'num_leaves': 100, 'learning_rate': 0.15883134126841958, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 3, 'min_child_samples': 10, 'lambda_l1': 0.6670439018472212, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:42:40,268] Trial 90 finished with value: 0.28530291393053364 and parameters: {'num_leaves': 100, 'learning_rate': 0.0985360040138645, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.0013747538305161463, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 5456, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:42:47,813] Trial 91 finished with value: 0.28498607922320984 and parameters: {'num_leaves': 100, 'learning_rate': 0.12753825307693267, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.002927091237668867, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 4168, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:42:57,934] Trial 92 finished with value: 0.28290841345898715 and parameters: {'num_leaves': 20, 'learning_rate': 0.05659111247529902, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.010058768021960086, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 4025, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:43:14,643] Trial 93 finished with value: 0.2729141214981335 and parameters: {'num_leaves': 100, 'learning_rate': 0.0587528465385651, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.008676279460049386, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 4123, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 5.999677029246122}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:43:25,101] Trial 94 finished with value: 0.29086943157729667 and parameters: {'num_leaves': 100, 'learning_rate': 0.24405448724389664, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.023645584199573463, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# ...
# [I 2025-07-16 19:57:41,483] Trial 170 finished with value: 0.25970344411865903 and parameters: {'num_leaves': 100, 'learning_rate': 0.05902498826329461, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.01012165535575663, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 2211, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 4.575312531321604}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:57:49,922] Trial 171 finished with value: 0.2961238625019641 and parameters: {'num_leaves': 20, 'learning_rate': 0.1070524251065139, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 85, 'lambda_l1': 0.020022767187318387, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2015, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:58:03,741] Trial 172 finished with value: 0.26698603829573025 and parameters: {'num_leaves': 100, 'learning_rate': 0.061024427733214315, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 59, 'lambda_l1': 0.0036845911472154188, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 2655, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:58:15,571] Trial 173 finished with value: 0.2747962495574751 and parameters: {'num_leaves': 20, 'learning_rate': 0.06344247678642642, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 91, 'lambda_l1': 0.14470970891164986, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 4780, 'min_data_in_leaf': 61, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:58:25,284] Trial 174 finished with value: 0.26115734638407273 and parameters: {'num_leaves': 100, 'learning_rate': 0.1117183365910311, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 19, 'lambda_l1': 0.03371064232109719, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:58:36,781] Trial 175 finished with value: 0.27796229916119547 and parameters: {'num_leaves': 100, 'learning_rate': 0.08266307894698088, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 40, 'lambda_l1': 0.0024247914272965843, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 3169, 'min_data_in_leaf': 16, 'path_smooth': 0.9999999999999999, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:58:47,378] Trial 176 finished with value: 0.2718132469711858 and parameters: {'num_leaves': 100, 'learning_rate': 0.06397232442534888, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.0071376870682316835, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2265, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 5.413170519386187}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:58:57,465] Trial 177 finished with value: 0.28019969423726954 and parameters: {'num_leaves': 20, 'learning_rate': 0.17400280531988116, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.020908516911768017, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:59:07,004] Trial 178 finished with value: 0.28900657163208016 and parameters: {'num_leaves': 100, 'learning_rate': 0.11248574718203469, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.007116947827697024, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 1405, 'min_data_in_leaf': 100, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:59:18,456] Trial 179 finished with value: 0.26107569290475646 and parameters: {'num_leaves': 20, 'learning_rate': 0.10439548641497999, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.022887394992038155, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:59:26,933] Trial 180 finished with value: 0.3008512270682258 and parameters: {'num_leaves': 100, 'learning_rate': 0.16743699476820537, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.003838809339526134, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 2924, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:59:35,825] Trial 181 finished with value: 0.27779380868717385 and parameters: {'num_leaves': 100, 'learning_rate': 0.19379502853639663, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 2544, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:59:45,170] Trial 182 finished with value: 0.26907878731122764 and parameters: {'num_leaves': 100, 'learning_rate': 0.08331072988580528, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.17583436047278328, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 3172, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 19:59:58,283] Trial 183 finished with value: 0.2704136943403668 and parameters: {'num_leaves': 20, 'learning_rate': 0.10326151787746195, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.041740454181509914, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 3980, 'min_data_in_leaf': 48, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:00:06,804] Trial 184 finished with value: 0.2848292550644243 and parameters: {'num_leaves': 100, 'learning_rate': 0.1854179571735465, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.0010000000000000002, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2885, 'min_data_in_leaf': 100, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:00:15,163] Trial 185 finished with value: 0.25823195831321466 and parameters: {'num_leaves': 100, 'learning_rate': 0.059462141384728946, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.01595185646868207, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 2536, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:00:24,576] Trial 186 finished with value: 0.2791451287208521 and parameters: {'num_leaves': 100, 'learning_rate': 0.29999999999999993, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.15008510357312327, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 4466, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.765534045412473}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:00:32,572] Trial 187 finished with value: 0.2667384686775469 and parameters: {'num_leaves': 100, 'learning_rate': 0.06587766861464864, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.13048914139996395, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 2837, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:00:44,200] Trial 188 finished with value: 0.2739409080326977 and parameters: {'num_leaves': 20, 'learning_rate': 0.0548648154079343, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.011294249873363376, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:00:55,002] Trial 189 finished with value: 0.26120494461545146 and parameters: {'num_leaves': 75, 'learning_rate': 0.06085145263218901, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.006517457630938664, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 2773, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 5.0489049393001535}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:01:04,549] Trial 190 finished with value: 0.2735135252618991 and parameters: {'num_leaves': 100, 'learning_rate': 0.21420617162944738, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.03200946730479123, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 3576, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 5.44755515493964}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:01:11,967] Trial 191 finished with value: 0.2767881827609013 and parameters: {'num_leaves': 100, 'learning_rate': 0.05908987264261254, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.012976620576709008, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2473, 'min_data_in_leaf': 10, 'path_smooth': 0.0, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:01:26,489] Trial 192 finished with value: 0.2617402708014609 and parameters: {'num_leaves': 20, 'learning_rate': 0.10749229850686018, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.030590805199601976, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 7.007774304261405}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:01:37,640] Trial 193 finished with value: 0.28653180392863953 and parameters: {'num_leaves': 100, 'learning_rate': 0.0714896400743509, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 100, 'lambda_l1': 0.0015645463891296864, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 2669, 'min_data_in_leaf': 100, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:01:53,996] Trial 194 finished with value: 0.2741105034313127 and parameters: {'num_leaves': 20, 'learning_rate': 0.10919558654021153, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.05890145353827972, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 6.12153427439857}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:02:03,547] Trial 195 finished with value: 0.2555986655363025 and parameters: {'num_leaves': 20, 'learning_rate': 0.05458230983914296, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.023760473284785335, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 8.685474671179861}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:02:13,550] Trial 196 finished with value: 0.30586954061854177 and parameters: {'num_leaves': 100, 'learning_rate': 0.1398551033177778, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.001436454826967895, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 822, 'min_data_in_leaf': 100, 'path_smooth': 0.15133262497577915, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:02:29,752] Trial 197 finished with value: 0.2992153772881344 and parameters: {'num_leaves': 100, 'learning_rate': 0.13859319101481413, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.0012399942267732596, 'lambda_l2': 0.0010000000000000002, 'max_depth': 10, 'max_bin': 2606, 'min_data_in_leaf': 100, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:02:37,850] Trial 198 finished with value: 0.2830289378822963 and parameters: {'num_leaves': 100, 'learning_rate': 0.1030473282089169, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.010653526113103187, 'lambda_l2': 9.999999999999998, 'max_depth': 3, 'max_bin': 6000, 'min_data_in_leaf': 10, 'path_smooth': 0.9999999999999999, 'min_child_weight': 9.999999999999998}. Best is trial 88 with value: 0.2554160351450552.
# [I 2025-07-16 20:02:46,793] Trial 199 finished with value: 0.2865200616017019 and parameters: {'num_leaves': 20, 'learning_rate': 0.0724361237479211, 'feature_fraction': 0.7, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.2003513668013574, 'lambda_l2': 0.0010000000000000002, 'max_depth': 3, 'max_bin': 3177, 'min_data_in_leaf': 100, 'path_smooth': 0.9999999999999999, 'min_child_weight': 1.0}. Best is trial 88 with value: 0.2554160351450552.
# Mejores hiperparámetros encontrados:
# {'num_leaves': 100, 'learning_rate': 0.05903574495153758, 'feature_fraction': 0.9999999999999999, 'bagging_fraction': 0.9999999999999999, 'bagging_freq': 1, 'min_child_samples': 10, 'lambda_l1': 0.005950599787956933, 'lambda_l2': 9.999999999999998, 'max_depth': 10, 'max_bin': 3722, 'min_data_in_leaf': 10, 'path_smooth': 0.7676024063227341, 'min_child_weight': 9.999999999999998}
# Mejor MAE: 0.2554

# %%
best_params = study.best_params.copy()
best_params.update({
    "objective": "regression",
    "metric": ["rmse", "mape"],
    "verbosity": -1,
    "n_jobs": -1,
    "seed": 42
})


model = lgb.train(
    best_params,
    lgb.Dataset(X_train, label=y_train),
    valid_sets=[lgb.Dataset(X_val, label=y_val)],
    callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)],
    num_boost_round = 1000
)

# Asegurar las mismas columnas
X_kgl = df_kgl[X_train.columns]  # Misma estructura

# === 9. Hacer predicción sobre nuevos datos ===
preds_kgl = model.predict(X_kgl)

# %%
result = pd.DataFrame({"product_id": X_kgl["product_id"], "tn_k":X_kgl["tn"], "pred": preds_kgl})
total = X_kgl["tn"].sum()
result["tn"] = result["pred"] * total*0.9
result = result[result["product_id"].isin(productos_ok["product_id"])]
result.loc[result["tn"] < 0, "tn"] = 0

result
# Out:
#        product_id        tn_k      pred          tn
# 35          20001  1504.68856  0.037555  849.893233
# 71          20002  1087.30855  0.034667  784.537125
# 107         20003   892.50129  0.024541  555.380130
# 143         20004   637.90002  0.018100  409.608192
# 179         20005   593.24443  0.015091  341.527429
# ...           ...         ...       ...         ...
# 22358       20962     1.99182  0.000082    1.851249
# 22362       20975     1.69045  0.000082    1.851249
# 22366       20995     1.55285  0.000080    1.819052
# 22370       21087     1.02205  0.000071    1.598291
# 22374       21214     0.24428  0.000071    1.598291
#
# [780 rows x 4 columns]

# %%
os.makedirs("results",exist_ok=True)
result[["product_id","tn"]].to_csv(f"results/shared_lgbm2.csv",sep=',', index=False)

# %%
import matplotlib.pyplot as plt
from lightgbm import plot_importance  # Importación específica
# Visualizar importancia de características
plot_importance(model, importance_type='gain', max_num_features=20)  # Usar la función importada
plt.show()
