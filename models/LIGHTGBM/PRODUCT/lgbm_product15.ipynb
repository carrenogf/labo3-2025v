# %%
study_name = "lightgbm15"

# %%
import pandas as pd
import gc
import numpy as np
from sklearn.preprocessing import LabelEncoder
from scipy.stats import linregress
from sklearn.model_selection import TimeSeriesSplit


df = pd.read_csv("../datasets/sell-in.txt.gz", sep="\t")
productos = pd.read_csv("../datasets/tb_productos.txt", sep="\t")
productos = productos.drop_duplicates(subset=["product_id"],keep="first")  # Eliminar duplicados por si acaso
stocks = pd.read_csv("../datasets/tb_stocks.txt", sep="\t")

productos_ok = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/product_id_apredecir201912.txt", sep="\t")
df = df[df["product_id"].isin(productos_ok["product_id"])]
df = df.groupby(by=["periodo","product_id"]).agg({
    "tn":"sum",
    "plan_precios_cuidados":"first",
    "customer_id":"nunique",
    }).reset_index()


productos_list = df['product_id'].unique()
periodos = df['periodo'].unique()
idx = pd.MultiIndex.from_product([productos_list, periodos], names=['product_id', 'periodo'])
completo = idx.to_frame(index=False)
# 4 filtrar combinaciones periodo_producto
completo = completo.merge(df, on=['periodo', 'product_id'], how='left')
nacimiento_producto = df.groupby('product_id')['periodo'].min().rename('nacimiento_producto')

completo = completo.merge(nacimiento_producto, on='product_id', how='left')
completo = completo[completo['periodo'] >= completo['nacimiento_producto']]



df = pd.merge(completo, productos, how="left", on="product_id")
df = df.merge(stocks, how="left", on=["product_id", "periodo"])

df["periodo"] = pd.to_datetime(df["periodo"], format="%Y%m")

df["mes"] = df["periodo"].dt.month
df["year"] = df["periodo"].dt.year
df["quarter"] = df["periodo"].dt.quarter

# totales por cat1 por periodo
df["cat1_total"] = df.groupby(["periodo", "cat1"])["tn"].transform("sum")
df["cat1_mean"] = df.groupby(["periodo", "cat1"])["tn"].transform("mean")
df["cat1_mean_12"] = df.groupby(["periodo", "cat1"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat1_customers"] = df.groupby(["periodo", "cat1"])["customer_id"].transform("nunique")
# totales por cat2 por periodo
df["cat2_total"] = df.groupby(["periodo", "cat2"])["tn"].transform("sum")
df["cat2_mean"] = df.groupby(["periodo", "cat2"])["tn"].transform("mean")
df["cat2_mean_12"] = df.groupby(["periodo", "cat2"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat2_customers"] = df.groupby(["periodo", "cat2"])["customer_id"].transform("nunique")
# totales por cat3 por periodo
df["cat3_total"] = df.groupby(["periodo", "cat3"])["tn"].transform("sum")
df["cat3_mean"] = df.groupby(["periodo", "cat3"])["tn"].transform("mean")
df["cat3_mean_12"] = df.groupby(["periodo", "cat3"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat3_customers"] = df.groupby(["periodo", "cat3"])["customer_id"].transform("nunique")


# shift t-1 a t12
meses = ["tn"]
for i in range(1, 13):
    df[f"tn_t{i}"] = df.groupby("product_id")["tn"].shift(i)
    df[f"delta_t{i}"] = df[f"tn"] / df[f"tn_t{i}"]
    meses.append(f"tn_t{i}")
    df[f"cat1_t{i}"] = df.groupby("product_id")["cat1_total"].shift(i)
    df[f"cat2_t{i}"] = df.groupby("product_id")["cat2_total"].shift(i)
    df[f"cat3_t{i}"] = df.groupby("product_id")["cat3_total"].shift(i)
    df[f"customer_id_t{i}"] = df.groupby("product_id")["customer_id"].shift(i)
  
df["i_tn_t12"] = df["tn"] / df["tn_t12"]
df["i_tn_t6"] = df["tn"] / df["tn_t6"]
df["i_tn_t3"] = df["tn"] / df["tn_t3"]

df["i_tn_customers"] = df["tn"] / df["customer_id"]

df["promedio_t12"] = df[meses].mean(axis=1)
df["promedio_t6"] = df[meses[:6]].mean(axis=1)
df["promedio_t3"] = df[meses[:3]].mean(axis=1)

df["mediana_t12"] = df[meses].median(axis=1)
df["mediana_t6"] = df[meses[:6]].median(axis=1)
df["mediana_t3"] = df[meses[:3]].median(axis=1)

df["maximo_t12"] = df[meses].max(axis=1)
df["maximo_t6"] = df[meses[:6]].max(axis=1)
df["maximo_t3"] = df[meses[:3]].max(axis=1)

df["minimo_t12"] = df[meses].min(axis=1)
df["minimo_t6"] = df[meses[:6]].min(axis=1)
df["minimo_t3"] = df[meses[:3]].min(axis=1)

# Función para calcular la pendiente de una serie temporal
def calcular_pendiente(serie):
    datos = serie.dropna().values
    if len(datos) < 2:  # Mínimo 2 puntos para una regresión
        return np.nan
    x = np.arange(len(datos))  # [0, 1, 2, ..., n-1] (representa el tiempo)
    slope, _, _, _, _ = linregress(x, datos)
    return slope

# Aplicamos la función por grupo (producto) y reindexamos para alinear con df
df["pendiente_reg_12"] = (
    df.groupby("product_id")[meses]
    .apply(lambda grupo: grupo.apply(calcular_pendiente, axis=1))
    .reset_index(level=0, drop=True)  # Eliminamos el nivel de grupo para alinear índices
)

df['media_movil_3m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(3).mean())
df['media_movil_6m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(6).mean())
df['media_movil_12m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(12).mean())
df['diff_media_3_6'] = df['media_movil_3m'] - df['media_movil_6m']
df['diff_media_6_12'] = df['media_movil_6m'] - df['media_movil_12m']
df['diff_media_3_12'] = df['media_movil_3m'] - df['media_movil_12m']
df["diff_tn_mm3"] = df["tn"] - df['media_movil_3m']
df["diff_tn_mm6"] = df["tn"] - df['media_movil_6m']
df["diff_tn_mm12"] = df["tn"] - df['media_movil_12m']
df["i_tn_mm3"] = df["tn"] / df['media_movil_3m']
df["i_tn_mm6"] = df["tn"] / df['media_movil_6m']
df["i_tn_mm12"] = df["tn"] / df['media_movil_12m']

from scipy.stats import mode
def rolling_mode(x):
    return x.shift(1).rolling(6, min_periods=1).apply(lambda x: mode(x, keepdims=True)[0][0], raw=False)
#Moda o patrón de cantidad
df['modo_6m'] = df.groupby(['product_id'])['tn'].transform(rolling_mode)
df['modo_diff'] = df['tn'] - df['modo_6m']


# target t+2
df["target"] = df.groupby("product_id")["tn"].shift(-2)




cat_cols = ['cat1', 'cat2', 'cat3', 'brand']
for col in cat_cols:
    if col in df.columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
        
del completo, productos, stocks
gc.collect()
df
# Out:
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:83: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["mediana_t12"] = df[meses].median(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["mediana_t6"] = df[meses[:6]].median(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:85: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["mediana_t3"] = df[meses[:3]].median(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:87: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["maximo_t12"] = df[meses].max(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["maximo_t6"] = df[meses[:6]].max(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["maximo_t3"] = df[meses[:3]].max(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["minimo_t12"] = df[meses].min(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["minimo_t6"] = df[meses[:6]].min(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:93: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["minimo_t3"] = df[meses[:3]].min(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:105: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["pendiente_reg_12"] = (
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['media_movil_3m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(3).mean())
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:112: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['media_movil_6m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(6).mean())
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:113: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['media_movil_12m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(12).mean())
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:114: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['diff_media_3_6'] = df['media_movil_3m'] - df['media_movil_6m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['diff_media_6_12'] = df['media_movil_6m'] - df['media_movil_12m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['diff_media_3_12'] = df['media_movil_3m'] - df['media_movil_12m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["diff_tn_mm3"] = df["tn"] - df['media_movil_3m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["diff_tn_mm6"] = df["tn"] - df['media_movil_6m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["diff_tn_mm12"] = df["tn"] - df['media_movil_12m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["i_tn_mm3"] = df["tn"] / df['media_movil_3m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["i_tn_mm6"] = df["tn"] / df['media_movil_6m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:122: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["i_tn_mm12"] = df["tn"] / df['media_movil_12m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:128: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['modo_6m'] = df.groupby(['product_id'])['tn'].transform(rolling_mode)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['modo_diff'] = df['tn'] - df['modo_6m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\691632394.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["target"] = df.groupby("product_id")["tn"].shift(-2)
#        product_id    periodo          tn  plan_precios_cuidados  customer_id  \
# 0           20001 2017-01-01   934.77222                    0.0        186.0
# 1           20001 2017-02-01   798.01620                    0.0        185.0
# 2           20001 2017-03-01  1303.35771                    0.0        188.0
# 3           20001 2017-04-01  1069.96130                    0.0        104.0
# 4           20001 2017-05-01  1502.20132                    0.0        238.0
# ...           ...        ...         ...                    ...          ...
# 22370       21087 2019-12-01     1.02205                    0.0         51.0
# 22371       21214 2019-09-01     0.34250                    0.0          2.0
# 22372       21214 2019-10-01     0.21735                    0.0         38.0
# 22373       21214 2019-11-01     0.84012                    0.0         43.0
# 22374       21214 2019-12-01     0.24428                    0.0         37.0
#
#        nacimiento_producto  cat1  cat2  cat3  brand  ...  diff_media_3_12  \
# 0                   201701     1    10    47      0  ...              NaN
# 1                   201701     1    10    47      0  ...              NaN
# 2                   201701     1    10    47      0  ...              NaN
# 3                   201701     1    10    47      0  ...              NaN
# 4                   201701     1    10    47      0  ...              NaN
# ...                    ...   ...   ...   ...    ...  ...              ...
# 22370               201909     2     3     3     23  ...              NaN
# 22371               201909     2     3    65     23  ...              NaN
# 22372               201909     2     3    65     23  ...              NaN
# 22373               201909     2     3    65     23  ...              NaN
# 22374               201909     2     3    65     23  ...              NaN
#
#        diff_tn_mm3  diff_tn_mm6  diff_tn_mm12  i_tn_mm3  i_tn_mm6  i_tn_mm12  \
# 0              NaN          NaN           NaN       NaN       NaN        NaN
# 1              NaN          NaN           NaN       NaN       NaN        NaN
# 2       291.309000          NaN           NaN  1.287841       NaN        NaN
# 3        12.849563          NaN           NaN  1.012155       NaN        NaN
# 4       210.361210          NaN           NaN  1.162838       NaN        NaN
# ...            ...          ...           ...       ...       ...        ...
# 22370    -0.087857          NaN           NaN  0.920843       NaN        NaN
# 22371          NaN          NaN           NaN       NaN       NaN        NaN
# 22372          NaN          NaN           NaN       NaN       NaN        NaN
# 22373     0.373463          NaN           NaN  1.800296       NaN        NaN
# 22374    -0.189637          NaN           NaN  0.562965       NaN        NaN
#
#          modo_6m  modo_diff      target
# 0            NaN        NaN  1303.35771
# 1      934.77222 -136.75602  1069.96130
# 2      798.01620  505.34151  1502.20132
# 3      798.01620  271.94510  1520.06539
# 4      798.01620  704.18512  1030.67391
# ...          ...        ...         ...
# 22370    0.29997    0.72208         NaN
# 22371        NaN        NaN     0.84012
# 22372    0.34250   -0.12515     0.24428
# 22373    0.21735    0.62277         NaN
# 22374    0.21735    0.02693         NaN
#
# [22375 rows x 131 columns]

# %%
df_kgl = df[df["periodo"] == "2019-12-01"]
df_kgl["periodo"] = df_kgl["periodo"].astype(int)
df = df[~df["periodo"].isin(["2019-11-01", "2019-12-01"])]
# Out:
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\2505419454.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kgl["periodo"] = df_kgl["periodo"].astype(int)
# C:\Users\carre\AppData\Local\Temp\ipykernel_11044\2505419454.py:3: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df = df[~df["periodo"].isin(["2019-11-01", "2019-12-01"])]

# %%
# Definir fecha de corte
fecha_corte = "2019-10-01"

# Separar entrenamiento y test
df_train = df[df["periodo"] < fecha_corte].copy()
df_train["target"] = df_train["target"].fillna(0)  # Asegurarse de que no haya NaN en el target
df_test = df[df["periodo"] == fecha_corte].copy()
# Separar variables predictoras (eliminando target y columnas que no se usan)
features = [col for col in df.columns if col not in ["target"]]

X_train = df_train[features].copy()
X_train["periodo"] = X_train["periodo"].astype(int)
y_train = df_train["target"].copy()

X_val = df_test[features].copy()
X_val["periodo"] = X_val["periodo"].astype(int)
y_val = df_test["target"].copy()

sort_idx = df_train["periodo"].argsort()
X_train = X_train.iloc[sort_idx].reset_index(drop=True)
y_train = y_train.iloc[sort_idx].reset_index(drop=True)

# %%
# # Separar features y target
# X = df.drop(columns=["target"])
# y = df["target"]
# X_train = X[X["periodo"] < '2019-10-01']
# X_train["periodo"] = X_train["periodo"].astype(int)
# y_train = y[X["periodo"] < '2019-10-01']

# X_val = X[X["periodo"] == '2019-10-01']
# X_val["periodo"] = X_val["periodo"].astype(int)
# y_val = y[X["periodo"] == '2019-10-01']

# %%
import lightgbm as lgb
import optuna
from sklearn.metrics import mean_squared_error, mean_absolute_error 
import os

def custom_mape_loss(y_true, y_pred):
    numerator = np.sum(np.abs(y_true - y_pred))
    denominator = np.sum(np.abs(y_true))
    epsilon = np.finfo(float).eps  # Valor muy pequeño para evitar división por cero
    return numerator / (denominator + epsilon)

# === 2. Definición del objetivo para Optuna ===
def objective(trial):
    params = {
        "objective": "regression",
        "metric": "mape",
        "boosting_type": "gbdt",
        "verbosity": -1,
        "n_jobs": -1,
        "seed": 42,
        "linear_tree": True,
        "num_leaves": trial.suggest_int("num_leaves", 20, 300),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.2),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 0.9),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.7, 0.95),
        "bagging_freq": trial.suggest_int("bagging_freq", 0, 5),
        "min_child_samples": trial.suggest_int("min_child_samples", 10, 100),
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-3, 5.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-3, 5.0, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 18),
        "max_bin": trial.suggest_int("max_bin", 2000, 8000),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 200),
        "extra_trees": trial.suggest_categorical("extra_trees", [True, False]),
        "path_smooth": trial.suggest_float("path_smooth", 0, 1),
    }

    # Inicializar el CV
    tscv = TimeSeriesSplit(n_splits=3)
    mape_scores = []

    for train_index, val_index in tscv.split(X_train):
        X_tr, X_val_split = X_train.iloc[train_index], X_train.iloc[val_index]
        y_tr, y_val_split = y_train.iloc[train_index], y_train.iloc[val_index]
        w_tr = X_tr["tn"].to_numpy()

        dtrain = lgb.Dataset(X_tr, label=y_tr, weight=w_tr)
        dval = lgb.Dataset(X_val_split, label=y_val_split)

        model = lgb.train(
            params,
            dtrain,
            valid_sets=[dval],
            num_boost_round=1000,
            callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)],
        )

        preds = model.predict(X_val_split)
        mae = mean_absolute_error(y_val_split, preds)
        mape_scores.append(mae)

    return np.mean(mape_scores)

# === 3. Configurar almacenamiento SQLite para Optuna ===
os.makedirs("optuna_storage", exist_ok=True)
DB_PATH = "optuna_storage/optuna.db"
STUDY_NAME = study_name
storage_url = f"sqlite:///{DB_PATH}"

# === 4. Crear o cargar estudio ===
study = optuna.create_study(
    study_name=STUDY_NAME,
    storage=storage_url,
    direction="minimize",
    load_if_exists=True
)

# === 5. Ejecutar optimización ===
study.optimize(objective, n_trials=150)

# === 6. Mostrar resultados ===
print("Mejores hiperparámetros encontrados:")
print(study.best_params)
print(f"Mejor MAE: {study.best_value:.4f}")
# Out:
# [I 2025-07-12 12:16:27,612] Using an existing study with name 'lightgbm15' instead of creating a new one.
# [I 2025-07-12 12:16:35,532] Trial 24 finished with value: 1.267009970607098e+18 and parameters: {'num_leaves': 69, 'learning_rate': 0.055291897749258315, 'feature_fraction': 0.7990409026415956, 'bagging_fraction': 0.9267776503103184, 'bagging_freq': 1, 'min_child_samples': 24, 'lambda_l1': 0.18594084980384581, 'lambda_l2': 0.022793908686044393, 'max_depth': 15, 'max_bin': 2773, 'min_data_in_leaf': 97, 'extra_trees': True, 'path_smooth': 0.18340597788263596}. Best is trial 16 with value: 875687403153164.0.
# [I 2025-07-12 12:16:41,586] Trial 25 finished with value: 60182.53208620876 and parameters: {'num_leaves': 99, 'learning_rate': 0.1757918646771815, 'feature_fraction': 0.7214908794778776, 'bagging_fraction': 0.8709042606328, 'bagging_freq': 1, 'min_child_samples': 88, 'lambda_l1': 1.0724041715350847, 'lambda_l2': 0.10656819766490977, 'max_depth': 6, 'max_bin': 2236, 'min_data_in_leaf': 136, 'extra_trees': False, 'path_smooth': 0.6687513195505532}. Best is trial 25 with value: 60182.53208620876.
# [I 2025-07-12 12:16:47,907] Trial 26 finished with value: 1.6036673865817648e+17 and parameters: {'num_leaves': 124, 'learning_rate': 0.1730050155374246, 'feature_fraction': 0.7308345838457763, 'bagging_fraction': 0.8831910466881139, 'bagging_freq': 1, 'min_child_samples': 87, 'lambda_l1': 1.4652072240693703, 'lambda_l2': 0.14987885591473898, 'max_depth': 6, 'max_bin': 2835, 'min_data_in_leaf': 130, 'extra_trees': False, 'path_smooth': 0.8376599862062432}. Best is trial 25 with value: 60182.53208620876.
# [I 2025-07-12 12:16:51,923] Trial 27 finished with value: 7551.270040818287 and parameters: {'num_leaves': 67, 'learning_rate': 0.14563971436633139, 'feature_fraction': 0.633448197133643, 'bagging_fraction': 0.8318981258805362, 'bagging_freq': 1, 'min_child_samples': 64, 'lambda_l1': 1.1350548866293197, 'lambda_l2': 0.03450502357055946, 'max_depth': 3, 'max_bin': 4065, 'min_data_in_leaf': 141, 'extra_trees': False, 'path_smooth': 0.5459756302166195}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:16:56,051] Trial 28 finished with value: 18487.182252890107 and parameters: {'num_leaves': 22, 'learning_rate': 0.14443976285057364, 'feature_fraction': 0.6316283314768957, 'bagging_fraction': 0.8338667456932463, 'bagging_freq': 1, 'min_child_samples': 63, 'lambda_l1': 1.1952995873570238, 'lambda_l2': 1.0884978705994213, 'max_depth': 3, 'max_bin': 4261, 'min_data_in_leaf': 143, 'extra_trees': False, 'path_smooth': 0.5699366000542991}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:16:59,967] Trial 29 finished with value: 13911.062154272806 and parameters: {'num_leaves': 34, 'learning_rate': 0.1455653866575681, 'feature_fraction': 0.6326472069784336, 'bagging_fraction': 0.8267072180483346, 'bagging_freq': 1, 'min_child_samples': 61, 'lambda_l1': 1.253722010823677, 'lambda_l2': 1.5387643704626566, 'max_depth': 3, 'max_bin': 4291, 'min_data_in_leaf': 168, 'extra_trees': False, 'path_smooth': 0.6945804212410642}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:04,004] Trial 30 finished with value: 42401.690021726914 and parameters: {'num_leaves': 28, 'learning_rate': 0.14561279833402685, 'feature_fraction': 0.6335730290290496, 'bagging_fraction': 0.8325818498625321, 'bagging_freq': 1, 'min_child_samples': 56, 'lambda_l1': 2.8006456928533616, 'lambda_l2': 1.5381652431568182, 'max_depth': 3, 'max_bin': 4185, 'min_data_in_leaf': 165, 'extra_trees': False, 'path_smooth': 0.5646644572587182}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:09,798] Trial 31 finished with value: 5.1764964153357126e+17 and parameters: {'num_leaves': 22, 'learning_rate': 0.11593636576961455, 'feature_fraction': 0.8905729094919286, 'bagging_fraction': 0.8018670089153813, 'bagging_freq': 0, 'min_child_samples': 62, 'lambda_l1': 0.21811114146970573, 'lambda_l2': 1.1008583249643658, 'max_depth': 4, 'max_bin': 4728, 'min_data_in_leaf': 195, 'extra_trees': False, 'path_smooth': 0.7325472534517505}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:14,244] Trial 32 finished with value: 90870.41308179806 and parameters: {'num_leaves': 57, 'learning_rate': 0.13799085128585556, 'feature_fraction': 0.6325547852343134, 'bagging_fraction': 0.8413316366121754, 'bagging_freq': 1, 'min_child_samples': 47, 'lambda_l1': 3.350983318606142, 'lambda_l2': 1.7422512145351539, 'max_depth': 4, 'max_bin': 3932, 'min_data_in_leaf': 182, 'extra_trees': False, 'path_smooth': 0.8856127415489764}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:18,826] Trial 33 finished with value: 1.0502371380192017e+18 and parameters: {'num_leaves': 52, 'learning_rate': 0.1502252350129654, 'feature_fraction': 0.6002944161961229, 'bagging_fraction': 0.8102090338848371, 'bagging_freq': 2, 'min_child_samples': 68, 'lambda_l1': 1.1293702644083317, 'lambda_l2': 0.5176650926004834, 'max_depth': 4, 'max_bin': 5538, 'min_data_in_leaf': 158, 'extra_trees': False, 'path_smooth': 0.6068375393259383}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:23,286] Trial 34 finished with value: 60401.11467276217 and parameters: {'num_leaves': 42, 'learning_rate': 0.10458457120124116, 'feature_fraction': 0.6878566809447249, 'bagging_fraction': 0.8223001795464513, 'bagging_freq': 0, 'min_child_samples': 39, 'lambda_l1': 0.23490851234941998, 'lambda_l2': 0.32668145584287106, 'max_depth': 3, 'max_bin': 4792, 'min_data_in_leaf': 112, 'extra_trees': False, 'path_smooth': 0.7044468725183153}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:27,313] Trial 35 finished with value: 14069.451545647893 and parameters: {'num_leaves': 26, 'learning_rate': 0.13582576168599686, 'feature_fraction': 0.6367219680692, 'bagging_fraction': 0.8306870680304325, 'bagging_freq': 1, 'min_child_samples': 60, 'lambda_l1': 2.6027034941082996, 'lambda_l2': 0.9393432031172949, 'max_depth': 3, 'max_bin': 4299, 'min_data_in_leaf': 167, 'extra_trees': False, 'path_smooth': 0.5199409334419712}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:32,941] Trial 36 finished with value: 1.0242541437700069e+18 and parameters: {'num_leaves': 20, 'learning_rate': 0.13147909123628232, 'feature_fraction': 0.6313090997726477, 'bagging_fraction': 0.7818780711251743, 'bagging_freq': 1, 'min_child_samples': 58, 'lambda_l1': 1.9878784934233384, 'lambda_l2': 0.7873829832113821, 'max_depth': 5, 'max_bin': 4264, 'min_data_in_leaf': 183, 'extra_trees': False, 'path_smooth': 0.5474759905820399}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:37,415] Trial 37 finished with value: 55656.36393393088 and parameters: {'num_leaves': 62, 'learning_rate': 0.1138669622352184, 'feature_fraction': 0.6009962883852107, 'bagging_fraction': 0.8479562844210069, 'bagging_freq': 0, 'min_child_samples': 70, 'lambda_l1': 4.7361578467834375, 'lambda_l2': 2.5883485750359085, 'max_depth': 3, 'max_bin': 5157, 'min_data_in_leaf': 140, 'extra_trees': False, 'path_smooth': 0.35707118600684284}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:43,745] Trial 38 finished with value: 8.418756996810003e+16 and parameters: {'num_leaves': 35, 'learning_rate': 0.15715428622405483, 'feature_fraction': 0.6414185371962594, 'bagging_fraction': 0.7916100500821722, 'bagging_freq': 1, 'min_child_samples': 48, 'lambda_l1': 0.8556269018551286, 'lambda_l2': 0.9025978388078814, 'max_depth': 5, 'max_bin': 3918, 'min_data_in_leaf': 156, 'extra_trees': False, 'path_smooth': 0.7949539868064984}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:49,138] Trial 39 finished with value: 3.0774468881797344e+17 and parameters: {'num_leaves': 58, 'learning_rate': 0.1261650455325974, 'feature_fraction': 0.6193400752041494, 'bagging_fraction': 0.8233946004803037, 'bagging_freq': 0, 'min_child_samples': 60, 'lambda_l1': 2.0854492581375093, 'lambda_l2': 0.28774010251064697, 'max_depth': 4, 'max_bin': 4868, 'min_data_in_leaf': 173, 'extra_trees': False, 'path_smooth': 0.4981221323888825}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:53,523] Trial 40 finished with value: 45546.17670851702 and parameters: {'num_leaves': 39, 'learning_rate': 0.14213438359393704, 'feature_fraction': 0.6809931674223402, 'bagging_fraction': 0.7025930789579157, 'bagging_freq': 2, 'min_child_samples': 53, 'lambda_l1': 0.048817819798362846, 'lambda_l2': 4.61580596764844, 'max_depth': 3, 'max_bin': 5450, 'min_data_in_leaf': 105, 'extra_trees': False, 'path_smooth': 0.41427588517543057}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:17:58,149] Trial 41 finished with value: 1.7688447028756522e+17 and parameters: {'num_leaves': 76, 'learning_rate': 0.1845265681310963, 'feature_fraction': 0.6518647663627467, 'bagging_fraction': 0.8204947655591576, 'bagging_freq': 1, 'min_child_samples': 80, 'lambda_l1': 0.3165130923040709, 'lambda_l2': 0.048428987897706145, 'max_depth': 5, 'max_bin': 3665, 'min_data_in_leaf': 192, 'extra_trees': False, 'path_smooth': 0.6027638804148534}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:18:06,141] Trial 42 finished with value: 2.884566594249579e+17 and parameters: {'num_leaves': 50, 'learning_rate': 0.13288193702175688, 'feature_fraction': 0.6168816717999229, 'bagging_fraction': 0.7529679335296304, 'bagging_freq': 0, 'min_child_samples': 72, 'lambda_l1': 0.7408544906137998, 'lambda_l2': 1.7104640254403738, 'max_depth': 7, 'max_bin': 4511, 'min_data_in_leaf': 163, 'extra_trees': False, 'path_smooth': 0.33655261168101513}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:18:11,653] Trial 43 finished with value: 63981.266504011604 and parameters: {'num_leaves': 188, 'learning_rate': 0.1608077679872285, 'feature_fraction': 0.6981470258052179, 'bagging_fraction': 0.8069157843341518, 'bagging_freq': 2, 'min_child_samples': 35, 'lambda_l1': 0.11117326696237402, 'lambda_l2': 0.6012527394190649, 'max_depth': 4, 'max_bin': 5995, 'min_data_in_leaf': 180, 'extra_trees': False, 'path_smooth': 0.45644773027812635}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:18:17,472] Trial 44 finished with value: 72365.8100636214 and parameters: {'num_leaves': 90, 'learning_rate': 0.11329177859869392, 'feature_fraction': 0.6460448031595248, 'bagging_fraction': 0.7910776660498017, 'bagging_freq': 1, 'min_child_samples': 51, 'lambda_l1': 2.2015019399936446, 'lambda_l2': 1.216709703774725, 'max_depth': 5, 'max_bin': 4135, 'min_data_in_leaf': 127, 'extra_trees': False, 'path_smooth': 0.88306350491306}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:18:21,223] Trial 45 finished with value: 30605.777532856595 and parameters: {'num_leaves': 30, 'learning_rate': 0.14805771891152017, 'feature_fraction': 0.6283705157064465, 'bagging_fraction': 0.8361064014285089, 'bagging_freq': 1, 'min_child_samples': 57, 'lambda_l1': 3.535138621888956, 'lambda_l2': 1.7970158214895546, 'max_depth': 3, 'max_bin': 4511, 'min_data_in_leaf': 166, 'extra_trees': False, 'path_smooth': 0.5629216177645743}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:18:25,235] Trial 46 finished with value: 13896.95908663003 and parameters: {'num_leaves': 37, 'learning_rate': 0.150484017350952, 'feature_fraction': 0.6695516270008629, 'bagging_fraction': 0.8532018691316674, 'bagging_freq': 1, 'min_child_samples': 62, 'lambda_l1': 3.578077055986571, 'lambda_l2': 3.3531796657051856, 'max_depth': 3, 'max_bin': 5028, 'min_data_in_leaf': 149, 'extra_trees': False, 'path_smooth': 0.5810884338774862}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:18:30,118] Trial 47 finished with value: 3.849417201278487e+17 and parameters: {'num_leaves': 36, 'learning_rate': 0.11927773981532286, 'feature_fraction': 0.6132656736081321, 'bagging_fraction': 0.8589211166144438, 'bagging_freq': 0, 'min_child_samples': 64, 'lambda_l1': 1.6863267713463526, 'lambda_l2': 3.0793457855853283, 'max_depth': 4, 'max_bin': 5063, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.6201401513256537}. Best is trial 27 with value: 7551.270040818287.
# [I 2025-07-12 12:18:33,919] Trial 48 finished with value: 3740.627231059733 and parameters: {'num_leaves': 20, 'learning_rate': 0.17289029562957425, 'feature_fraction': 0.6721899009448079, 'bagging_fraction': 0.8720561001042189, 'bagging_freq': 1, 'min_child_samples': 77, 'lambda_l1': 0.962607079692408, 'lambda_l2': 2.6434752121023406, 'max_depth': 3, 'max_bin': 3791, 'min_data_in_leaf': 151, 'extra_trees': False, 'path_smooth': 0.688890726841421}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:18:41,221] Trial 49 finished with value: 2.40222674760428e+17 and parameters: {'num_leaves': 65, 'learning_rate': 0.18482691501238224, 'feature_fraction': 0.6735160691702646, 'bagging_fraction': 0.8705981361758313, 'bagging_freq': 2, 'min_child_samples': 78, 'lambda_l1': 0.7453383501706202, 'lambda_l2': 4.863672909301989, 'max_depth': 7, 'max_bin': 5338, 'min_data_in_leaf': 116, 'extra_trees': False, 'path_smooth': 0.6829510495519044}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:18:46,732] Trial 50 finished with value: 1.3533270095848454e+17 and parameters: {'num_leaves': 49, 'learning_rate': 0.16916637410409424, 'feature_fraction': 0.6714622986656242, 'bagging_fraction': 0.8466472973158232, 'bagging_freq': 0, 'min_child_samples': 74, 'lambda_l1': 0.3421835661628145, 'lambda_l2': 2.6307907168609876, 'max_depth': 5, 'max_bin': 3653, 'min_data_in_leaf': 153, 'extra_trees': False, 'path_smooth': 0.7358881882789863}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:18:51,051] Trial 51 finished with value: 18797.974248176022 and parameters: {'num_leaves': 145, 'learning_rate': 0.15444057640304612, 'feature_fraction': 0.6940497695657442, 'bagging_fraction': 0.8725917687292474, 'bagging_freq': 1, 'min_child_samples': 82, 'lambda_l1': 2.7547721717296474, 'lambda_l2': 0.012228238016348272, 'max_depth': 3, 'max_bin': 5870, 'min_data_in_leaf': 187, 'extra_trees': False, 'path_smooth': 0.0045556205823350515}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:18:55,394] Trial 52 finished with value: 9.43390823003249e+17 and parameters: {'num_leaves': 290, 'learning_rate': 0.18070323683559608, 'feature_fraction': 0.7111622333328629, 'bagging_fraction': 0.894260528540566, 'bagging_freq': 2, 'min_child_samples': 67, 'lambda_l1': 3.910086325986442, 'lambda_l2': 0.0045509297884071325, 'max_depth': 4, 'max_bin': 3485, 'min_data_in_leaf': 173, 'extra_trees': True, 'path_smooth': 0.6496593358476604}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:03,655] Trial 53 finished with value: 1.865001709265202e+18 and parameters: {'num_leaves': 112, 'learning_rate': 0.19049657608719658, 'feature_fraction': 0.6650829756789813, 'bagging_fraction': 0.8557376806140442, 'bagging_freq': 2, 'min_child_samples': 75, 'lambda_l1': 0.0395832843410742, 'lambda_l2': 0.03853321803715309, 'max_depth': 8, 'max_bin': 6471, 'min_data_in_leaf': 131, 'extra_trees': False, 'path_smooth': 0.7133714140771563}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:13,309] Trial 54 finished with value: 6.710529392973905e+17 and parameters: {'num_leaves': 86, 'learning_rate': 0.1313998940706758, 'feature_fraction': 0.7340796147833341, 'bagging_fraction': 0.8132888104862117, 'bagging_freq': 1, 'min_child_samples': 70, 'lambda_l1': 0.9567434070930354, 'lambda_l2': 2.6498857651735994, 'max_depth': 9, 'max_bin': 3903, 'min_data_in_leaf': 159, 'extra_trees': False, 'path_smooth': 0.7997332695388866}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:17,068] Trial 55 finished with value: 29965.902135511064 and parameters: {'num_leaves': 33, 'learning_rate': 0.14053904243162244, 'feature_fraction': 0.6456030683719882, 'bagging_fraction': 0.8292672429530715, 'bagging_freq': 1, 'min_child_samples': 62, 'lambda_l1': 1.3322964833685342, 'lambda_l2': 0.8093374580293702, 'max_depth': 3, 'max_bin': 4608, 'min_data_in_leaf': 148, 'extra_trees': False, 'path_smooth': 0.5125154935386103}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:20,810] Trial 56 finished with value: 10261.466247361112 and parameters: {'num_leaves': 22, 'learning_rate': 0.16290513117681812, 'feature_fraction': 0.6227609141703664, 'bagging_fraction': 0.8397297952035572, 'bagging_freq': 1, 'min_child_samples': 60, 'lambda_l1': 2.635795419673831, 'lambda_l2': 2.1370701314229796, 'max_depth': 3, 'max_bin': 4356, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.5753990492411142}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:25,637] Trial 57 finished with value: 70532.15849256923 and parameters: {'num_leaves': 44, 'learning_rate': 0.16424500155216518, 'feature_fraction': 0.6122876593871661, 'bagging_fraction': 0.8487606108042686, 'bagging_freq': 1, 'min_child_samples': 53, 'lambda_l1': 2.4830234913198805, 'lambda_l2': 3.7459944329451127, 'max_depth': 4, 'max_bin': 5070, 'min_data_in_leaf': 119, 'extra_trees': False, 'path_smooth': 0.5929685053943967}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:29,646] Trial 58 finished with value: 51620.22559098268 and parameters: {'num_leaves': 20, 'learning_rate': 0.1724336260241483, 'feature_fraction': 0.6529093781501676, 'bagging_fraction': 0.8815841634204428, 'bagging_freq': 0, 'min_child_samples': 67, 'lambda_l1': 0.6148649911998307, 'lambda_l2': 2.1229877607275354, 'max_depth': 3, 'max_bin': 4054, 'min_data_in_leaf': 136, 'extra_trees': False, 'path_smooth': 0.6441908643136754}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:34,089] Trial 59 finished with value: 3.312496753994263e+17 and parameters: {'num_leaves': 56, 'learning_rate': 0.15321407241208257, 'feature_fraction': 0.6248911834579505, 'bagging_fraction': 0.8667669912707552, 'bagging_freq': 2, 'min_child_samples': 59, 'lambda_l1': 1.600169601417566, 'lambda_l2': 0.0010833203322648361, 'max_depth': 5, 'max_bin': 4359, 'min_data_in_leaf': 42, 'extra_trees': True, 'path_smooth': 0.4591249550759206}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:39,093] Trial 60 finished with value: 7.847531309907952e+16 and parameters: {'num_leaves': 224, 'learning_rate': 0.16450393729484056, 'feature_fraction': 0.641183334223138, 'bagging_fraction': 0.7968862816856992, 'bagging_freq': 1, 'min_child_samples': 43, 'lambda_l1': 3.2312014994783653, 'lambda_l2': 1.4690586397693695, 'max_depth': 4, 'max_bin': 4822, 'min_data_in_leaf': 152, 'extra_trees': False, 'path_smooth': 0.5157463957057142}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:45,004] Trial 61 finished with value: 38845.812577110606 and parameters: {'num_leaves': 72, 'learning_rate': 0.1776539553634855, 'feature_fraction': 0.6609457588575304, 'bagging_fraction': 0.817956683659451, 'bagging_freq': 1, 'min_child_samples': 50, 'lambda_l1': 4.406657819239725, 'lambda_l2': 3.6180176008633023, 'max_depth': 6, 'max_bin': 3700, 'min_data_in_leaf': 173, 'extra_trees': False, 'path_smooth': 0.7634802639023278}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:49,322] Trial 62 finished with value: 63093.00601444698 and parameters: {'num_leaves': 33, 'learning_rate': 0.1265140514581134, 'feature_fraction': 0.7436760566214378, 'bagging_fraction': 0.8427724206921585, 'bagging_freq': 3, 'min_child_samples': 55, 'lambda_l1': 1.887315970180557, 'lambda_l2': 0.08354983626114779, 'max_depth': 3, 'max_bin': 3207, 'min_data_in_leaf': 93, 'extra_trees': False, 'path_smooth': 0.6898922061610098}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:19:54,700] Trial 63 finished with value: 2.7066419597444634e+18 and parameters: {'num_leaves': 46, 'learning_rate': 0.15846423490479283, 'feature_fraction': 0.6081370032287875, 'bagging_fraction': 0.855567517997221, 'bagging_freq': 4, 'min_child_samples': 60, 'lambda_l1': 0.012426717176812437, 'lambda_l2': 2.2333239947539463, 'max_depth': 14, 'max_bin': 4449, 'min_data_in_leaf': 164, 'extra_trees': True, 'path_smooth': 0.4078382791203741}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:00,268] Trial 64 finished with value: 46814.20606606649 and parameters: {'num_leaves': 32, 'learning_rate': 0.1992477873001698, 'feature_fraction': 0.6876035121717567, 'bagging_fraction': 0.827934708444211, 'bagging_freq': 1, 'min_child_samples': 83, 'lambda_l1': 2.551234927633151, 'lambda_l2': 1.2692511970810894, 'max_depth': 5, 'max_bin': 5675, 'min_data_in_leaf': 125, 'extra_trees': False, 'path_smooth': 0.5415758471615635}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:03,968] Trial 65 finished with value: 35954.88181939266 and parameters: {'num_leaves': 23, 'learning_rate': 0.16911580339052035, 'feature_fraction': 0.6373743881994498, 'bagging_fraction': 0.8351926666334075, 'bagging_freq': 1, 'min_child_samples': 63, 'lambda_l1': 1.2610907414507093, 'lambda_l2': 1.0111941489911953, 'max_depth': 3, 'max_bin': 4101, 'min_data_in_leaf': 140, 'extra_trees': False, 'path_smooth': 0.5728220287708794}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:08,387] Trial 66 finished with value: 8.26260325878958e+16 and parameters: {'num_leaves': 41, 'learning_rate': 0.1482856962336173, 'feature_fraction': 0.6232072273687481, 'bagging_fraction': 0.8394551327624754, 'bagging_freq': 1, 'min_child_samples': 71, 'lambda_l1': 0.9273312469875994, 'lambda_l2': 0.6314665604371829, 'max_depth': 4, 'max_bin': 3793, 'min_data_in_leaf': 143, 'extra_trees': False, 'path_smooth': 0.6269065402496623}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:12,254] Trial 67 finished with value: 8387.371156285686 and parameters: {'num_leaves': 28, 'learning_rate': 0.13840904322274372, 'feature_fraction': 0.6550805887246102, 'bagging_fraction': 0.8646624485821524, 'bagging_freq': 1, 'min_child_samples': 66, 'lambda_l1': 0.43434945158525945, 'lambda_l2': 0.3333682230708524, 'max_depth': 3, 'max_bin': 4681, 'min_data_in_leaf': 150, 'extra_trees': False, 'path_smooth': 0.4860809798808434}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:16,807] Trial 68 finished with value: 5.183724709265941e+17 and parameters: {'num_leaves': 65, 'learning_rate': 0.135316527938789, 'feature_fraction': 0.6547418034821362, 'bagging_fraction': 0.8762430323046215, 'bagging_freq': 0, 'min_child_samples': 67, 'lambda_l1': 0.3701962710114967, 'lambda_l2': 0.3796690143430917, 'max_depth': 3, 'max_bin': 4683, 'min_data_in_leaf': 152, 'extra_trees': False, 'path_smooth': 0.43463803521137573}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:21,451] Trial 69 finished with value: 50969.66299113911 and parameters: {'num_leaves': 51, 'learning_rate': 0.12437167210112704, 'feature_fraction': 0.6704411379130701, 'bagging_fraction': 0.8646049426954953, 'bagging_freq': 1, 'min_child_samples': 56, 'lambda_l1': 0.6028079134634414, 'lambda_l2': 0.21975050091693016, 'max_depth': 4, 'max_bin': 3449, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.47218775655758766}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:28,619] Trial 70 finished with value: 4.256587092652528e+17 and parameters: {'num_leaves': 29, 'learning_rate': 0.13994548333127804, 'feature_fraction': 0.7988533798227945, 'bagging_fraction': 0.8915164438849752, 'bagging_freq': 2, 'min_child_samples': 65, 'lambda_l1': 1.5906363151587601, 'lambda_l2': 0.037366233166555754, 'max_depth': 6, 'max_bin': 4957, 'min_data_in_leaf': 178, 'extra_trees': False, 'path_smooth': 0.6618642036020321}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:33,997] Trial 71 finished with value: 280134.6769520988 and parameters: {'num_leaves': 40, 'learning_rate': 0.027634301332287198, 'feature_fraction': 0.6813291983804771, 'bagging_fraction': 0.9149983833318813, 'bagging_freq': 1, 'min_child_samples': 74, 'lambda_l1': 0.42198674556252014, 'lambda_l2': 0.7044905045677372, 'max_depth': 3, 'max_bin': 4375, 'min_data_in_leaf': 160, 'extra_trees': False, 'path_smooth': 0.5282438266764393}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:45,776] Trial 72 finished with value: 5.686465336102424e+18 and parameters: {'num_leaves': 56, 'learning_rate': 0.10924081550320336, 'feature_fraction': 0.7092168936360952, 'bagging_fraction': 0.8846050115912677, 'bagging_freq': 0, 'min_child_samples': 77, 'lambda_l1': 3.059050857279836, 'lambda_l2': 3.394077597747593, 'max_depth': 12, 'max_bin': 5261, 'min_data_in_leaf': 169, 'extra_trees': False, 'path_smooth': 0.5858755712397888}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:49,943] Trial 73 finished with value: 1.5237756805116957e+17 and parameters: {'num_leaves': 172, 'learning_rate': 0.14972522360533158, 'feature_fraction': 0.6059718392893124, 'bagging_fraction': 0.8468771564475702, 'bagging_freq': 1, 'min_child_samples': 61, 'lambda_l1': 0.7905221550724025, 'lambda_l2': 2.148640752365471, 'max_depth': 4, 'max_bin': 2542, 'min_data_in_leaf': 149, 'extra_trees': False, 'path_smooth': 0.4929809722698628}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:53,745] Trial 74 finished with value: 1.462334802555933e+18 and parameters: {'num_leaves': 79, 'learning_rate': 0.16005272770099394, 'feature_fraction': 0.6454891357284415, 'bagging_fraction': 0.8604833167580163, 'bagging_freq': 2, 'min_child_samples': 13, 'lambda_l1': 1.1291101496048561, 'lambda_l2': 0.12847020234455592, 'max_depth': 5, 'max_bin': 3985, 'min_data_in_leaf': 187, 'extra_trees': True, 'path_smooth': 0.6255712466354197}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:20:57,613] Trial 75 finished with value: 9856.096505367974 and parameters: {'num_leaves': 20, 'learning_rate': 0.14251080720160492, 'feature_fraction': 0.6342798578809813, 'bagging_fraction': 0.8260254662075383, 'bagging_freq': 1, 'min_child_samples': 69, 'lambda_l1': 2.150909841196228, 'lambda_l2': 1.3493322902900555, 'max_depth': 3, 'max_bin': 4189, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.5433118039715642}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:01,505] Trial 76 finished with value: 18844.01815182457 and parameters: {'num_leaves': 20, 'learning_rate': 0.09132130434047067, 'feature_fraction': 0.6215739970467318, 'bagging_fraction': 0.8265744806317352, 'bagging_freq': 1, 'min_child_samples': 69, 'lambda_l1': 2.138511233155751, 'lambda_l2': 0.46023765854891024, 'max_depth': 3, 'max_bin': 4608, 'min_data_in_leaf': 137, 'extra_trees': False, 'path_smooth': 0.3834132913023348}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:05,199] Trial 77 finished with value: 35427.17902215855 and parameters: {'num_leaves': 28, 'learning_rate': 0.13588215104226956, 'feature_fraction': 0.6366937351111244, 'bagging_fraction': 0.8159170698731092, 'bagging_freq': 1, 'min_child_samples': 65, 'lambda_l1': 4.028406356879785, 'lambda_l2': 1.3895230236452434, 'max_depth': 3, 'max_bin': 4226, 'min_data_in_leaf': 155, 'extra_trees': False, 'path_smooth': 0.5418253401196297}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:10,059] Trial 78 finished with value: 7.465100952077399e+17 and parameters: {'num_leaves': 38, 'learning_rate': 0.14346271910051792, 'feature_fraction': 0.6614837164862268, 'bagging_fraction': 0.8529982853739406, 'bagging_freq': 1, 'min_child_samples': 72, 'lambda_l1': 1.5121652130324, 'lambda_l2': 1.885905777717061, 'max_depth': 4, 'max_bin': 4831, 'min_data_in_leaf': 112, 'extra_trees': False, 'path_smooth': 0.4388911496386819}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:14,486] Trial 79 finished with value: 97812.9014255486 and parameters: {'num_leaves': 30, 'learning_rate': 0.15221196948032387, 'feature_fraction': 0.6511224580856279, 'bagging_fraction': 0.8428429632084302, 'bagging_freq': 1, 'min_child_samples': 58, 'lambda_l1': 1.9003567517418296, 'lambda_l2': 1.039880023112826, 'max_depth': 4, 'max_bin': 3808, 'min_data_in_leaf': 168, 'extra_trees': False, 'path_smooth': 0.4834342975793976}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:30,025] Trial 80 finished with value: 1.0943734117571938e+19 and parameters: {'num_leaves': 47, 'learning_rate': 0.1289368815239046, 'feature_fraction': 0.6280833656160265, 'bagging_fraction': 0.8014729510214675, 'bagging_freq': 0, 'min_child_samples': 54, 'lambda_l1': 0.5330373220695519, 'lambda_l2': 0.23626563976429854, 'max_depth': 13, 'max_bin': 4379, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.3116386242228534}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:33,867] Trial 81 finished with value: 9684.967015940992 and parameters: {'num_leaves': 62, 'learning_rate': 0.1689871810450408, 'feature_fraction': 0.6172597124630419, 'bagging_fraction': 0.8095182656361619, 'bagging_freq': 1, 'min_child_samples': 94, 'lambda_l1': 4.74362709300406, 'lambda_l2': 0.013700032596873406, 'max_depth': 3, 'max_bin': 4062, 'min_data_in_leaf': 123, 'extra_trees': False, 'path_smooth': 0.5868000089305967}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:37,644] Trial 82 finished with value: 2.7598908306713667e+17 and parameters: {'num_leaves': 58, 'learning_rate': 0.1891021434426749, 'feature_fraction': 0.6193219469021836, 'bagging_fraction': 0.7735391502656173, 'bagging_freq': 1, 'min_child_samples': 90, 'lambda_l1': 4.797366946573163, 'lambda_l2': 0.014018830949599832, 'max_depth': 3, 'max_bin': 7625, 'min_data_in_leaf': 123, 'extra_trees': False, 'path_smooth': 0.6013083338075236}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:47,916] Trial 83 finished with value: 7.639630159746469e+17 and parameters: {'num_leaves': 64, 'learning_rate': 0.17453884472904918, 'feature_fraction': 0.8338018508414726, 'bagging_fraction': 0.7854269450728615, 'bagging_freq': 2, 'min_child_samples': 94, 'lambda_l1': 0.2645545221091136, 'lambda_l2': 0.06079663899046506, 'max_depth': 11, 'max_bin': 3298, 'min_data_in_leaf': 133, 'extra_trees': False, 'path_smooth': 0.710954060163315}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:53,021] Trial 84 finished with value: 34091.59043270658 and parameters: {'num_leaves': 98, 'learning_rate': 0.16689022044024707, 'feature_fraction': 0.6080282188452336, 'bagging_fraction': 0.8103618887792359, 'bagging_freq': 1, 'min_child_samples': 83, 'lambda_l1': 0.11572715464152501, 'lambda_l2': 0.007592852212532235, 'max_depth': 5, 'max_bin': 3552, 'min_data_in_leaf': 129, 'extra_trees': False, 'path_smooth': 0.5638140241936176}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:21:56,843] Trial 85 finished with value: 22861.97659845377 and parameters: {'num_leaves': 26, 'learning_rate': 0.12040926501821023, 'feature_fraction': 0.636563614404964, 'bagging_fraction': 0.8213406103230266, 'bagging_freq': 1, 'min_child_samples': 65, 'lambda_l1': 3.3966975994259077, 'lambda_l2': 0.025332498557748846, 'max_depth': 3, 'max_bin': 4024, 'min_data_in_leaf': 161, 'extra_trees': False, 'path_smooth': 0.5256538326157719}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:22:01,642] Trial 86 finished with value: 76442.19352680632 and parameters: {'num_leaves': 38, 'learning_rate': 0.1572852814721679, 'feature_fraction': 0.6290454024499126, 'bagging_fraction': 0.8273096958847582, 'bagging_freq': 1, 'min_child_samples': 59, 'lambda_l1': 2.444041579853566, 'lambda_l2': 0.004644788243797416, 'max_depth': 4, 'max_bin': 4227, 'min_data_in_leaf': 148, 'extra_trees': False, 'path_smooth': 0.6753751043182644}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:22:05,513] Trial 87 finished with value: 13798.937044508224 and parameters: {'num_leaves': 47, 'learning_rate': 0.14489013054263783, 'feature_fraction': 0.6445753309492556, 'bagging_fraction': 0.832608612612719, 'bagging_freq': 1, 'min_child_samples': 62, 'lambda_l1': 2.8983120881314957, 'lambda_l2': 2.7379450080254073, 'max_depth': 3, 'max_bin': 4630, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.7646335885980411}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:22:28,487] Trial 88 finished with value: 2.4572262939309046e+17 and parameters: {'num_leaves': 50, 'learning_rate': 0.14501249024752452, 'feature_fraction': 0.6665517420667584, 'bagging_fraction': 0.900282426287813, 'bagging_freq': 1, 'min_child_samples': 62, 'lambda_l1': 3.7439087614869004, 'lambda_l2': 0.01623350119981378, 'max_depth': 16, 'max_bin': 4579, 'min_data_in_leaf': 11, 'extra_trees': False, 'path_smooth': 0.7603038983692421}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:22:32,555] Trial 89 finished with value: 42169.56219682749 and parameters: {'num_leaves': 68, 'learning_rate': 0.16100837972389248, 'feature_fraction': 0.646546366150344, 'bagging_fraction': 0.804435762520307, 'bagging_freq': 1, 'min_child_samples': 68, 'lambda_l1': 4.96534835339595, 'lambda_l2': 2.7904890957256336, 'max_depth': 3, 'max_bin': 4711, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.6465690281981106}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:22:37,457] Trial 90 finished with value: 2.798399846645595e+17 and parameters: {'num_leaves': 41, 'learning_rate': 0.17091587935202934, 'feature_fraction': 0.6561737901134332, 'bagging_fraction': 0.8383099552651719, 'bagging_freq': 0, 'min_child_samples': 80, 'lambda_l1': 1.0747251323480582, 'lambda_l2': 4.16853656019675, 'max_depth': 4, 'max_bin': 5036, 'min_data_in_leaf': 109, 'extra_trees': False, 'path_smooth': 0.8328190967811281}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:22:41,358] Trial 91 finished with value: 5672.672634907788 and parameters: {'num_leaves': 73, 'learning_rate': 0.1800038501765594, 'feature_fraction': 0.6133857647948568, 'bagging_fraction': 0.865395228158835, 'bagging_freq': 1, 'min_child_samples': 51, 'lambda_l1': 2.917659147990686, 'lambda_l2': 0.008751646485466709, 'max_depth': 3, 'max_bin': 4934, 'min_data_in_leaf': 119, 'extra_trees': False, 'path_smooth': 0.9508042967720671}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:01,816] Trial 92 finished with value: 2.3151905223642206e+19 and parameters: {'num_leaves': 74, 'learning_rate': 0.1813198973443209, 'feature_fraction': 0.6002792123271995, 'bagging_fraction': 0.8761239536626813, 'bagging_freq': 2, 'min_child_samples': 51, 'lambda_l1': 2.9560468236992796, 'lambda_l2': 0.00949407855506997, 'max_depth': 18, 'max_bin': 5412, 'min_data_in_leaf': 119, 'extra_trees': False, 'path_smooth': 0.8677313786032701}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:05,426] Trial 93 finished with value: 4.15909897763615e+17 and parameters: {'num_leaves': 83, 'learning_rate': 0.17616863777436229, 'feature_fraction': 0.6142798129052667, 'bagging_fraction': 0.8648929335645461, 'bagging_freq': 1, 'min_child_samples': 45, 'lambda_l1': 2.1115068906981063, 'lambda_l2': 0.00745090945822463, 'max_depth': 4, 'max_bin': 4950, 'min_data_in_leaf': 67, 'extra_trees': True, 'path_smooth': 0.985747510828097}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:09,667] Trial 94 finished with value: 30940.463045756664 and parameters: {'num_leaves': 120, 'learning_rate': 0.18564119843197846, 'feature_fraction': 0.7783980088925717, 'bagging_fraction': 0.8538004423420549, 'bagging_freq': 1, 'min_child_samples': 95, 'lambda_l1': 1.804170699378476, 'lambda_l2': 0.03025389102160977, 'max_depth': 3, 'max_bin': 5221, 'min_data_in_leaf': 123, 'extra_trees': False, 'path_smooth': 0.1741257004447796}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:13,470] Trial 95 finished with value: 10040.544554786782 and parameters: {'num_leaves': 54, 'learning_rate': 0.1532878463214997, 'feature_fraction': 0.6242847646982627, 'bagging_fraction': 0.8320479838138679, 'bagging_freq': 1, 'min_child_samples': 57, 'lambda_l1': 1.3832468008203984, 'lambda_l2': 2.4645624769927057, 'max_depth': 3, 'max_bin': 4471, 'min_data_in_leaf': 105, 'extra_trees': False, 'path_smooth': 0.9361393199205309}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:17,273] Trial 96 finished with value: 10011.494263522824 and parameters: {'num_leaves': 60, 'learning_rate': 0.15520023298491123, 'feature_fraction': 0.619462531327062, 'bagging_fraction': 0.8333028383811666, 'bagging_freq': 1, 'min_child_samples': 57, 'lambda_l1': 1.4135107489634886, 'lambda_l2': 0.0027113306147555204, 'max_depth': 3, 'max_bin': 4445, 'min_data_in_leaf': 99, 'extra_trees': False, 'path_smooth': 0.92777104690209}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:21,249] Trial 97 finished with value: 47524.62169319761 and parameters: {'num_leaves': 90, 'learning_rate': 0.16397728270742007, 'feature_fraction': 0.6108771561050804, 'bagging_fraction': 0.8344466517571845, 'bagging_freq': 1, 'min_child_samples': 57, 'lambda_l1': 1.3981758775022528, 'lambda_l2': 0.0017796524057503925, 'max_depth': 3, 'max_bin': 4098, 'min_data_in_leaf': 98, 'extra_trees': False, 'path_smooth': 0.9361561040872518}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:26,342] Trial 98 finished with value: 2.125764057508186e+17 and parameters: {'num_leaves': 59, 'learning_rate': 0.15423562635031007, 'feature_fraction': 0.6237021523527606, 'bagging_fraction': 0.8176210394701062, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.7467031649302022, 'lambda_l2': 0.0027243057043919074, 'max_depth': 4, 'max_bin': 4478, 'min_data_in_leaf': 89, 'extra_trees': False, 'path_smooth': 0.973480661033998}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:30,286] Trial 99 finished with value: 19823.821961682774 and parameters: {'num_leaves': 54, 'learning_rate': 0.17928337456418955, 'feature_fraction': 0.6414535242368187, 'bagging_fraction': 0.8112111387364132, 'bagging_freq': 1, 'min_child_samples': 51, 'lambda_l1': 2.4884644011426573, 'lambda_l2': 0.0035039713663388566, 'max_depth': 3, 'max_bin': 3905, 'min_data_in_leaf': 105, 'extra_trees': False, 'path_smooth': 0.9201215670838221}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:35,095] Trial 100 finished with value: 6.496210869009747e+17 and parameters: {'num_leaves': 70, 'learning_rate': 0.19535800485478733, 'feature_fraction': 0.615847471593688, 'bagging_fraction': 0.8423606156353797, 'bagging_freq': 0, 'min_child_samples': 53, 'lambda_l1': 0.9314747316974492, 'lambda_l2': 0.0021822734367824607, 'max_depth': 4, 'max_bin': 3746, 'min_data_in_leaf': 78, 'extra_trees': False, 'path_smooth': 0.9529397520459275}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:38,845] Trial 101 finished with value: 46498.59385499915 and parameters: {'num_leaves': 44, 'learning_rate': 0.1685837499178179, 'feature_fraction': 0.6041141151788743, 'bagging_fraction': 0.8308552107264889, 'bagging_freq': 1, 'min_child_samples': 55, 'lambda_l1': 1.5783306084536923, 'lambda_l2': 0.0017026689746102645, 'max_depth': 3, 'max_bin': 4680, 'min_data_in_leaf': 99, 'extra_trees': False, 'path_smooth': 0.835046240951396}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:44,506] Trial 102 finished with value: 1.9344188242814093e+17 and parameters: {'num_leaves': 77, 'learning_rate': 0.16204216288829992, 'feature_fraction': 0.6282605308949087, 'bagging_fraction': 0.8699567503368002, 'bagging_freq': 1, 'min_child_samples': 48, 'lambda_l1': 0.00327557496433425, 'lambda_l2': 0.09303036425451416, 'max_depth': 5, 'max_bin': 4180, 'min_data_in_leaf': 112, 'extra_trees': False, 'path_smooth': 0.896017243764209}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:48,333] Trial 103 finished with value: 9417.891083722985 and parameters: {'num_leaves': 106, 'learning_rate': 0.15604277664086388, 'feature_fraction': 0.6183984536773329, 'bagging_fraction': 0.7949018499824886, 'bagging_freq': 2, 'min_child_samples': 42, 'lambda_l1': 1.2698768005051064, 'lambda_l2': 0.0065486925059968235, 'max_depth': 3, 'max_bin': 4412, 'min_data_in_leaf': 117, 'extra_trees': False, 'path_smooth': 0.9507425717208934}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:52,983] Trial 104 finished with value: 5.5782086261984614e+17 and parameters: {'num_leaves': 92, 'learning_rate': 0.1558943548994319, 'feature_fraction': 0.6151265066810738, 'bagging_fraction': 0.7971639439106051, 'bagging_freq': 2, 'min_child_samples': 41, 'lambda_l1': 1.2615008585831462, 'lambda_l2': 0.007749262692195008, 'max_depth': 4, 'max_bin': 4405, 'min_data_in_leaf': 116, 'extra_trees': False, 'path_smooth': 0.9202237038346384}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:23:56,928] Trial 105 finished with value: 72969.9796864597 and parameters: {'num_leaves': 136, 'learning_rate': 0.14435816570050458, 'feature_fraction': 0.6222016312659517, 'bagging_fraction': 0.8239444103038274, 'bagging_freq': 1, 'min_child_samples': 34, 'lambda_l1': 1.0367846430065089, 'lambda_l2': 0.005426923882112579, 'max_depth': 3, 'max_bin': 4552, 'min_data_in_leaf': 102, 'extra_trees': False, 'path_smooth': 0.9630142618701291}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:00,987] Trial 106 finished with value: 11632.957970009937 and parameters: {'num_leaves': 113, 'learning_rate': 0.14933221686492962, 'feature_fraction': 0.6344371592801941, 'bagging_fraction': 0.7928017372417364, 'bagging_freq': 1, 'min_child_samples': 46, 'lambda_l1': 3.0213299241892955, 'lambda_l2': 0.0014613543855549935, 'max_depth': 3, 'max_bin': 4783, 'min_data_in_leaf': 134, 'extra_trees': False, 'path_smooth': 0.8587985051693909}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:04,947] Trial 107 finished with value: 2.7872893610226602e+17 and parameters: {'num_leaves': 161, 'learning_rate': 0.17431608575849328, 'feature_fraction': 0.6339236513893668, 'bagging_fraction': 0.7528267270324102, 'bagging_freq': 1, 'min_child_samples': 43, 'lambda_l1': 2.276709796042758, 'lambda_l2': 0.0012654286524590142, 'max_depth': 3, 'max_bin': 4877, 'min_data_in_leaf': 126, 'extra_trees': False, 'path_smooth': 0.9995168269263787}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:09,602] Trial 108 finished with value: 45667.18832749483 and parameters: {'num_leaves': 110, 'learning_rate': 0.15066125959220275, 'feature_fraction': 0.6076457806036776, 'bagging_fraction': 0.7948973157422536, 'bagging_freq': 3, 'min_child_samples': 49, 'lambda_l1': 1.8938351628234835, 'lambda_l2': 0.0014095735076065723, 'max_depth': 4, 'max_bin': 4300, 'min_data_in_leaf': 134, 'extra_trees': False, 'path_smooth': 0.904877097335508}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:14,474] Trial 109 finished with value: 3.888489047924079e+17 and parameters: {'num_leaves': 85, 'learning_rate': 0.07177650660761908, 'feature_fraction': 0.6175660643256687, 'bagging_fraction': 0.7879365563317307, 'bagging_freq': 2, 'min_child_samples': 38, 'lambda_l1': 4.073831256323083, 'lambda_l2': 0.009372224378444566, 'max_depth': 3, 'max_bin': 4767, 'min_data_in_leaf': 120, 'extra_trees': False, 'path_smooth': 0.8698849582108591}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:19,177] Trial 110 finished with value: 48260.73162029536 and parameters: {'num_leaves': 120, 'learning_rate': 0.13820499354473464, 'feature_fraction': 0.6269534085740696, 'bagging_fraction': 0.7754058770723359, 'bagging_freq': 1, 'min_child_samples': 46, 'lambda_l1': 1.3765212375740798, 'lambda_l2': 0.0027651026999403797, 'max_depth': 4, 'max_bin': 3891, 'min_data_in_leaf': 108, 'extra_trees': False, 'path_smooth': 0.949393261684263}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:22,178] Trial 111 finished with value: 3.2147527284349254e+17 and parameters: {'num_leaves': 103, 'learning_rate': 0.16091798001965815, 'feature_fraction': 0.6397844202378209, 'bagging_fraction': 0.807831586950804, 'bagging_freq': 1, 'min_child_samples': 29, 'lambda_l1': 0.671455498310218, 'lambda_l2': 0.003501718543547785, 'max_depth': 3, 'max_bin': 4103, 'min_data_in_leaf': 128, 'extra_trees': True, 'path_smooth': 0.8604022797942905}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:29,407] Trial 112 finished with value: 4.172711118210961e+17 and parameters: {'num_leaves': 134, 'learning_rate': 0.15723477807696656, 'feature_fraction': 0.8883435502448842, 'bagging_fraction': 0.8596433363188671, 'bagging_freq': 1, 'min_child_samples': 41, 'lambda_l1': 0.5093259603216558, 'lambda_l2': 0.006146088295808043, 'max_depth': 5, 'max_bin': 4471, 'min_data_in_leaf': 115, 'extra_trees': False, 'path_smooth': 0.9299605248600076}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:33,156] Trial 113 finished with value: 40285.160414613776 and parameters: {'num_leaves': 62, 'learning_rate': 0.16845498223221853, 'feature_fraction': 0.6486390414256434, 'bagging_fraction': 0.799754467710679, 'bagging_freq': 2, 'min_child_samples': 76, 'lambda_l1': 0.07741460293687483, 'lambda_l2': 0.021209115042911467, 'max_depth': 3, 'max_bin': 3606, 'min_data_in_leaf': 95, 'extra_trees': False, 'path_smooth': 0.9726138805009081}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:37,860] Trial 114 finished with value: 2.2630306773164467e+17 and parameters: {'num_leaves': 24, 'learning_rate': 0.1647757074131074, 'feature_fraction': 0.6329835058467042, 'bagging_fraction': 0.7635486441719997, 'bagging_freq': 1, 'min_child_samples': 47, 'lambda_l1': 1.7320971190395955, 'lambda_l2': 0.006298509105566617, 'max_depth': 4, 'max_bin': 3998, 'min_data_in_leaf': 103, 'extra_trees': False, 'path_smooth': 0.9016916024843347}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:41,624] Trial 115 finished with value: 10841.355238574644 and parameters: {'num_leaves': 48, 'learning_rate': 0.14178218932844883, 'feature_fraction': 0.6453600771141055, 'bagging_fraction': 0.8500301444059087, 'bagging_freq': 1, 'min_child_samples': 64, 'lambda_l1': 2.944273420003127, 'lambda_l2': 2.4405735186256603, 'max_depth': 3, 'max_bin': 4648, 'min_data_in_leaf': 141, 'extra_trees': False, 'path_smooth': 0.7799388340653604}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:45,335] Trial 116 finished with value: 9975.824357728163 and parameters: {'num_leaves': 51, 'learning_rate': 0.14780423627638098, 'feature_fraction': 0.6199833535158725, 'bagging_fraction': 0.8503040311413191, 'bagging_freq': 4, 'min_child_samples': 64, 'lambda_l1': 3.260356507717166, 'lambda_l2': 0.01264064198798736, 'max_depth': 3, 'max_bin': 5165, 'min_data_in_leaf': 142, 'extra_trees': False, 'path_smooth': 0.8078218998369904}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:24:49,162] Trial 117 finished with value: 28371.902813585115 and parameters: {'num_leaves': 69, 'learning_rate': 0.13490937540889122, 'feature_fraction': 0.6184368562433852, 'bagging_fraction': 0.844922273447149, 'bagging_freq': 4, 'min_child_samples': 66, 'lambda_l1': 3.5394122914957173, 'lambda_l2': 2.2796238374786064, 'max_depth': 3, 'max_bin': 5172, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.8132132659995858}. Best is trial 48 with value: 3740.627231059733.
# ...
# [I 2025-07-12 12:27:03,886] Trial 144 finished with value: 4.966330543131428e+17 and parameters: {'num_leaves': 55, 'learning_rate': 0.16181481111941465, 'feature_fraction': 0.6236906859222433, 'bagging_fraction': 0.8359541818130461, 'bagging_freq': 4, 'min_child_samples': 61, 'lambda_l1': 0.7157676571114041, 'lambda_l2': 0.023233478974345387, 'max_depth': 4, 'max_bin': 7445, 'min_data_in_leaf': 137, 'extra_trees': False, 'path_smooth': 0.5635722187252045}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:08,310] Trial 145 finished with value: 9811.093506160829 and parameters: {'num_leaves': 265, 'learning_rate': 0.14696780862438696, 'feature_fraction': 0.6316592889676584, 'bagging_fraction': 0.8303607088637578, 'bagging_freq': 4, 'min_child_samples': 98, 'lambda_l1': 1.3231557428501748, 'lambda_l2': 0.015424234241543282, 'max_depth': 3, 'max_bin': 5905, 'min_data_in_leaf': 107, 'extra_trees': False, 'path_smooth': 0.630177702560905}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:12,682] Trial 146 finished with value: 19807.19065097917 and parameters: {'num_leaves': 280, 'learning_rate': 0.17170801939408722, 'feature_fraction': 0.6303409958105363, 'bagging_fraction': 0.8318680567512251, 'bagging_freq': 4, 'min_child_samples': 97, 'lambda_l1': 1.190361434647863, 'lambda_l2': 0.019611820000718715, 'max_depth': 3, 'max_bin': 4263, 'min_data_in_leaf': 123, 'extra_trees': False, 'path_smooth': 0.6300984874455048}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:16,962] Trial 147 finished with value: 22007.039296335537 and parameters: {'num_leaves': 275, 'learning_rate': 0.14812491362767513, 'feature_fraction': 0.6107501473307217, 'bagging_fraction': 0.8255085094553887, 'bagging_freq': 3, 'min_child_samples': 95, 'lambda_l1': 0.8664614383915964, 'lambda_l2': 0.014980321283669629, 'max_depth': 3, 'max_bin': 6363, 'min_data_in_leaf': 110, 'extra_trees': False, 'path_smooth': 0.5743732044221694}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:21,173] Trial 148 finished with value: 7.801580012779836e+17 and parameters: {'num_leaves': 263, 'learning_rate': 0.15955746926257477, 'feature_fraction': 0.6173919148405381, 'bagging_fraction': 0.8312451109170127, 'bagging_freq': 4, 'min_child_samples': 92, 'lambda_l1': 1.590854424846949, 'lambda_l2': 0.010560649281391069, 'max_depth': 3, 'max_bin': 6320, 'min_data_in_leaf': 106, 'extra_trees': False, 'path_smooth': 0.6546099345607754}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:25,438] Trial 149 finished with value: 7516.3456705486315 and parameters: {'num_leaves': 262, 'learning_rate': 0.15227202234397966, 'feature_fraction': 0.6267014098929713, 'bagging_fraction': 0.8217119533944001, 'bagging_freq': 4, 'min_child_samples': 56, 'lambda_l1': 1.9980858285795566, 'lambda_l2': 0.02768496093738984, 'max_depth': 3, 'max_bin': 6588, 'min_data_in_leaf': 149, 'extra_trees': False, 'path_smooth': 0.5951773609673303}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:30,210] Trial 150 finished with value: 3.462240536741605e+17 and parameters: {'num_leaves': 255, 'learning_rate': 0.16550825420803558, 'feature_fraction': 0.6250711669262619, 'bagging_fraction': 0.8192834010657026, 'bagging_freq': 4, 'min_child_samples': 97, 'lambda_l1': 1.3126785264736511, 'lambda_l2': 0.03195263731491356, 'max_depth': 4, 'max_bin': 6597, 'min_data_in_leaf': 149, 'extra_trees': False, 'path_smooth': 0.6101434303996263}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:47,673] Trial 151 finished with value: 1.1047885044728525e+19 and parameters: {'num_leaves': 218, 'learning_rate': 0.1512051464341103, 'feature_fraction': 0.6048530766513516, 'bagging_fraction': 0.8141908603738722, 'bagging_freq': 4, 'min_child_samples': 99, 'lambda_l1': 2.049170244980103, 'lambda_l2': 0.019552501560202416, 'max_depth': 17, 'max_bin': 4040, 'min_data_in_leaf': 152, 'extra_trees': False, 'path_smooth': 0.5087496016843364}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:51,672] Trial 152 finished with value: 2.5337419648562376e+18 and parameters: {'num_leaves': 184, 'learning_rate': 0.18249103864798966, 'feature_fraction': 0.6323939959974383, 'bagging_fraction': 0.8399638910685909, 'bagging_freq': 4, 'min_child_samples': 90, 'lambda_l1': 1.10217129165462, 'lambda_l2': 0.029471175455166573, 'max_depth': 3, 'max_bin': 7065, 'min_data_in_leaf': 96, 'extra_trees': False, 'path_smooth': 0.6308279226937312}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:27:55,040] Trial 153 finished with value: 1.1206454952096674e+16 and parameters: {'num_leaves': 271, 'learning_rate': 0.15536961916500708, 'feature_fraction': 0.619617104672235, 'bagging_fraction': 0.8050181622108273, 'bagging_freq': 4, 'min_child_samples': 93, 'lambda_l1': 0.6230826273731658, 'lambda_l2': 0.02692356767612321, 'max_depth': 3, 'max_bin': 5973, 'min_data_in_leaf': 141, 'extra_trees': True, 'path_smooth': 0.6932529038847922}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:02,305] Trial 154 finished with value: 2.0934912651762032e+17 and parameters: {'num_leaves': 20, 'learning_rate': 0.17584698659278167, 'feature_fraction': 0.6389962131557969, 'bagging_fraction': 0.8221464487515846, 'bagging_freq': 4, 'min_child_samples': 100, 'lambda_l1': 0.9324595235496898, 'lambda_l2': 0.016680289494345087, 'max_depth': 8, 'max_bin': 6501, 'min_data_in_leaf': 156, 'extra_trees': False, 'path_smooth': 0.6030734835253047}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:06,708] Trial 155 finished with value: 17034.323646866455 and parameters: {'num_leaves': 262, 'learning_rate': 0.14645613560074922, 'feature_fraction': 0.6143162809706857, 'bagging_fraction': 0.8300062121129774, 'bagging_freq': 4, 'min_child_samples': 31, 'lambda_l1': 1.8393712507626159, 'lambda_l2': 0.011720692237639715, 'max_depth': 3, 'max_bin': 6654, 'min_data_in_leaf': 117, 'extra_trees': False, 'path_smooth': 0.5794762523081829}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:10,909] Trial 156 finished with value: 39584.51437297606 and parameters: {'num_leaves': 260, 'learning_rate': 0.1518380210928023, 'feature_fraction': 0.6296410677232767, 'bagging_fraction': 0.8364729053396734, 'bagging_freq': 3, 'min_child_samples': 55, 'lambda_l1': 1.4356609795136683, 'lambda_l2': 0.013254498420150447, 'max_depth': 3, 'max_bin': 6186, 'min_data_in_leaf': 103, 'extra_trees': False, 'path_smooth': 0.5431262465470639}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:15,136] Trial 157 finished with value: 7.801580012779634e+17 and parameters: {'num_leaves': 278, 'learning_rate': 0.1685315839232155, 'feature_fraction': 0.6244126972826872, 'bagging_fraction': 0.844474988010711, 'bagging_freq': 3, 'min_child_samples': 98, 'lambda_l1': 2.6019954420283744, 'lambda_l2': 4.867235458400275, 'max_depth': 3, 'max_bin': 6724, 'min_data_in_leaf': 127, 'extra_trees': False, 'path_smooth': 0.5543721044711443}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:19,507] Trial 158 finished with value: 22644.827729439163 and parameters: {'num_leaves': 296, 'learning_rate': 0.1575088925017051, 'feature_fraction': 0.6390450555785452, 'bagging_fraction': 0.8240730757361805, 'bagging_freq': 1, 'min_child_samples': 56, 'lambda_l1': 2.264458084465389, 'lambda_l2': 0.05508543332456395, 'max_depth': 3, 'max_bin': 5262, 'min_data_in_leaf': 146, 'extra_trees': False, 'path_smooth': 0.9401445137639696}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:24,371] Trial 159 finished with value: 1.7574194760389008e+17 and parameters: {'num_leaves': 40, 'learning_rate': 0.16336971828650998, 'feature_fraction': 0.7570102041093758, 'bagging_fraction': 0.8103633135332626, 'bagging_freq': 1, 'min_child_samples': 51, 'lambda_l1': 3.1706247347332446, 'lambda_l2': 0.06842274170432029, 'max_depth': 4, 'max_bin': 6472, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.5925522679195221}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:28,133] Trial 160 finished with value: 8582.989259611864 and parameters: {'num_leaves': 33, 'learning_rate': 0.1446649321973898, 'feature_fraction': 0.6210095355149575, 'bagging_fraction': 0.86123294139184, 'bagging_freq': 1, 'min_child_samples': 96, 'lambda_l1': 1.992406268783327, 'lambda_l2': 0.025550258346847647, 'max_depth': 3, 'max_bin': 6870, 'min_data_in_leaf': 161, 'extra_trees': False, 'path_smooth': 0.9663727006800801}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:32,806] Trial 161 finished with value: 4.3985200255591173e+18 and parameters: {'num_leaves': 32, 'learning_rate': 0.14630905587009707, 'feature_fraction': 0.6204239749820666, 'bagging_fraction': 0.8613612026593843, 'bagging_freq': 1, 'min_child_samples': 96, 'lambda_l1': 1.564610097395666, 'lambda_l2': 0.041701581306774524, 'max_depth': 4, 'max_bin': 6918, 'min_data_in_leaf': 162, 'extra_trees': False, 'path_smooth': 0.9532608841942253}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:36,694] Trial 162 finished with value: 12304.019531372362 and parameters: {'num_leaves': 26, 'learning_rate': 0.15390127303048043, 'feature_fraction': 0.6138312625078876, 'bagging_fraction': 0.8172487039550206, 'bagging_freq': 1, 'min_child_samples': 92, 'lambda_l1': 1.9059859111817, 'lambda_l2': 0.024587031484315788, 'max_depth': 3, 'max_bin': 6865, 'min_data_in_leaf': 138, 'extra_trees': False, 'path_smooth': 0.9185358869164034}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:41,028] Trial 163 finished with value: 48028.98310257936 and parameters: {'num_leaves': 36, 'learning_rate': 0.15981298190736043, 'feature_fraction': 0.6069016052898267, 'bagging_fraction': 0.873915245213387, 'bagging_freq': 4, 'min_child_samples': 88, 'lambda_l1': 1.1700443933045375, 'lambda_l2': 0.02167865805837946, 'max_depth': 4, 'max_bin': 7042, 'min_data_in_leaf': 159, 'extra_trees': False, 'path_smooth': 0.9965432374269722}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:44,854] Trial 164 finished with value: 4397.054224455308 and parameters: {'num_leaves': 60, 'learning_rate': 0.1391773873741533, 'feature_fraction': 0.6346454966041906, 'bagging_fraction': 0.8805725512330036, 'bagging_freq': 1, 'min_child_samples': 94, 'lambda_l1': 2.2021785280151507, 'lambda_l2': 0.01741492291290202, 'max_depth': 3, 'max_bin': 4161, 'min_data_in_leaf': 149, 'extra_trees': False, 'path_smooth': 0.9632655315457058}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:48,964] Trial 165 finished with value: 41220.71354849944 and parameters: {'num_leaves': 67, 'learning_rate': 0.1395514580905935, 'feature_fraction': 0.6346032599084788, 'bagging_fraction': 0.8788862245210164, 'bagging_freq': 1, 'min_child_samples': 95, 'lambda_l1': 2.082387510616561, 'lambda_l2': 0.018262392596129197, 'max_depth': 3, 'max_bin': 4169, 'min_data_in_leaf': 154, 'extra_trees': False, 'path_smooth': 0.9723405635099271}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:52,890] Trial 166 finished with value: 27285.135656664545 and parameters: {'num_leaves': 60, 'learning_rate': 0.14294690235437624, 'feature_fraction': 0.6276182981590356, 'bagging_fraction': 0.8857432320046087, 'bagging_freq': 1, 'min_child_samples': 85, 'lambda_l1': 1.4749898008201636, 'lambda_l2': 0.01613993023526788, 'max_depth': 3, 'max_bin': 3968, 'min_data_in_leaf': 150, 'extra_trees': False, 'path_smooth': 0.9356923533499071}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:28:56,682] Trial 167 finished with value: 21895.67129066377 and parameters: {'num_leaves': 51, 'learning_rate': 0.137259382746207, 'feature_fraction': 0.620900962679712, 'bagging_fraction': 0.8991706167826575, 'bagging_freq': 1, 'min_child_samples': 97, 'lambda_l1': 1.0099222507360346, 'lambda_l2': 0.003070341506736882, 'max_depth': 3, 'max_bin': 4432, 'min_data_in_leaf': 158, 'extra_trees': False, 'path_smooth': 0.9537517667058799}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:29:00,594] Trial 168 finished with value: 5900.01696199377 and parameters: {'num_leaves': 29, 'learning_rate': 0.1498177815396845, 'feature_fraction': 0.6423181795488799, 'bagging_fraction': 0.8684077463882849, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 1.795910691614691, 'lambda_l2': 0.013091369031300313, 'max_depth': 3, 'max_bin': 4303, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.9638862326927393}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:29:09,706] Trial 169 finished with value: 7.523585597460371e+17 and parameters: {'num_leaves': 45, 'learning_rate': 0.014381685739893804, 'feature_fraction': 0.6448253344201459, 'bagging_fraction': 0.8689627926316349, 'bagging_freq': 1, 'min_child_samples': 93, 'lambda_l1': 1.2877661728918046, 'lambda_l2': 0.013929828522225816, 'max_depth': 4, 'max_bin': 4238, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.9629198042130962}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:29:13,482] Trial 170 finished with value: 16784.766308639064 and parameters: {'num_leaves': 58, 'learning_rate': 0.14935547773665325, 'feature_fraction': 0.6481732785027287, 'bagging_fraction': 0.8814701097373854, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 1.742972109902765, 'lambda_l2': 0.026773068078705265, 'max_depth': 3, 'max_bin': 4761, 'min_data_in_leaf': 150, 'extra_trees': False, 'path_smooth': 0.9982941481465604}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:29:17,207] Trial 171 finished with value: 25233.714346323995 and parameters: {'num_leaves': 30, 'learning_rate': 0.1445109212421279, 'feature_fraction': 0.6388511394762795, 'bagging_fraction': 0.8598582051042023, 'bagging_freq': 1, 'min_child_samples': 99, 'lambda_l1': 2.2186714024943752, 'lambda_l2': 0.012689755751605828, 'max_depth': 3, 'max_bin': 4556, 'min_data_in_leaf': 163, 'extra_trees': False, 'path_smooth': 0.9028248908535955}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:29:22,309] Trial 172 finished with value: 77196.35277154465 and parameters: {'num_leaves': 41, 'learning_rate': 0.15154841900205268, 'feature_fraction': 0.6341484870871205, 'bagging_fraction': 0.8936229073010303, 'bagging_freq': 1, 'min_child_samples': 94, 'lambda_l1': 1.6902659409452607, 'lambda_l2': 0.009652589027106669, 'max_depth': 4, 'max_bin': 3731, 'min_data_in_leaf': 27, 'extra_trees': False, 'path_smooth': 0.9346884387357624}. Best is trial 48 with value: 3740.627231059733.
# [I 2025-07-12 12:29:26,311] Trial 173 finished with value: 14150.49442260858 and parameters: {'num_leaves': 65, 'learning_rate': 0.14748654080260437, 'feature_fraction': 0.6520881431544654, 'bagging_fraction': 0.8744864422293106, 'bagging_freq': 1, 'min_child_samples': 91, 'lambda_l1': 0.7645159127867384, 'lambda_l2': 0.017805601215444933, 'max_depth': 3, 'max_bin': 4066, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.8851278349906733}. Best is trial 48 with value: 3740.627231059733.
# Mejores hiperparámetros encontrados:
# {'num_leaves': 20, 'learning_rate': 0.17289029562957425, 'feature_fraction': 0.6721899009448079, 'bagging_fraction': 0.8720561001042189, 'bagging_freq': 1, 'min_child_samples': 77, 'lambda_l1': 0.962607079692408, 'lambda_l2': 2.6434752121023406, 'max_depth': 3, 'max_bin': 3791, 'min_data_in_leaf': 151, 'extra_trees': False, 'path_smooth': 0.688890726841421}
# Mejor MAE: 3740.6272

# %%
best_params = study.best_params.copy()
best_params.update({
    # "linear_tree": True,
    "objective": "regression",
    "metric": ["rmse", "mape"],
    "verbosity": -1,
    "n_jobs": -1,
    "seed": 42
})

model = lgb.train(
    best_params,
    lgb.Dataset(X_train, label=y_train),
    valid_sets=[lgb.Dataset(X_val, label=y_val)],
    num_boost_round=1000,
    callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
)

# Asegurar las mismas columnas
X_kgl = df_kgl[X_train.columns]  # Misma estructura

# === 9. Hacer predicción sobre nuevos datos ===
preds_kgl = model.predict(X_kgl)

# %%
result = pd.DataFrame({"product_id": X_kgl["product_id"],  "tn": preds_kgl})

result = result[result["product_id"].isin(productos_ok["product_id"])]

result
# Out:
#        product_id           tn
# 35          20001  1348.685697
# 71          20002  1209.575811
# 107         20003   856.620571
# 143         20004   580.901028
# 179         20005   484.833795
# ...           ...          ...
# 22358       20962     3.765231
# 22362       20975     3.765231
# 22366       20995     3.765231
# 22370       21087     3.275076
# 22374       21214     3.275076
#
# [780 rows x 2 columns]

# %%
result.to_csv(f"{study_name}.csv",sep=',', index=False)

# %%
import matplotlib.pyplot as plt
from lightgbm import plot_importance  # Importación específica
# Visualizar importancia de características
plot_importance(model, importance_type='gain', max_num_features=10)  # Usar la función importada
plt.show()

# %%
import webbrowser
webbrowser.open("https://www.soundhelix.com/examples/mp3/SoundHelix-Song-3.mp3")
# Out:
# True
