# %%
study_name = "lightgbm10_3"

# %%
import pandas as pd
import gc
import numpy as np
from sklearn.preprocessing import LabelEncoder
from scipy.stats import linregress
from scipy.stats import mode


sellin = pd.read_csv("../datasets/sell-in.txt.gz", sep="\t")
productos = pd.read_csv("../datasets/tb_productos.txt", sep="\t")
productos = productos.drop_duplicates(subset=["product_id"],keep="first")  # Eliminar duplicados por si acaso
stocks = pd.read_csv("../datasets/tb_stocks.txt", sep="\t")

productos_ok = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/product_id_apredecir201912.txt", sep="\t")



df = sellin[sellin["product_id"].isin(productos_ok["product_id"])]
df = df.groupby(by=["periodo","product_id"]).agg({
    "tn":"sum",
    "plan_precios_cuidados":"first",
    "customer_id":"nunique",
    }).reset_index()


productos_list = df['product_id'].unique()
periodos = df['periodo'].unique()
idx = pd.MultiIndex.from_product([productos_list, periodos], names=['product_id', 'periodo'])
completo = idx.to_frame(index=False)
# 4 filtrar combinaciones periodo_producto
completo = completo.merge(df, on=['periodo', 'product_id'], how='left')
nacimiento_producto = df.groupby('product_id')['periodo'].min().rename('nacimiento_producto')

completo = completo.merge(nacimiento_producto, on='product_id', how='left')
completo = completo[completo['periodo'] >= completo['nacimiento_producto']]



df = pd.merge(completo, productos, how="left", on="product_id")
df = df.merge(stocks, how="left", on=["product_id", "periodo"])

df["periodo_dt"] = pd.to_datetime(df["periodo"], format="%Y%m")

df["mes"] = df["periodo_dt"].dt.month
df["year"] = df["periodo_dt"].dt.year
df["quarter"] = df["periodo_dt"].dt.quarter
df["season"] = df["periodo_dt"].dt.month % 12 // 3 + 1



# totales por cat1 por periodo
df["cat1_total"] = df.groupby(["periodo", "cat1"])["tn"].transform("sum")
df["cat1_mean"] = df.groupby(["periodo", "cat1"])["tn"].transform("mean")
df["cat1_mean_12"] = df.groupby(["periodo", "cat1"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat1_customers"] = df.groupby(["periodo", "cat1"])["customer_id"].transform("nunique")
# totales por cat2 por periodo
df["cat2_total"] = df.groupby(["periodo", "cat2"])["tn"].transform("sum")
df["cat2_mean"] = df.groupby(["periodo", "cat2"])["tn"].transform("mean")
df["cat2_mean_12"] = df.groupby(["periodo", "cat2"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat2_customers"] = df.groupby(["periodo", "cat2"])["customer_id"].transform("nunique")
# totales por cat3 por periodo
df["cat3_total"] = df.groupby(["periodo", "cat3"])["tn"].transform("sum")
df["cat3_mean"] = df.groupby(["periodo", "cat3"])["tn"].transform("mean")
df["cat3_mean_12"] = df.groupby(["periodo", "cat3"])["tn"].transform(lambda x: x.rolling(12).mean())
df["cat3_customers"] = df.groupby(["periodo", "cat3"])["customer_id"].transform("nunique")


# shift t-1 a t12
meses = ["tn"]
for i in range(1, 13):
    df[f"tn_t{i}"] = df.groupby("product_id")["tn"].shift(i)
    df[f"delta_t{i}"] = df[f"tn"] / df[f"tn_t{i}"]
    meses.append(f"tn_t{i}")
    df[f"cat1_t{i}"] = df.groupby("product_id")["cat1_total"].shift(i)
    df[f"cat2_t{i}"] = df.groupby("product_id")["cat2_total"].shift(i)
    df[f"cat3_t{i}"] = df.groupby("product_id")["cat3_total"].shift(i)
    df[f"customer_id_t{i}"] = df.groupby("product_id")["customer_id"].shift(i)
  
df["i_tn_t12"] = df["tn"] / df["tn_t12"]
df["i_tn_t6"] = df["tn"] / df["tn_t6"]
df["i_tn_t3"] = df["tn"] / df["tn_t3"]
df["i_tn_customers"] = df["tn"] / df["customer_id"]


df["promedio_t12"] = df[meses].mean(axis=1)
df["promedio_t6"] = df[meses[:6]].mean(axis=1)
df["promedio_t3"] = df[meses[:3]].mean(axis=1)

df["mediana_t12"] = df[meses].median(axis=1)
df["mediana_t6"] = df[meses[:6]].median(axis=1)
df["mediana_t3"] = df[meses[:3]].median(axis=1)

df["maximo_t12"] = df[meses].max(axis=1)
df["maximo_t6"] = df[meses[:6]].max(axis=1)
df["maximo_t3"] = df[meses[:3]].max(axis=1)

df["minimo_t12"] = df[meses].min(axis=1)
df["minimo_t6"] = df[meses[:6]].min(axis=1)
df["minimo_t3"] = df[meses[:3]].min(axis=1)

# Función para calcular la pendiente de una serie temporal
def calcular_pendiente(serie):
    datos = serie.dropna().values
    if len(datos) < 2:  # Mínimo 2 puntos para una regresión
        return np.nan
    x = np.arange(len(datos))  # [0, 1, 2, ..., n-1] (representa el tiempo)
    slope, _, _, _, _ = linregress(x, datos)
    return slope

# Aplicamos la función por grupo (producto) y reindexamos para alinear con df
df["pendiente_reg_12"] = (
    df.groupby("product_id")[meses]
    .apply(lambda grupo: grupo.apply(calcular_pendiente, axis=1))
    .reset_index(level=0, drop=True)  # Eliminamos el nivel de grupo para alinear índices
)
df["pendiente_reg_6"] = (
    df.groupby("product_id")[meses[:6]]
    .apply(lambda grupo: grupo.apply(calcular_pendiente, axis=1))
    .reset_index(level=0, drop=True)  # Eliminamos el nivel de grupo para alinear índices
)
df["pendiente_reg_3"] = (
    df.groupby("product_id")[meses[:3]]
    .apply(lambda grupo: grupo.apply(calcular_pendiente, axis=1))
    .reset_index(level=0, drop=True)  # Eliminamos el nivel de grupo para alinear índices
)


df['media_movil_3m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(3).mean())
df['media_movil_6m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(6).mean())
df['media_movil_12m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(12).mean())
df['diff_media_3_6'] = df['media_movil_3m'] - df['media_movil_6m']
df['diff_media_6_12'] = df['media_movil_6m'] - df['media_movil_12m']
df['diff_media_3_12'] = df['media_movil_3m'] - df['media_movil_12m']
df["diff_tn_mm3"] = df["tn"] - df['media_movil_3m']
df["diff_tn_mm6"] = df["tn"] - df['media_movil_6m']
df["diff_tn_mm12"] = df["tn"] - df['media_movil_12m']
df["i_tn_mm3"] = df["tn"] / df['media_movil_3m']
df["i_tn_mm6"] = df["tn"] / df['media_movil_6m']
df["i_tn_mm12"] = df["tn"] / df['media_movil_12m']


def rolling_mode(x):
    return x.shift(1).rolling(6, min_periods=1).apply(lambda x: mode(x, keepdims=True)[0][0], raw=False)
#Moda o patrón de cantidad
df['modo_6m'] = df.groupby(['product_id'])['tn'].transform(rolling_mode)
df['modo_diff'] = df['tn'] - df['modo_6m']


# Crear columna con el id del cliente que más compró en cada periodo-producto
cliente_max_tn = sellin.groupby(['periodo', 'product_id', 'customer_id'])['tn'].sum().reset_index()
idx_max_cliente = cliente_max_tn.loc[cliente_max_tn.groupby(['periodo', 'product_id'])['tn'].idxmax()][['periodo', 'product_id', 'customer_id']]
idx_max_cliente = idx_max_cliente.rename(columns={'customer_id': 'max_cliente_id'})
df = df.merge(idx_max_cliente, on=['periodo', 'product_id'], how='left')


# target t+2
df["target"] = df.groupby("product_id")["tn"].shift(-2)


cat_cols = ['cat1', 'cat2', 'cat3', 'brand', 'plan_precios_cuidados']
for col in cat_cols:
    if col in df.columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
        
del completo, productos, stocks
gc.collect()
df
# Out:
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["mediana_t12"] = df[meses].median(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["mediana_t6"] = df[meses[:6]].median(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["mediana_t3"] = df[meses[:3]].median(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:93: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["maximo_t12"] = df[meses].max(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["maximo_t6"] = df[meses[:6]].max(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:95: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["maximo_t3"] = df[meses[:3]].max(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["minimo_t12"] = df[meses].min(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:98: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["minimo_t6"] = df[meses[:6]].min(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:99: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["minimo_t3"] = df[meses[:3]].min(axis=1)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["pendiente_reg_12"] = (
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:116: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["pendiente_reg_6"] = (
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["pendiente_reg_3"] = (
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:128: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['media_movil_3m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(3).mean())
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:129: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['media_movil_6m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(6).mean())
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['media_movil_12m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(12).mean())
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:131: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['diff_media_3_6'] = df['media_movil_3m'] - df['media_movil_6m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:132: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['diff_media_6_12'] = df['media_movil_6m'] - df['media_movil_12m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['diff_media_3_12'] = df['media_movil_3m'] - df['media_movil_12m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["diff_tn_mm3"] = df["tn"] - df['media_movil_3m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:135: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["diff_tn_mm6"] = df["tn"] - df['media_movil_6m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:136: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["diff_tn_mm12"] = df["tn"] - df['media_movil_12m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:137: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["i_tn_mm3"] = df["tn"] / df['media_movil_3m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["i_tn_mm6"] = df["tn"] / df['media_movil_6m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["i_tn_mm12"] = df["tn"] / df['media_movil_12m']
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:145: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['modo_6m'] = df.groupby(['product_id'])['tn'].transform(rolling_mode)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\368844546.py:146: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['modo_diff'] = df['tn'] - df['modo_6m']
#        product_id  periodo          tn  plan_precios_cuidados  customer_id  \
# 0           20001   201701   934.77222                      0        186.0
# 1           20001   201702   798.01620                      0        185.0
# 2           20001   201703  1303.35771                      0        188.0
# 3           20001   201704  1069.96130                      0        104.0
# 4           20001   201705  1502.20132                      0        238.0
# ...           ...      ...         ...                    ...          ...
# 22370       21087   201912     1.02205                      0         51.0
# 22371       21214   201909     0.34250                      0          2.0
# 22372       21214   201910     0.21735                      0         38.0
# 22373       21214   201911     0.84012                      0         43.0
# 22374       21214   201912     0.24428                      0         37.0
#
#        nacimiento_producto  cat1  cat2  cat3  brand  ...  diff_tn_mm3  \
# 0                   201701     1    10    47      0  ...          NaN
# 1                   201701     1    10    47      0  ...          NaN
# 2                   201701     1    10    47      0  ...   291.309000
# 3                   201701     1    10    47      0  ...    12.849563
# 4                   201701     1    10    47      0  ...   210.361210
# ...                    ...   ...   ...   ...    ...  ...          ...
# 22370               201909     2     3     3     23  ...    -0.087857
# 22371               201909     2     3    65     23  ...          NaN
# 22372               201909     2     3    65     23  ...          NaN
# 22373               201909     2     3    65     23  ...     0.373463
# 22374               201909     2     3    65     23  ...    -0.189637
#
#        diff_tn_mm6 diff_tn_mm12  i_tn_mm3  i_tn_mm6  i_tn_mm12    modo_6m  \
# 0              NaN          NaN       NaN       NaN        NaN        NaN
# 1              NaN          NaN       NaN       NaN        NaN  934.77222
# 2              NaN          NaN  1.287841       NaN        NaN  798.01620
# 3              NaN          NaN  1.012155       NaN        NaN  798.01620
# 4              NaN          NaN  1.162838       NaN        NaN  798.01620
# ...            ...          ...       ...       ...        ...        ...
# 22370          NaN          NaN  0.920843       NaN        NaN    0.29997
# 22371          NaN          NaN       NaN       NaN        NaN        NaN
# 22372          NaN          NaN       NaN       NaN        NaN    0.34250
# 22373          NaN          NaN  1.800296       NaN        NaN    0.21735
# 22374          NaN          NaN  0.562965       NaN        NaN    0.21735
#
#        modo_diff  max_cliente_id      target
# 0            NaN         10004.0  1303.35771
# 1     -136.75602         10001.0  1069.96130
# 2      505.34151         10004.0  1502.20132
# 3      271.94510         10012.0  1520.06539
# 4      704.18512         10007.0  1030.67391
# ...          ...             ...         ...
# 22370    0.72208         10052.0         NaN
# 22371        NaN         10052.0     0.84012
# 22372   -0.12515         10052.0     0.24428
# 22373    0.62277         10007.0         NaN
# 22374    0.02693         10029.0         NaN
#
# [22375 rows x 136 columns]

# %%
df_kgl = df[df["periodo_dt"] == "2019-12-01"]
df_kgl["periodo_dt"] = df_kgl["periodo_dt"].astype(int)
df = df[~df["periodo_dt"].isin(["2019-11-01", "2019-12-01"])]
# Out:
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\3178732104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kgl["periodo_dt"] = df_kgl["periodo_dt"].astype(int)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\3178732104.py:3: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df = df[~df["periodo_dt"].isin(["2019-11-01", "2019-12-01"])]

# %%
# Separar features y target
X = df.drop(columns=["target"])
y = df["target"]
X_train = X[X["periodo_dt"] < '2019-10-01']
X_train["periodo_dt"] = X_train["periodo_dt"].astype(int)
y_train = y[X["periodo_dt"] < '2019-10-01']

X_val = X[X["periodo_dt"] == '2019-10-01']
X_val["periodo_dt"] = X_val["periodo_dt"].astype(int)
y_val = y[X["periodo_dt"] == '2019-10-01']
# Out:
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\73950357.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["periodo_dt"] = X_train["periodo_dt"].astype(int)
# C:\Users\carre\AppData\Local\Temp\ipykernel_10712\73950357.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_val["periodo_dt"] = X_val["periodo_dt"].astype(int)

# %%
import lightgbm as lgb
import optuna
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os

def custom_mape_loss(y_true, y_pred):
    numerator = np.sum(np.abs(y_true - y_pred))
    denominator = np.sum(np.abs(y_true))
    epsilon = np.finfo(float).eps  # Valor muy pequeño para evitar división por cero
    return numerator / (denominator + epsilon)

# === 2. Definición del objetivo para Optuna ===
def objective(trial):
    params = {
        "sample_weight": X_train["tn"].to_list(),
        "objective": "regression",
        "metric": ["rmse", "mape"],
        "boosting_type": "gbdt",
        "verbosity": -1,
        "n_jobs": -1,
        "seed": 42,
        "num_leaves": trial.suggest_int("num_leaves", 20, 200),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.2),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 0.9),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.7, 0.95),
        "bagging_freq": trial.suggest_int("bagging_freq", 0, 5),
        "min_child_samples": trial.suggest_int("min_child_samples", 10, 100),
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-3, 5.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-3, 5.0, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 18),
        "max_bin": trial.suggest_int("max_bin", 10, 8000),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 200),
        "extra_trees": trial.suggest_categorical("extra_trees", [True, False]),
        "path_smooth": trial.suggest_float("path_smooth", 0, 1),  # Nuevo parámetro útil
    }

    model = lgb.train(
        params,
        lgb.Dataset(X_train, label=y_train),
        valid_sets=[lgb.Dataset(X_val, label=y_val)],
        num_boost_round=1000,
        callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)]
    )

    preds = model.predict(X_val)
    
    
    
    mape = custom_mape_loss(y_val, preds)
    # rmse = mean_squared_error(y_val, preds)
    # rmse = np.sqrt(rmse)
    
    #rmse = mean_squared_error(y_val, preds, squared=False)
    return mape

# === 3. Configurar almacenamiento SQLite para Optuna ===
os.makedirs("optuna_storage", exist_ok=True)
DB_PATH = "optuna_storage/optuna.db"
STUDY_NAME = study_name
storage_url = f"sqlite:///{DB_PATH}"

# === 4. Crear o cargar estudio ===
study = optuna.create_study(
    study_name=STUDY_NAME,
    storage=storage_url,
    direction="minimize",
    load_if_exists=True
)

# === 5. Ejecutar optimización ===
study.optimize(objective, n_trials=1000)

# === 6. Mostrar resultados ===
print("Mejores hiperparámetros encontrados:")
print(study.best_params)
print(f"Mejor MAE: {study.best_value:.4f}")
# Out:
# [I 2025-07-12 13:20:33,997] A new study created in RDB with name: lightgbm10_3
# [I 2025-07-12 13:20:40,061] Trial 0 finished with value: 0.267978016139524 and parameters: {'num_leaves': 99, 'learning_rate': 0.1766578670562598, 'feature_fraction': 0.8529288556676591, 'bagging_fraction': 0.9133166437043206, 'bagging_freq': 2, 'min_child_samples': 74, 'lambda_l1': 0.07932502872660434, 'lambda_l2': 0.0030417575919859077, 'max_depth': 5, 'max_bin': 4197, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.0891109362923217}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:20:48,460] Trial 1 finished with value: 0.2715643042285548 and parameters: {'num_leaves': 149, 'learning_rate': 0.10826173695029903, 'feature_fraction': 0.6052646444660272, 'bagging_fraction': 0.7503097821127366, 'bagging_freq': 0, 'min_child_samples': 34, 'lambda_l1': 0.015230805525936855, 'lambda_l2': 0.6725384801176336, 'max_depth': 18, 'max_bin': 1151, 'min_data_in_leaf': 95, 'extra_trees': False, 'path_smooth': 0.3254902811263799}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:20:50,712] Trial 2 finished with value: 0.2985895748336125 and parameters: {'num_leaves': 48, 'learning_rate': 0.03736819972256522, 'feature_fraction': 0.8369656808691011, 'bagging_fraction': 0.7051101752315933, 'bagging_freq': 5, 'min_child_samples': 11, 'lambda_l1': 0.12488681022553227, 'lambda_l2': 0.04500638114431427, 'max_depth': 3, 'max_bin': 55, 'min_data_in_leaf': 133, 'extra_trees': True, 'path_smooth': 0.11144183821308651}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:21:40,172] Trial 3 finished with value: 0.27497650299655924 and parameters: {'num_leaves': 45, 'learning_rate': 0.025806304951784632, 'feature_fraction': 0.7179162794945793, 'bagging_fraction': 0.7582822585520793, 'bagging_freq': 1, 'min_child_samples': 91, 'lambda_l1': 0.058192731418327454, 'lambda_l2': 0.03933899103133837, 'max_depth': 14, 'max_bin': 7771, 'min_data_in_leaf': 138, 'extra_trees': False, 'path_smooth': 0.6702695089941916}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:21:58,563] Trial 4 finished with value: 0.29457079084161436 and parameters: {'num_leaves': 158, 'learning_rate': 0.048293412276615814, 'feature_fraction': 0.8273327606117753, 'bagging_fraction': 0.7067758179563592, 'bagging_freq': 0, 'min_child_samples': 52, 'lambda_l1': 0.0038018801385014565, 'lambda_l2': 1.5074352394163502, 'max_depth': 8, 'max_bin': 5250, 'min_data_in_leaf': 19, 'extra_trees': False, 'path_smooth': 0.2044698318209608}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:22:32,660] Trial 5 finished with value: 0.2807764173102587 and parameters: {'num_leaves': 182, 'learning_rate': 0.010496712208133793, 'feature_fraction': 0.7144660227354083, 'bagging_fraction': 0.9158132895431851, 'bagging_freq': 4, 'min_child_samples': 37, 'lambda_l1': 0.05722166915909094, 'lambda_l2': 0.020133450471965873, 'max_depth': 15, 'max_bin': 7670, 'min_data_in_leaf': 142, 'extra_trees': True, 'path_smooth': 0.1260690389029825}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:22:39,421] Trial 6 finished with value: 0.2742401890534994 and parameters: {'num_leaves': 102, 'learning_rate': 0.10945735199694914, 'feature_fraction': 0.6293951806941948, 'bagging_fraction': 0.7925948452446869, 'bagging_freq': 5, 'min_child_samples': 80, 'lambda_l1': 0.5361702581764796, 'lambda_l2': 0.0237218946012476, 'max_depth': 7, 'max_bin': 4553, 'min_data_in_leaf': 191, 'extra_trees': False, 'path_smooth': 0.34351537875744254}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:23:05,103] Trial 7 finished with value: 0.27701979467973303 and parameters: {'num_leaves': 24, 'learning_rate': 0.10544985269089374, 'feature_fraction': 0.8441832660897968, 'bagging_fraction': 0.7914749659659611, 'bagging_freq': 3, 'min_child_samples': 83, 'lambda_l1': 0.01501458737428557, 'lambda_l2': 1.1904914887901799, 'max_depth': 18, 'max_bin': 7984, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.5945523646972087}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:23:44,109] Trial 8 finished with value: 0.2844982434291337 and parameters: {'num_leaves': 142, 'learning_rate': 0.0475595011521255, 'feature_fraction': 0.8197955053214029, 'bagging_fraction': 0.7528315084306404, 'bagging_freq': 2, 'min_child_samples': 60, 'lambda_l1': 0.011579971709477829, 'lambda_l2': 0.021326518423584566, 'max_depth': 14, 'max_bin': 5258, 'min_data_in_leaf': 179, 'extra_trees': False, 'path_smooth': 0.3121382072076332}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:23:56,504] Trial 9 finished with value: 0.2968946257037049 and parameters: {'num_leaves': 39, 'learning_rate': 0.025432577173132815, 'feature_fraction': 0.7488069064735104, 'bagging_fraction': 0.7274982151239643, 'bagging_freq': 5, 'min_child_samples': 30, 'lambda_l1': 0.41528088221315423, 'lambda_l2': 0.14088974701797236, 'max_depth': 14, 'max_bin': 5199, 'min_data_in_leaf': 134, 'extra_trees': True, 'path_smooth': 0.8470847845722342}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:23:59,066] Trial 10 finished with value: 0.2857985001821121 and parameters: {'num_leaves': 85, 'learning_rate': 0.19821793296012946, 'feature_fraction': 0.8969284128673572, 'bagging_fraction': 0.9134207411298503, 'bagging_freq': 2, 'min_child_samples': 68, 'lambda_l1': 1.709138529234653, 'lambda_l2': 0.0011237465235941506, 'max_depth': 3, 'max_bin': 2676, 'min_data_in_leaf': 73, 'extra_trees': True, 'path_smooth': 0.012885648052184714}. Best is trial 0 with value: 0.267978016139524.
# [I 2025-07-12 13:24:05,716] Trial 11 finished with value: 0.2575634019652293 and parameters: {'num_leaves': 131, 'learning_rate': 0.16727616900030132, 'feature_fraction': 0.618766304606726, 'bagging_fraction': 0.8806878012401868, 'bagging_freq': 0, 'min_child_samples': 42, 'lambda_l1': 0.0016146102088576298, 'lambda_l2': 0.0011982469430457125, 'max_depth': 9, 'max_bin': 2673, 'min_data_in_leaf': 84, 'extra_trees': False, 'path_smooth': 0.40953552639405844}. Best is trial 11 with value: 0.2575634019652293.
# [I 2025-07-12 13:24:09,927] Trial 12 finished with value: 0.31463653278421666 and parameters: {'num_leaves': 118, 'learning_rate': 0.1880859189606518, 'feature_fraction': 0.6836216219550766, 'bagging_fraction': 0.8700636719318515, 'bagging_freq': 1, 'min_child_samples': 100, 'lambda_l1': 0.001416733665836157, 'lambda_l2': 0.00124699053479315, 'max_depth': 7, 'max_bin': 2909, 'min_data_in_leaf': 71, 'extra_trees': False, 'path_smooth': 0.4681254506333586}. Best is trial 11 with value: 0.2575634019652293.
# [I 2025-07-12 13:24:15,538] Trial 13 finished with value: 0.31570366001736344 and parameters: {'num_leaves': 76, 'learning_rate': 0.1527269378658457, 'feature_fraction': 0.6568403154232691, 'bagging_fraction': 0.8629419050144689, 'bagging_freq': 1, 'min_child_samples': 48, 'lambda_l1': 0.0013052902894431012, 'lambda_l2': 0.0045766115960504975, 'max_depth': 9, 'max_bin': 2922, 'min_data_in_leaf': 36, 'extra_trees': False, 'path_smooth': 0.9397558351808681}. Best is trial 11 with value: 0.2575634019652293.
# [I 2025-07-12 13:24:22,515] Trial 14 finished with value: 0.2610250715705661 and parameters: {'num_leaves': 121, 'learning_rate': 0.15345822306627716, 'feature_fraction': 0.7765151083422902, 'bagging_fraction': 0.946088592290169, 'bagging_freq': 3, 'min_child_samples': 69, 'lambda_l1': 0.18607440555330007, 'lambda_l2': 0.004667418913086619, 'max_depth': 5, 'max_bin': 3753, 'min_data_in_leaf': 99, 'extra_trees': False, 'path_smooth': 0.4829137932882166}. Best is trial 11 with value: 0.2575634019652293.
# [I 2025-07-12 13:24:29,383] Trial 15 finished with value: 0.2627802941694557 and parameters: {'num_leaves': 200, 'learning_rate': 0.14379894823502065, 'feature_fraction': 0.7807900357858379, 'bagging_fraction': 0.9409622854151198, 'bagging_freq': 3, 'min_child_samples': 16, 'lambda_l1': 3.5415284487022425, 'lambda_l2': 0.006096937804887876, 'max_depth': 11, 'max_bin': 1658, 'min_data_in_leaf': 96, 'extra_trees': False, 'path_smooth': 0.5010358976424568}. Best is trial 11 with value: 0.2575634019652293.
# [I 2025-07-12 13:24:40,775] Trial 16 finished with value: 0.28564836219702994 and parameters: {'num_leaves': 128, 'learning_rate': 0.14409430356197475, 'feature_fraction': 0.7833986765802938, 'bagging_fraction': 0.8615277873226402, 'bagging_freq': 4, 'min_child_samples': 64, 'lambda_l1': 0.34427249766760976, 'lambda_l2': 0.18133556356394206, 'max_depth': 11, 'max_bin': 6158, 'min_data_in_leaf': 52, 'extra_trees': False, 'path_smooth': 0.733527058744623}. Best is trial 11 with value: 0.2575634019652293.
# [I 2025-07-12 13:24:46,765] Trial 17 finished with value: 0.2673678627449241 and parameters: {'num_leaves': 71, 'learning_rate': 0.1679732028587464, 'feature_fraction': 0.7590135248799006, 'bagging_fraction': 0.9449635570588866, 'bagging_freq': 3, 'min_child_samples': 45, 'lambda_l1': 0.007135125109699391, 'lambda_l2': 0.008376345000974129, 'max_depth': 5, 'max_bin': 3582, 'min_data_in_leaf': 100, 'extra_trees': False, 'path_smooth': 0.44204274246483544}. Best is trial 11 with value: 0.2575634019652293.
# [I 2025-07-12 13:24:50,722] Trial 18 finished with value: 0.3051293983982139 and parameters: {'num_leaves': 170, 'learning_rate': 0.07615679328163132, 'feature_fraction': 0.6814703220163891, 'bagging_fraction': 0.8848385364918282, 'bagging_freq': 4, 'min_child_samples': 26, 'lambda_l1': 0.03285935380929879, 'lambda_l2': 0.002554789726333131, 'max_depth': 5, 'max_bin': 1817, 'min_data_in_leaf': 73, 'extra_trees': True, 'path_smooth': 0.589053428957688}. Best is trial 11 with value: 0.2575634019652293.
# [I 2025-07-12 13:25:08,471] Trial 19 finished with value: 0.2509981624403785 and parameters: {'num_leaves': 133, 'learning_rate': 0.12934994485734927, 'feature_fraction': 0.7267647067483809, 'bagging_fraction': 0.8318705830207591, 'bagging_freq': 0, 'min_child_samples': 57, 'lambda_l1': 0.17633346660759455, 'lambda_l2': 3.7024140952127884, 'max_depth': 9, 'max_bin': 6594, 'min_data_in_leaf': 116, 'extra_trees': False, 'path_smooth': 0.24316107766368794}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:25:20,476] Trial 20 finished with value: 0.26791740691754967 and parameters: {'num_leaves': 133, 'learning_rate': 0.1280345368902874, 'feature_fraction': 0.6049901522209482, 'bagging_fraction': 0.8320199007826594, 'bagging_freq': 0, 'min_child_samples': 44, 'lambda_l1': 0.00305276234748645, 'lambda_l2': 4.657960727589004, 'max_depth': 10, 'max_bin': 6467, 'min_data_in_leaf': 117, 'extra_trees': False, 'path_smooth': 0.2208791768836913}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:25:28,896] Trial 21 finished with value: 0.25941339668293345 and parameters: {'num_leaves': 118, 'learning_rate': 0.16412535706876555, 'feature_fraction': 0.7198496398604463, 'bagging_fraction': 0.829865948325834, 'bagging_freq': 1, 'min_child_samples': 57, 'lambda_l1': 0.2124304166587029, 'lambda_l2': 0.14782537523928832, 'max_depth': 7, 'max_bin': 3756, 'min_data_in_leaf': 112, 'extra_trees': False, 'path_smooth': 0.38358482678914435}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:25:42,577] Trial 22 finished with value: 0.2706537890647678 and parameters: {'num_leaves': 111, 'learning_rate': 0.12654918127871487, 'feature_fraction': 0.7320674242215334, 'bagging_fraction': 0.8364621571582456, 'bagging_freq': 0, 'min_child_samples': 57, 'lambda_l1': 1.3660427202282677, 'lambda_l2': 0.2564561045983433, 'max_depth': 9, 'max_bin': 6597, 'min_data_in_leaf': 166, 'extra_trees': False, 'path_smooth': 0.37859359910407814}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:25:49,796] Trial 23 finished with value: 0.2651538848806627 and parameters: {'num_leaves': 158, 'learning_rate': 0.08582871341281569, 'feature_fraction': 0.6764487806394526, 'bagging_fraction': 0.8112750145778664, 'bagging_freq': 1, 'min_child_samples': 39, 'lambda_l1': 0.2355610896645115, 'lambda_l2': 3.783746722444124, 'max_depth': 7, 'max_bin': 2294, 'min_data_in_leaf': 122, 'extra_trees': False, 'path_smooth': 0.2629691756939072}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:25:56,859] Trial 24 finished with value: 0.2694718547919745 and parameters: {'num_leaves': 94, 'learning_rate': 0.17905886194432954, 'feature_fraction': 0.6390546786431736, 'bagging_fraction': 0.8413987668939376, 'bagging_freq': 0, 'min_child_samples': 57, 'lambda_l1': 1.0581066827428685, 'lambda_l2': 0.45779116023390204, 'max_depth': 12, 'max_bin': 3435, 'min_data_in_leaf': 114, 'extra_trees': False, 'path_smooth': 0.19345579702965643}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:26:06,869] Trial 25 finished with value: 0.26632091429382015 and parameters: {'num_leaves': 138, 'learning_rate': 0.16565619425664177, 'feature_fraction': 0.700198008244723, 'bagging_fraction': 0.8012981190395769, 'bagging_freq': 1, 'min_child_samples': 51, 'lambda_l1': 0.031807077494988935, 'lambda_l2': 0.1015883753604258, 'max_depth': 9, 'max_bin': 4612, 'min_data_in_leaf': 86, 'extra_trees': False, 'path_smooth': 0.38104501875570385}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:26:10,019] Trial 26 finished with value: 0.2680225174409726 and parameters: {'num_leaves': 114, 'learning_rate': 0.13430341978700394, 'feature_fraction': 0.6469292116385522, 'bagging_fraction': 0.8856440257655401, 'bagging_freq': 0, 'min_child_samples': 22, 'lambda_l1': 0.1289368766467065, 'lambda_l2': 0.3612050198159683, 'max_depth': 12, 'max_bin': 634, 'min_data_in_leaf': 55, 'extra_trees': True, 'path_smooth': 0.3978618864654533}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:26:18,906] Trial 27 finished with value: 0.28113732018826837 and parameters: {'num_leaves': 179, 'learning_rate': 0.1644030429682508, 'feature_fraction': 0.8013747675221217, 'bagging_fraction': 0.8489573271838637, 'bagging_freq': 1, 'min_child_samples': 41, 'lambda_l1': 0.6065535527985414, 'lambda_l2': 1.3503989259613918, 'max_depth': 8, 'max_bin': 5876, 'min_data_in_leaf': 168, 'extra_trees': False, 'path_smooth': 0.5475161079592691}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:26:23,633] Trial 28 finished with value: 0.26083324477280845 and parameters: {'num_leaves': 150, 'learning_rate': 0.11832184831120442, 'feature_fraction': 0.7399825293209262, 'bagging_fraction': 0.7747710318598013, 'bagging_freq': 0, 'min_child_samples': 62, 'lambda_l1': 0.029340109744149804, 'lambda_l2': 2.549122001845981, 'max_depth': 6, 'max_bin': 2188, 'min_data_in_leaf': 83, 'extra_trees': False, 'path_smooth': 0.2702779040080832}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:26:40,831] Trial 29 finished with value: 0.27153074998949034 and parameters: {'num_leaves': 100, 'learning_rate': 0.08857369944030374, 'feature_fraction': 0.8671855806567292, 'bagging_fraction': 0.8929561065117986, 'bagging_freq': 2, 'min_child_samples': 75, 'lambda_l1': 0.08150564893379683, 'lambda_l2': 0.010830497343668706, 'max_depth': 10, 'max_bin': 7062, 'min_data_in_leaf': 110, 'extra_trees': False, 'path_smooth': 0.1521091202228115}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:26:51,036] Trial 30 finished with value: 0.2684646216574005 and parameters: {'num_leaves': 125, 'learning_rate': 0.18272934018555909, 'feature_fraction': 0.6212476115848112, 'bagging_fraction': 0.822023224135792, 'bagging_freq': 1, 'min_child_samples': 71, 'lambda_l1': 0.25573580451579314, 'lambda_l2': 0.06474450849738515, 'max_depth': 12, 'max_bin': 4487, 'min_data_in_leaf': 125, 'extra_trees': False, 'path_smooth': 0.6423465629654447}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:26:55,752] Trial 31 finished with value: 0.27199124374280753 and parameters: {'num_leaves': 153, 'learning_rate': 0.1207774904321706, 'feature_fraction': 0.7444742700328566, 'bagging_fraction': 0.7772885863376197, 'bagging_freq': 0, 'min_child_samples': 60, 'lambda_l1': 0.0033699982690077977, 'lambda_l2': 2.6638570307344573, 'max_depth': 6, 'max_bin': 2215, 'min_data_in_leaf': 85, 'extra_trees': False, 'path_smooth': 0.26627858745610333}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:26:59,005] Trial 32 finished with value: 0.29988975642016014 and parameters: {'num_leaves': 144, 'learning_rate': 0.11691716825119834, 'feature_fraction': 0.7026738914135251, 'bagging_fraction': 0.772946467195444, 'bagging_freq': 0, 'min_child_samples': 63, 'lambda_l1': 0.03625491923927107, 'lambda_l2': 2.4196884384538824, 'max_depth': 6, 'max_bin': 1269, 'min_data_in_leaf': 57, 'extra_trees': False, 'path_smooth': 0.2884803399583586}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:03,648] Trial 33 finished with value: 0.26009696117956926 and parameters: {'num_leaves': 167, 'learning_rate': 0.14036275992841146, 'feature_fraction': 0.6644907699937734, 'bagging_fraction': 0.8217637399331561, 'bagging_freq': 0, 'min_child_samples': 55, 'lambda_l1': 0.10863444353924868, 'lambda_l2': 0.5629275552654347, 'max_depth': 4, 'max_bin': 4044, 'min_data_in_leaf': 88, 'extra_trees': False, 'path_smooth': 0.07610602848708728}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:08,416] Trial 34 finished with value: 0.25728159884241864 and parameters: {'num_leaves': 170, 'learning_rate': 0.13990492933304116, 'feature_fraction': 0.6606869634527902, 'bagging_fraction': 0.8153777971522208, 'bagging_freq': 0, 'min_child_samples': 53, 'lambda_l1': 0.11585473503842848, 'lambda_l2': 0.9259671947885064, 'max_depth': 4, 'max_bin': 4127, 'min_data_in_leaf': 152, 'extra_trees': False, 'path_smooth': 0.03736889260853031}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:12,968] Trial 35 finished with value: 0.2662500418558961 and parameters: {'num_leaves': 192, 'learning_rate': 0.15357898490294097, 'feature_fraction': 0.6009516768392711, 'bagging_fraction': 0.8510373374090388, 'bagging_freq': 1, 'min_child_samples': 49, 'lambda_l1': 0.16056251874286265, 'lambda_l2': 0.7695427934975467, 'max_depth': 4, 'max_bin': 3541, 'min_data_in_leaf': 128, 'extra_trees': False, 'path_smooth': 0.023353655237694608}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:17,487] Trial 36 finished with value: 0.301656615164708 and parameters: {'num_leaves': 166, 'learning_rate': 0.17077976993000152, 'feature_fraction': 0.7201829412970958, 'bagging_fraction': 0.8078081474188312, 'bagging_freq': 0, 'min_child_samples': 32, 'lambda_l1': 0.7455220060833505, 'lambda_l2': 0.9985969399327137, 'max_depth': 8, 'max_bin': 5696, 'min_data_in_leaf': 155, 'extra_trees': True, 'path_smooth': 0.09747030624953618}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:24,463] Trial 37 finished with value: 0.27929758630830304 and parameters: {'num_leaves': 107, 'learning_rate': 0.15831183688747405, 'feature_fraction': 0.6251911150106237, 'bagging_fraction': 0.8180154233645824, 'bagging_freq': 2, 'min_child_samples': 53, 'lambda_l1': 0.06880220317909888, 'lambda_l2': 0.04615675506649215, 'max_depth': 8, 'max_bin': 3110, 'min_data_in_leaf': 153, 'extra_trees': False, 'path_smooth': 0.41882384468399586}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:28,858] Trial 38 finished with value: 0.26123239899523365 and parameters: {'num_leaves': 135, 'learning_rate': 0.19651436752020557, 'feature_fraction': 0.6957056723607332, 'bagging_fraction': 0.875186854633382, 'bagging_freq': 0, 'min_child_samples': 35, 'lambda_l1': 0.05033405245600641, 'lambda_l2': 0.3140864452929069, 'max_depth': 3, 'max_bin': 7110, 'min_data_in_leaf': 155, 'extra_trees': False, 'path_smooth': 0.1882713218991764}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:34,073] Trial 39 finished with value: 0.2560602358585493 and parameters: {'num_leaves': 67, 'learning_rate': 0.135917858879605, 'feature_fraction': 0.6671991936075841, 'bagging_fraction': 0.8966683288610913, 'bagging_freq': 1, 'min_child_samples': 44, 'lambda_l1': 0.10353427221486576, 'lambda_l2': 1.8356860677253584, 'max_depth': 4, 'max_bin': 4908, 'min_data_in_leaf': 109, 'extra_trees': False, 'path_smooth': 0.33620925412520797}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:40,495] Trial 40 finished with value: 0.3231960506237103 and parameters: {'num_leaves': 66, 'learning_rate': 0.09177551835591463, 'feature_fraction': 0.6641851663389311, 'bagging_fraction': 0.9010748768899136, 'bagging_freq': 1, 'min_child_samples': 44, 'lambda_l1': 0.020899184426489748, 'lambda_l2': 1.7972637530681135, 'max_depth': 16, 'max_bin': 4933, 'min_data_in_leaf': 193, 'extra_trees': True, 'path_smooth': 0.3289559833026539}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:47,630] Trial 41 finished with value: 0.2603816264890795 and parameters: {'num_leaves': 59, 'learning_rate': 0.13552720276432903, 'feature_fraction': 0.6380952060225266, 'bagging_fraction': 0.9271760986369971, 'bagging_freq': 1, 'min_child_samples': 48, 'lambda_l1': 0.0922189217915561, 'lambda_l2': 0.7406456942224918, 'max_depth': 6, 'max_bin': 3935, 'min_data_in_leaf': 106, 'extra_trees': False, 'path_smooth': 0.3560381329699647}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:53,457] Trial 42 finished with value: 0.2619668955618119 and parameters: {'num_leaves': 90, 'learning_rate': 0.10921380958727446, 'feature_fraction': 0.7203969594569191, 'bagging_fraction': 0.8580987359473528, 'bagging_freq': 0, 'min_child_samples': 40, 'lambda_l1': 0.3216692442857157, 'lambda_l2': 4.910402281024996, 'max_depth': 4, 'max_bin': 4285, 'min_data_in_leaf': 136, 'extra_trees': False, 'path_smooth': 0.5294453592999155}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:27:58,093] Trial 43 finished with value: 0.266238818977504 and parameters: {'num_leaves': 86, 'learning_rate': 0.14738943026107965, 'feature_fraction': 0.647927525881131, 'bagging_fraction': 0.9044905591635526, 'bagging_freq': 2, 'min_child_samples': 54, 'lambda_l1': 0.15529153934645987, 'lambda_l2': 1.8293535893192228, 'max_depth': 3, 'max_bin': 5452, 'min_data_in_leaf': 106, 'extra_trees': False, 'path_smooth': 0.07650626736600133}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:02,593] Trial 44 finished with value: 0.2657180529921351 and parameters: {'num_leaves': 46, 'learning_rate': 0.1335323518350581, 'feature_fraction': 0.620070918349169, 'bagging_fraction': 0.7883309628109755, 'bagging_freq': 1, 'min_child_samples': 66, 'lambda_l1': 0.04593442267581846, 'lambda_l2': 0.9349776158199715, 'max_depth': 4, 'max_bin': 3260, 'min_data_in_leaf': 143, 'extra_trees': False, 'path_smooth': 0.13590945801255006}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:13,756] Trial 45 finished with value: 0.26152921501359155 and parameters: {'num_leaves': 22, 'learning_rate': 0.09911158548002988, 'feature_fraction': 0.6754821443047782, 'bagging_fraction': 0.9246929327757272, 'bagging_freq': 0, 'min_child_samples': 36, 'lambda_l1': 0.4527619562421249, 'lambda_l2': 0.015008055519490592, 'max_depth': 7, 'max_bin': 4826, 'min_data_in_leaf': 179, 'extra_trees': False, 'path_smooth': 0.32293590424947405}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:26,161] Trial 46 finished with value: 0.2973889361059457 and parameters: {'num_leaves': 129, 'learning_rate': 0.06797496351782112, 'feature_fraction': 0.7654992371171551, 'bagging_fraction': 0.8429196723215292, 'bagging_freq': 2, 'min_child_samples': 58, 'lambda_l1': 0.20882642699084328, 'lambda_l2': 0.1922625733959722, 'max_depth': 9, 'max_bin': 7467, 'min_data_in_leaf': 65, 'extra_trees': False, 'path_smooth': 0.45446872555209195}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:32,281] Trial 47 finished with value: 0.26788636675424327 and parameters: {'num_leaves': 107, 'learning_rate': 0.15828779528923503, 'feature_fraction': 0.7095511195674258, 'bagging_fraction': 0.8748461004266721, 'bagging_freq': 0, 'min_child_samples': 80, 'lambda_l1': 0.009619167807145246, 'lambda_l2': 0.03071807201218209, 'max_depth': 8, 'max_bin': 2728, 'min_data_in_leaf': 117, 'extra_trees': False, 'path_smooth': 0.23368497653716025}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:36,940] Trial 48 finished with value: 0.2908823324833129 and parameters: {'num_leaves': 37, 'learning_rate': 0.18613466188250508, 'feature_fraction': 0.6940971183741552, 'bagging_fraction': 0.7432380757647001, 'bagging_freq': 1, 'min_child_samples': 46, 'lambda_l1': 0.12273906366194251, 'lambda_l2': 0.0020145833643965597, 'max_depth': 10, 'max_bin': 4093, 'min_data_in_leaf': 43, 'extra_trees': True, 'path_smooth': 0.4174705124376006}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:42,009] Trial 49 finished with value: 0.2614610188692865 and parameters: {'num_leaves': 119, 'learning_rate': 0.1715080515555199, 'feature_fraction': 0.6155321751076513, 'bagging_fraction': 0.8012402724328683, 'bagging_freq': 0, 'min_child_samples': 52, 'lambda_l1': 0.066056946242846, 'lambda_l2': 0.10304375726831755, 'max_depth': 5, 'max_bin': 4910, 'min_data_in_leaf': 91, 'extra_trees': False, 'path_smooth': 0.17108124238856792}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:46,985] Trial 50 finished with value: 0.28197599518988903 and parameters: {'num_leaves': 57, 'learning_rate': 0.14759223353386777, 'feature_fraction': 0.6549573291880082, 'bagging_fraction': 0.8266621462644989, 'bagging_freq': 1, 'min_child_samples': 29, 'lambda_l1': 0.005243293045063749, 'lambda_l2': 3.1183618479946777, 'max_depth': 7, 'max_bin': 3824, 'min_data_in_leaf': 79, 'extra_trees': False, 'path_smooth': 0.5007653090392192}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:51,036] Trial 51 finished with value: 0.26696646685308417 and parameters: {'num_leaves': 169, 'learning_rate': 0.14072596308457982, 'feature_fraction': 0.6675832614416094, 'bagging_fraction': 0.8260432540996097, 'bagging_freq': 0, 'min_child_samples': 55, 'lambda_l1': 0.10556870477438735, 'lambda_l2': 0.5943119692292818, 'max_depth': 4, 'max_bin': 4202, 'min_data_in_leaf': 93, 'extra_trees': False, 'path_smooth': 0.04301817716464462}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:54,838] Trial 52 finished with value: 0.2609878294817894 and parameters: {'num_leaves': 179, 'learning_rate': 0.12506611977113957, 'feature_fraction': 0.7276663779759085, 'bagging_fraction': 0.8111727645866683, 'bagging_freq': 0, 'min_child_samples': 50, 'lambda_l1': 0.3329127067647667, 'lambda_l2': 0.5414514174951636, 'max_depth': 3, 'max_bin': 3186, 'min_data_in_leaf': 101, 'extra_trees': False, 'path_smooth': 0.07459251426161345}. Best is trial 19 with value: 0.2509981624403785.
# [I 2025-07-12 13:28:59,441] Trial 53 finished with value: 0.2413831940870928 and parameters: {'num_leaves': 188, 'learning_rate': 0.13919188722321268, 'feature_fraction': 0.6359664446675085, 'bagging_fraction': 0.8344008631424239, 'bagging_freq': 0, 'min_child_samples': 42, 'lambda_l1': 0.022108592460749685, 'lambda_l2': 1.2364619176519653, 'max_depth': 5, 'max_bin': 2639, 'min_data_in_leaf': 129, 'extra_trees': False, 'path_smooth': 0.11949702880292995}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:03,467] Trial 54 finished with value: 0.25338087720561203 and parameters: {'num_leaves': 188, 'learning_rate': 0.1599393578537714, 'feature_fraction': 0.6355915381250116, 'bagging_fraction': 0.8680319248054247, 'bagging_freq': 0, 'min_child_samples': 42, 'lambda_l1': 0.002087830669873998, 'lambda_l2': 1.6215283870520938, 'max_depth': 6, 'max_bin': 1897, 'min_data_in_leaf': 128, 'extra_trees': False, 'path_smooth': 0.23221090131027186}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:06,825] Trial 55 finished with value: 0.24846315818970074 and parameters: {'num_leaves': 187, 'learning_rate': 0.15795332873901463, 'feature_fraction': 0.6343676397644796, 'bagging_fraction': 0.8551496827718645, 'bagging_freq': 0, 'min_child_samples': 40, 'lambda_l1': 0.0019832717852364076, 'lambda_l2': 1.7755730558173193, 'max_depth': 5, 'max_bin': 1666, 'min_data_in_leaf': 129, 'extra_trees': False, 'path_smooth': 0.22493951824648484}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:09,777] Trial 56 finished with value: 0.2617591564160474 and parameters: {'num_leaves': 188, 'learning_rate': 0.13145774423854237, 'feature_fraction': 0.6491092519453542, 'bagging_fraction': 0.8658797199310453, 'bagging_freq': 0, 'min_child_samples': 37, 'lambda_l1': 0.001713713928963137, 'lambda_l2': 1.700323190131341, 'max_depth': 5, 'max_bin': 679, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.12848479938694643}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:13,577] Trial 57 finished with value: 0.2590424271859722 and parameters: {'num_leaves': 198, 'learning_rate': 0.11378803365496021, 'feature_fraction': 0.6340600840119334, 'bagging_fraction': 0.8528642348339828, 'bagging_freq': 0, 'min_child_samples': 24, 'lambda_l1': 0.0010168077052849574, 'lambda_l2': 1.2746330015619898, 'max_depth': 5, 'max_bin': 1523, 'min_data_in_leaf': 149, 'extra_trees': False, 'path_smooth': 0.2061829595045256}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:17,522] Trial 58 finished with value: 0.26894241708777883 and parameters: {'num_leaves': 186, 'learning_rate': 0.10124763097174422, 'feature_fraction': 0.6131199929167485, 'bagging_fraction': 0.8402066113940773, 'bagging_freq': 0, 'min_child_samples': 33, 'lambda_l1': 0.0021465123760690784, 'lambda_l2': 3.515626800939437, 'max_depth': 6, 'max_bin': 1946, 'min_data_in_leaf': 166, 'extra_trees': False, 'path_smooth': 0.2313351279852864}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:19,787] Trial 59 finished with value: 0.314861093267058 and parameters: {'num_leaves': 174, 'learning_rate': 0.15637968842974734, 'feature_fraction': 0.6386552438958469, 'bagging_fraction': 0.9020315028079582, 'bagging_freq': 0, 'min_child_samples': 43, 'lambda_l1': 0.005363672325659509, 'lambda_l2': 2.139745812271883, 'max_depth': 3, 'max_bin': 625, 'min_data_in_leaf': 140, 'extra_trees': True, 'path_smooth': 0.04685777623283826}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:22,947] Trial 60 finished with value: 0.24818066268105113 and parameters: {'num_leaves': 160, 'learning_rate': 0.14739261457781125, 'feature_fraction': 0.6897823940953681, 'bagging_fraction': 0.8914120639613957, 'bagging_freq': 1, 'min_child_samples': 40, 'lambda_l1': 0.0022744541556032707, 'lambda_l2': 1.2419679513253132, 'max_depth': 4, 'max_bin': 1005, 'min_data_in_leaf': 120, 'extra_trees': False, 'path_smooth': 0.11685660242939476}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:25,881] Trial 61 finished with value: 0.2553436733441452 and parameters: {'num_leaves': 160, 'learning_rate': 0.1489751007154162, 'feature_fraction': 0.6866879541134667, 'bagging_fraction': 0.889582788753425, 'bagging_freq': 1, 'min_child_samples': 39, 'lambda_l1': 0.004429825521136402, 'lambda_l2': 1.1021538604811996, 'max_depth': 4, 'max_bin': 1177, 'min_data_in_leaf': 128, 'extra_trees': False, 'path_smooth': 0.0035167005542899032}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:29,868] Trial 62 finished with value: 0.24837500924333267 and parameters: {'num_leaves': 160, 'learning_rate': 0.1619290187797273, 'feature_fraction': 0.6888222299698309, 'bagging_fraction': 0.8933701609292983, 'bagging_freq': 1, 'min_child_samples': 39, 'lambda_l1': 0.0020203819135169478, 'lambda_l2': 1.4085219359019772, 'max_depth': 5, 'max_bin': 1010, 'min_data_in_leaf': 120, 'extra_trees': False, 'path_smooth': 0.005230806786049348}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:32,391] Trial 63 finished with value: 0.25260291480973807 and parameters: {'num_leaves': 193, 'learning_rate': 0.17786335229744188, 'feature_fraction': 0.6893233986378084, 'bagging_fraction': 0.8811001328278716, 'bagging_freq': 1, 'min_child_samples': 31, 'lambda_l1': 0.0022887975062676866, 'lambda_l2': 1.2809879468466834, 'max_depth': 5, 'max_bin': 228, 'min_data_in_leaf': 122, 'extra_trees': False, 'path_smooth': 0.010743789221157644}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:34,711] Trial 64 finished with value: 0.26526683596665 and parameters: {'num_leaves': 183, 'learning_rate': 0.19262896982407599, 'feature_fraction': 0.6876595660238515, 'bagging_fraction': 0.8803652268445026, 'bagging_freq': 2, 'min_child_samples': 20, 'lambda_l1': 0.0024786365392258235, 'lambda_l2': 1.3429430703531515, 'max_depth': 6, 'max_bin': 184, 'min_data_in_leaf': 120, 'extra_trees': False, 'path_smooth': 0.16128968616712014}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:37,803] Trial 65 finished with value: 0.25961589159797316 and parameters: {'num_leaves': 197, 'learning_rate': 0.17703052604973524, 'feature_fraction': 0.6748542287567436, 'bagging_fraction': 0.8710730314775395, 'bagging_freq': 1, 'min_child_samples': 11, 'lambda_l1': 0.0012268218731756961, 'lambda_l2': 0.4200598808510931, 'max_depth': 5, 'max_bin': 943, 'min_data_in_leaf': 131, 'extra_trees': False, 'path_smooth': 0.12156035778741126}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:40,166] Trial 66 finished with value: 0.2789675128536184 and parameters: {'num_leaves': 192, 'learning_rate': 0.1608543066877485, 'feature_fraction': 0.7080562078814499, 'bagging_fraction': 0.9187217218952626, 'bagging_freq': 1, 'min_child_samples': 32, 'lambda_l1': 0.0020664201165211983, 'lambda_l2': 4.473111317982687, 'max_depth': 5, 'max_bin': 55, 'min_data_in_leaf': 123, 'extra_trees': False, 'path_smooth': 0.10580202859313229}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:43,313] Trial 67 finished with value: 0.2682289836511122 and parameters: {'num_leaves': 176, 'learning_rate': 0.17431436643109702, 'feature_fraction': 0.7363103465677219, 'bagging_fraction': 0.8637304502822174, 'bagging_freq': 5, 'min_child_samples': 28, 'lambda_l1': 0.007653591666457494, 'lambda_l2': 3.28615271106257, 'max_depth': 6, 'max_bin': 911, 'min_data_in_leaf': 115, 'extra_trees': False, 'path_smooth': 0.07076111615740688}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:46,948] Trial 68 finished with value: 0.25496622999625407 and parameters: {'num_leaves': 163, 'learning_rate': 0.18259957414905928, 'feature_fraction': 0.6312941233878757, 'bagging_fraction': 0.9095928589011871, 'bagging_freq': 4, 'min_child_samples': 38, 'lambda_l1': 0.0025471231900931457, 'lambda_l2': 2.332959371330735, 'max_depth': 5, 'max_bin': 1454, 'min_data_in_leaf': 135, 'extra_trees': False, 'path_smooth': 0.7834401483056119}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:29:50,017] Trial 69 finished with value: 0.278160637269353 and parameters: {'num_leaves': 144, 'learning_rate': 0.16359392649634452, 'feature_fraction': 0.7527168557536494, 'bagging_fraction': 0.8824716961955505, 'bagging_freq': 2, 'min_child_samples': 47, 'lambda_l1': 0.015422088798331167, 'lambda_l2': 0.8183072100687955, 'max_depth': 13, 'max_bin': 299, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.012641831323058354}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:20,680] Trial 70 finished with value: 0.3838227558457168 and parameters: {'num_leaves': 155, 'learning_rate': 0.0020034635621822144, 'feature_fraction': 0.6528066287393304, 'bagging_fraction': 0.8558651524544097, 'bagging_freq': 1, 'min_child_samples': 27, 'lambda_l1': 0.0016998786518676024, 'lambda_l2': 1.5131107212878352, 'max_depth': 7, 'max_bin': 1924, 'min_data_in_leaf': 123, 'extra_trees': False, 'path_smooth': 0.9923802943530369}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:24,928] Trial 71 finished with value: 0.2574010772418953 and parameters: {'num_leaves': 164, 'learning_rate': 0.1811929552956762, 'feature_fraction': 0.6113591278103905, 'bagging_fraction': 0.9125743478739647, 'bagging_freq': 5, 'min_child_samples': 38, 'lambda_l1': 0.0028263344293303614, 'lambda_l2': 2.865573421385782, 'max_depth': 5, 'max_bin': 1461, 'min_data_in_leaf': 136, 'extra_trees': False, 'path_smooth': 0.7457498872263606}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:29,359] Trial 72 finished with value: 0.2525058995667999 and parameters: {'num_leaves': 194, 'learning_rate': 0.18826156390185494, 'feature_fraction': 0.6299118699125914, 'bagging_fraction': 0.9082400311581093, 'bagging_freq': 3, 'min_child_samples': 41, 'lambda_l1': 0.0033049757133350797, 'lambda_l2': 2.236214825149098, 'max_depth': 6, 'max_bin': 2367, 'min_data_in_leaf': 128, 'extra_trees': False, 'path_smooth': 0.8331697409004534}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:34,140] Trial 73 finished with value: 0.30166459606260737 and parameters: {'num_leaves': 193, 'learning_rate': 0.19155302692846476, 'feature_fraction': 0.6427765745139843, 'bagging_fraction': 0.9355623200154602, 'bagging_freq': 3, 'min_child_samples': 42, 'lambda_l1': 0.0037222159253733392, 'lambda_l2': 3.9946391644995294, 'max_depth': 6, 'max_bin': 2376, 'min_data_in_leaf': 11, 'extra_trees': False, 'path_smooth': 0.17523369001760689}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:38,015] Trial 74 finished with value: 0.2623971867951471 and parameters: {'num_leaves': 186, 'learning_rate': 0.153473289417298, 'feature_fraction': 0.627967302567833, 'bagging_fraction': 0.8932368548255232, 'bagging_freq': 3, 'min_child_samples': 34, 'lambda_l1': 0.0013041257127243185, 'lambda_l2': 1.2315452232554627, 'max_depth': 6, 'max_bin': 1728, 'min_data_in_leaf': 119, 'extra_trees': False, 'path_smooth': 0.8829276967335639}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:41,568] Trial 75 finished with value: 0.25916189121017275 and parameters: {'num_leaves': 200, 'learning_rate': 0.1720614275917294, 'feature_fraction': 0.6789181775832777, 'bagging_fraction': 0.8466938633824347, 'bagging_freq': 3, 'min_child_samples': 41, 'lambda_l1': 0.006643629856865773, 'lambda_l2': 2.1316945666286027, 'max_depth': 7, 'max_bin': 917, 'min_data_in_leaf': 126, 'extra_trees': False, 'path_smooth': 0.2924962830064233}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:43,911] Trial 76 finished with value: 0.28378128619278886 and parameters: {'num_leaves': 175, 'learning_rate': 0.16710334682500927, 'feature_fraction': 0.7001912606132448, 'bagging_fraction': 0.8348469430817947, 'bagging_freq': 0, 'min_child_samples': 31, 'lambda_l1': 0.001918341355247765, 'lambda_l2': 0.649053412834001, 'max_depth': 4, 'max_bin': 523, 'min_data_in_leaf': 113, 'extra_trees': True, 'path_smooth': 0.654531039103999}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:50,701] Trial 77 finished with value: 0.28540423618776845 and parameters: {'num_leaves': 183, 'learning_rate': 0.19822691501683337, 'feature_fraction': 0.6890082610740488, 'bagging_fraction': 0.8786355320552667, 'bagging_freq': 4, 'min_child_samples': 88, 'lambda_l1': 0.004159259357950839, 'lambda_l2': 1.44643503839501, 'max_depth': 17, 'max_bin': 2080, 'min_data_in_leaf': 128, 'extra_trees': False, 'path_smooth': 0.25394140956268535}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:53,389] Trial 78 finished with value: 0.2604019507648489 and parameters: {'num_leaves': 188, 'learning_rate': 0.15048415414700106, 'feature_fraction': 0.606629177282568, 'bagging_fraction': 0.8689894903683963, 'bagging_freq': 3, 'min_child_samples': 35, 'lambda_l1': 0.0010219194257844045, 'lambda_l2': 1.0063021857710326, 'max_depth': 3, 'max_bin': 1285, 'min_data_in_leaf': 105, 'extra_trees': False, 'path_smooth': 0.04696836283338188}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:30:59,387] Trial 79 finished with value: 0.27172434025055975 and parameters: {'num_leaves': 193, 'learning_rate': 0.18728978985219563, 'feature_fraction': 0.792644907911396, 'bagging_fraction': 0.8966165586299327, 'bagging_freq': 0, 'min_child_samples': 46, 'lambda_l1': 0.0031002152388511788, 'lambda_l2': 2.8546265922822953, 'max_depth': 8, 'max_bin': 2480, 'min_data_in_leaf': 141, 'extra_trees': False, 'path_smooth': 0.1484133583504383}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:02,709] Trial 80 finished with value: 0.2611398308336411 and parameters: {'num_leaves': 180, 'learning_rate': 0.17747123886815205, 'feature_fraction': 0.7281158724162394, 'bagging_fraction': 0.88950942692059, 'bagging_freq': 1, 'min_child_samples': 49, 'lambda_l1': 0.012163041570627637, 'lambda_l2': 1.9961289126094666, 'max_depth': 5, 'max_bin': 1036, 'min_data_in_leaf': 131, 'extra_trees': False, 'path_smooth': 0.09752591024376668}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:06,267] Trial 81 finished with value: 0.2548244152747283 and parameters: {'num_leaves': 148, 'learning_rate': 0.18248429443459402, 'feature_fraction': 0.6307042370958956, 'bagging_fraction': 0.9097751936878786, 'bagging_freq': 4, 'min_child_samples': 37, 'lambda_l1': 0.0023399492522578236, 'lambda_l2': 2.35486967047962, 'max_depth': 5, 'max_bin': 1485, 'min_data_in_leaf': 135, 'extra_trees': False, 'path_smooth': 0.7577417577554776}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:09,904] Trial 82 finished with value: 0.25207296537289325 and parameters: {'num_leaves': 137, 'learning_rate': 0.16264055884778172, 'feature_fraction': 0.6575472136360798, 'bagging_fraction': 0.9248715249704912, 'bagging_freq': 4, 'min_child_samples': 41, 'lambda_l1': 0.0015693766797482257, 'lambda_l2': 1.664942726463798, 'max_depth': 4, 'max_bin': 1686, 'min_data_in_leaf': 160, 'extra_trees': False, 'path_smooth': 0.8412824412020058}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:14,296] Trial 83 finished with value: 0.25569608603727445 and parameters: {'num_leaves': 171, 'learning_rate': 0.14331156397615746, 'feature_fraction': 0.6710541732680988, 'bagging_fraction': 0.9042869470433006, 'bagging_freq': 4, 'min_child_samples': 40, 'lambda_l1': 0.0017506981367456207, 'lambda_l2': 1.6637454777940546, 'max_depth': 4, 'max_bin': 2603, 'min_data_in_leaf': 147, 'extra_trees': False, 'path_smooth': 0.8285642693597141}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:17,280] Trial 84 finished with value: 0.26162729651128047 and parameters: {'num_leaves': 195, 'learning_rate': 0.16146117779102498, 'feature_fraction': 0.6593156365377418, 'bagging_fraction': 0.9198182027936441, 'bagging_freq': 2, 'min_child_samples': 43, 'lambda_l1': 0.0014582135720607587, 'lambda_l2': 1.111481819535255, 'max_depth': 3, 'max_bin': 1705, 'min_data_in_leaf': 97, 'extra_trees': False, 'path_smooth': 0.21226264580001566}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:19,925] Trial 85 finished with value: 0.26313810068151944 and parameters: {'num_leaves': 124, 'learning_rate': 0.1698146195779418, 'feature_fraction': 0.6231816898922599, 'bagging_fraction': 0.9279275008410391, 'bagging_freq': 3, 'min_child_samples': 30, 'lambda_l1': 0.003310990850604229, 'lambda_l2': 0.7872846183294107, 'max_depth': 6, 'max_bin': 468, 'min_data_in_leaf': 110, 'extra_trees': False, 'path_smooth': 0.8736481656382775}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:24,100] Trial 86 finished with value: 0.26303185327698586 and parameters: {'num_leaves': 137, 'learning_rate': 0.15603734022975885, 'feature_fraction': 0.6455151009506173, 'bagging_fraction': 0.8586952395405695, 'bagging_freq': 0, 'min_child_samples': 25, 'lambda_l1': 0.005197063650595443, 'lambda_l2': 3.7890649188890357, 'max_depth': 4, 'max_bin': 2949, 'min_data_in_leaf': 162, 'extra_trees': False, 'path_smooth': 0.9418380972756109}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:28,259] Trial 87 finished with value: 0.27945224606843627 and parameters: {'num_leaves': 140, 'learning_rate': 0.14405916081298561, 'feature_fraction': 0.6574110273529896, 'bagging_fraction': 0.9373011163460852, 'bagging_freq': 4, 'min_child_samples': 41, 'lambda_l1': 0.0013818009873518345, 'lambda_l2': 0.4825211434187517, 'max_depth': 7, 'max_bin': 2076, 'min_data_in_leaf': 198, 'extra_trees': False, 'path_smooth': 0.7024406049945895}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:30,845] Trial 88 finished with value: 0.28130904720108646 and parameters: {'num_leaves': 156, 'learning_rate': 0.12197093956385577, 'feature_fraction': 0.7112274813971061, 'bagging_fraction': 0.884867448701652, 'bagging_freq': 0, 'min_child_samples': 45, 'lambda_l1': 0.002471018449368191, 'lambda_l2': 1.5403667675022068, 'max_depth': 4, 'max_bin': 1832, 'min_data_in_leaf': 179, 'extra_trees': True, 'path_smooth': 0.6203016484537174}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:33,929] Trial 89 finished with value: 0.2588724980521762 and parameters: {'num_leaves': 150, 'learning_rate': 0.12883562095232573, 'feature_fraction': 0.6373249255991383, 'bagging_fraction': 0.8449228061954097, 'bagging_freq': 2, 'min_child_samples': 35, 'lambda_l1': 0.023477975859006607, 'lambda_l2': 2.8159097702435876, 'max_depth': 5, 'max_bin': 760, 'min_data_in_leaf': 118, 'extra_trees': False, 'path_smooth': 0.8301946663611085}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:38,756] Trial 90 finished with value: 0.27514620705634324 and parameters: {'num_leaves': 189, 'learning_rate': 0.16689061405430947, 'feature_fraction': 0.6805489043583657, 'bagging_fraction': 0.8368794505243197, 'bagging_freq': 0, 'min_child_samples': 50, 'lambda_l1': 0.0011661144400332791, 'lambda_l2': 0.2591452858890292, 'max_depth': 11, 'max_bin': 1142, 'min_data_in_leaf': 104, 'extra_trees': False, 'path_smooth': 0.0270639441576198}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:42,364] Trial 91 finished with value: 0.25591027988988846 and parameters: {'num_leaves': 143, 'learning_rate': 0.18584947924077844, 'feature_fraction': 0.6321722127977232, 'bagging_fraction': 0.9097690813642725, 'bagging_freq': 4, 'min_child_samples': 36, 'lambda_l1': 0.002356950331508376, 'lambda_l2': 2.1249067483104387, 'max_depth': 5, 'max_bin': 1554, 'min_data_in_leaf': 138, 'extra_trees': False, 'path_smooth': 0.763176444234437}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:44,800] Trial 92 finished with value: 0.27037317498326896 and parameters: {'num_leaves': 146, 'learning_rate': 0.19253610981063732, 'feature_fraction': 0.622881744181009, 'bagging_fraction': 0.7123531499000769, 'bagging_freq': 4, 'min_child_samples': 37, 'lambda_l1': 0.001600504288852829, 'lambda_l2': 2.460403876777436, 'max_depth': 5, 'max_bin': 362, 'min_data_in_leaf': 123, 'extra_trees': False, 'path_smooth': 0.7979519434424093}. Best is trial 53 with value: 0.2413831940870928.
# [I 2025-07-12 13:31:48,601] Trial 93 finished with value: 0.25835674129535374 and parameters: {'num_leaves': 160, 'learning_rate': 0.17526900619405883, 'feature_fraction': 0.6432199296459349, 'bagging_fraction': 0.8997404690428685, 'bagging_freq': 4, 'min_child_samples': 33, 'lambda_l1': 0.002015716837011278, 'lambda_l2': 0.911197205262211, 'max_depth': 6, 'max_bin': 1321, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.867553711082212}. Best is trial 53 with value: 0.2413831940870928.
# ...
# [I 2025-07-12 14:45:54,806] Trial 970 finished with value: 0.25394221312837956 and parameters: {'num_leaves': 146, 'learning_rate': 0.14254708829880844, 'feature_fraction': 0.7404355129536555, 'bagging_fraction': 0.8914583740970329, 'bagging_freq': 5, 'min_child_samples': 24, 'lambda_l1': 0.023067731840708365, 'lambda_l2': 1.41611376659765, 'max_depth': 9, 'max_bin': 3226, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.9081724023271467}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:45:58,290] Trial 971 finished with value: 0.29165216309330233 and parameters: {'num_leaves': 139, 'learning_rate': 0.15945974641926408, 'feature_fraction': 0.8565146919667437, 'bagging_fraction': 0.8973463331412718, 'bagging_freq': 2, 'min_child_samples': 18, 'lambda_l1': 0.012768135709739071, 'lambda_l2': 1.146147638892797, 'max_depth': 6, 'max_bin': 3025, 'min_data_in_leaf': 145, 'extra_trees': True, 'path_smooth': 0.2621474224318516}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:02,707] Trial 972 finished with value: 0.26849989283366743 and parameters: {'num_leaves': 130, 'learning_rate': 0.15444396221183557, 'feature_fraction': 0.7293025505383413, 'bagging_fraction': 0.941502380618893, 'bagging_freq': 3, 'min_child_samples': 27, 'lambda_l1': 0.015926397452637093, 'lambda_l2': 0.5869112285320941, 'max_depth': 5, 'max_bin': 2838, 'min_data_in_leaf': 124, 'extra_trees': False, 'path_smooth': 0.28736986868794334}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:08,001] Trial 973 finished with value: 0.25322879250695496 and parameters: {'num_leaves': 135, 'learning_rate': 0.14657454680805507, 'feature_fraction': 0.7189184892805532, 'bagging_fraction': 0.9338397785100985, 'bagging_freq': 5, 'min_child_samples': 22, 'lambda_l1': 0.02110203854109527, 'lambda_l2': 0.13721322981402284, 'max_depth': 4, 'max_bin': 4098, 'min_data_in_leaf': 135, 'extra_trees': False, 'path_smooth': 0.8252927952550266}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:13,102] Trial 974 finished with value: 0.25222864495535774 and parameters: {'num_leaves': 125, 'learning_rate': 0.1680364339442887, 'feature_fraction': 0.7005408729664392, 'bagging_fraction': 0.8794781538980673, 'bagging_freq': 5, 'min_child_samples': 30, 'lambda_l1': 0.007409536738772749, 'lambda_l2': 0.8827272417676576, 'max_depth': 5, 'max_bin': 2652, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.29906752547724846}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:20,348] Trial 975 finished with value: 0.2466629213862004 and parameters: {'num_leaves': 132, 'learning_rate': 0.1398319465831297, 'feature_fraction': 0.7341274627973382, 'bagging_fraction': 0.8826310672747113, 'bagging_freq': 5, 'min_child_samples': 20, 'lambda_l1': 0.011642666611209683, 'lambda_l2': 0.5910355003279114, 'max_depth': 5, 'max_bin': 7734, 'min_data_in_leaf': 129, 'extra_trees': False, 'path_smooth': 0.1864968789887127}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:24,991] Trial 976 finished with value: 0.2583760982065856 and parameters: {'num_leaves': 151, 'learning_rate': 0.15229629045375556, 'feature_fraction': 0.7448568100584831, 'bagging_fraction': 0.8506598336164278, 'bagging_freq': 3, 'min_child_samples': 25, 'lambda_l1': 0.005878284650129207, 'lambda_l2': 1.0984088233459393, 'max_depth': 4, 'max_bin': 3484, 'min_data_in_leaf': 134, 'extra_trees': False, 'path_smooth': 0.5456491304821403}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:30,416] Trial 977 finished with value: 0.25217664990486816 and parameters: {'num_leaves': 142, 'learning_rate': 0.09352574910063097, 'feature_fraction': 0.7119206450627995, 'bagging_fraction': 0.890647556366471, 'bagging_freq': 5, 'min_child_samples': 28, 'lambda_l1': 0.018558504030179633, 'lambda_l2': 2.397830677955436, 'max_depth': 4, 'max_bin': 3696, 'min_data_in_leaf': 125, 'extra_trees': False, 'path_smooth': 0.1474082666807725}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:36,052] Trial 978 finished with value: 0.24898014142482955 and parameters: {'num_leaves': 146, 'learning_rate': 0.14871710525517823, 'feature_fraction': 0.7247944658392913, 'bagging_fraction': 0.9179397269044502, 'bagging_freq': 5, 'min_child_samples': 22, 'lambda_l1': 0.008955504324504919, 'lambda_l2': 1.5930802776871784, 'max_depth': 5, 'max_bin': 2606, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.8512688474524279}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:43,255] Trial 979 finished with value: 0.24459498586701434 and parameters: {'num_leaves': 139, 'learning_rate': 0.1330097228201094, 'feature_fraction': 0.7388603611699202, 'bagging_fraction': 0.9058437635102027, 'bagging_freq': 5, 'min_child_samples': 18, 'lambda_l1': 0.08457092741673074, 'lambda_l2': 0.22578720687934759, 'max_depth': 5, 'max_bin': 3833, 'min_data_in_leaf': 141, 'extra_trees': False, 'path_smooth': 0.2591945410057624}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:48,250] Trial 980 finished with value: 0.2549484230420655 and parameters: {'num_leaves': 128, 'learning_rate': 0.15714717212437332, 'feature_fraction': 0.7301476303182843, 'bagging_fraction': 0.8986091670914313, 'bagging_freq': 5, 'min_child_samples': 24, 'lambda_l1': 0.06306969073029219, 'lambda_l2': 0.7410598830937849, 'max_depth': 4, 'max_bin': 2840, 'min_data_in_leaf': 136, 'extra_trees': False, 'path_smooth': 0.8963638278660874}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:53,884] Trial 981 finished with value: 0.2532691781258726 and parameters: {'num_leaves': 158, 'learning_rate': 0.14551974188613512, 'feature_fraction': 0.6940490006952248, 'bagging_fraction': 0.858006038619468, 'bagging_freq': 5, 'min_child_samples': 64, 'lambda_l1': 0.014754797132513521, 'lambda_l2': 1.3057068032873105, 'max_depth': 6, 'max_bin': 2684, 'min_data_in_leaf': 128, 'extra_trees': False, 'path_smooth': 0.9507229792584907}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:46:59,496] Trial 982 finished with value: 0.25042729155610605 and parameters: {'num_leaves': 136, 'learning_rate': 0.15130257038406209, 'feature_fraction': 0.7467834099940162, 'bagging_fraction': 0.8861278477929887, 'bagging_freq': 5, 'min_child_samples': 33, 'lambda_l1': 0.022351515327929648, 'lambda_l2': 0.901593742304486, 'max_depth': 5, 'max_bin': 3387, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.8783309325143618}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:04,884] Trial 983 finished with value: 0.2566745689243752 and parameters: {'num_leaves': 131, 'learning_rate': 0.16189464874674594, 'feature_fraction': 0.7051367217190306, 'bagging_fraction': 0.9460817267249565, 'bagging_freq': 5, 'min_child_samples': 20, 'lambda_l1': 0.01058182555028611, 'lambda_l2': 0.06622200663729377, 'max_depth': 4, 'max_bin': 3067, 'min_data_in_leaf': 137, 'extra_trees': False, 'path_smooth': 0.2675201523876913}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:10,690] Trial 984 finished with value: 0.2613002040784209 and parameters: {'num_leaves': 153, 'learning_rate': 0.14087797427405233, 'feature_fraction': 0.7162370803150242, 'bagging_fraction': 0.8951495033723122, 'bagging_freq': 5, 'min_child_samples': 22, 'lambda_l1': 0.017087801832178697, 'lambda_l2': 0.568984598249286, 'max_depth': 5, 'max_bin': 2523, 'min_data_in_leaf': 123, 'extra_trees': False, 'path_smooth': 0.19603587455307991}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:14,668] Trial 985 finished with value: 0.24725275266096355 and parameters: {'num_leaves': 124, 'learning_rate': 0.15456789770001103, 'feature_fraction': 0.7202822906686583, 'bagging_fraction': 0.9140174365310917, 'bagging_freq': 3, 'min_child_samples': 25, 'lambda_l1': 0.008702708428830553, 'lambda_l2': 0.16318232556063222, 'max_depth': 4, 'max_bin': 2373, 'min_data_in_leaf': 131, 'extra_trees': False, 'path_smooth': 0.30397881006027966}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:20,735] Trial 986 finished with value: 0.2535608662100942 and parameters: {'num_leaves': 136, 'learning_rate': 0.1480481361703034, 'feature_fraction': 0.7354732272498273, 'bagging_fraction': 0.8676239818437977, 'bagging_freq': 5, 'min_child_samples': 27, 'lambda_l1': 0.012785490027448252, 'lambda_l2': 0.6992622161514207, 'max_depth': 5, 'max_bin': 2725, 'min_data_in_leaf': 140, 'extra_trees': False, 'path_smooth': 0.1717940957387554}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:27,723] Trial 987 finished with value: 0.257283693300272 and parameters: {'num_leaves': 148, 'learning_rate': 0.13517541477691303, 'feature_fraction': 0.7239912324233742, 'bagging_fraction': 0.9382207289834675, 'bagging_freq': 5, 'min_child_samples': 21, 'lambda_l1': 0.025881167988470562, 'lambda_l2': 1.9686080513008264, 'max_depth': 6, 'max_bin': 3204, 'min_data_in_leaf': 134, 'extra_trees': False, 'path_smooth': 0.5887887785736174}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:31,951] Trial 988 finished with value: 0.25675094219935796 and parameters: {'num_leaves': 67, 'learning_rate': 0.15805596569290795, 'feature_fraction': 0.7409820748950788, 'bagging_fraction': 0.8899714870164648, 'bagging_freq': 5, 'min_child_samples': 24, 'lambda_l1': 0.006810249863329538, 'lambda_l2': 1.0613969252845872, 'max_depth': 5, 'max_bin': 2331, 'min_data_in_leaf': 148, 'extra_trees': False, 'path_smooth': 0.21465999175664924}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:36,716] Trial 989 finished with value: 0.2582493450972402 and parameters: {'num_leaves': 143, 'learning_rate': 0.14364440775174675, 'feature_fraction': 0.7301330429317923, 'bagging_fraction': 0.880035477172544, 'bagging_freq': 5, 'min_child_samples': 19, 'lambda_l1': 0.019994247408587438, 'lambda_l2': 0.8307983039471029, 'max_depth': 4, 'max_bin': 2549, 'min_data_in_leaf': 127, 'extra_trees': False, 'path_smooth': 0.32653193149693094}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:39,635] Trial 990 finished with value: 0.2659894742437371 and parameters: {'num_leaves': 128, 'learning_rate': 0.1507623610799983, 'feature_fraction': 0.7488996977528412, 'bagging_fraction': 0.9010237899666443, 'bagging_freq': 5, 'min_child_samples': 23, 'lambda_l1': 0.06187649490705517, 'lambda_l2': 1.4142308112409847, 'max_depth': 5, 'max_bin': 495, 'min_data_in_leaf': 122, 'extra_trees': False, 'path_smooth': 0.9271433560441247}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:42,927] Trial 991 finished with value: 0.29258663518614586 and parameters: {'num_leaves': 133, 'learning_rate': 0.17140709004329605, 'feature_fraction': 0.6734150057919513, 'bagging_fraction': 0.8935407427536216, 'bagging_freq': 5, 'min_child_samples': 17, 'lambda_l1': 0.013526341015154163, 'lambda_l2': 0.2537343770736662, 'max_depth': 6, 'max_bin': 2887, 'min_data_in_leaf': 131, 'extra_trees': True, 'path_smooth': 0.2556298690456108}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:47,387] Trial 992 finished with value: 0.2490997816714077 and parameters: {'num_leaves': 141, 'learning_rate': 0.1462717250625143, 'feature_fraction': 0.7099081661694089, 'bagging_fraction': 0.8844830164372113, 'bagging_freq': 3, 'min_child_samples': 28, 'lambda_l1': 0.010184479738452686, 'lambda_l2': 0.5482846367131223, 'max_depth': 5, 'max_bin': 2372, 'min_data_in_leaf': 137, 'extra_trees': False, 'path_smooth': 0.22924225202606813}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:52,778] Trial 993 finished with value: 0.2648764137460581 and parameters: {'num_leaves': 48, 'learning_rate': 0.1651630957141976, 'feature_fraction': 0.7347765472212661, 'bagging_fraction': 0.9292121118467976, 'bagging_freq': 5, 'min_child_samples': 26, 'lambda_l1': 0.017096908198591644, 'lambda_l2': 1.193078763787627, 'max_depth': 4, 'max_bin': 3565, 'min_data_in_leaf': 143, 'extra_trees': False, 'path_smooth': 0.2812202519976718}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:47:57,849] Trial 994 finished with value: 0.26087891294422133 and parameters: {'num_leaves': 137, 'learning_rate': 0.15386903586000453, 'feature_fraction': 0.7264241394250622, 'bagging_fraction': 0.9253825701600495, 'bagging_freq': 5, 'min_child_samples': 21, 'lambda_l1': 0.0235964691321834, 'lambda_l2': 0.9434476879308508, 'max_depth': 5, 'max_bin': 2579, 'min_data_in_leaf': 134, 'extra_trees': False, 'path_smooth': 0.7811131217369414}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:48:03,351] Trial 995 finished with value: 0.26650287787542576 and parameters: {'num_leaves': 165, 'learning_rate': 0.1392989327277499, 'feature_fraction': 0.7451063965230978, 'bagging_fraction': 0.8745932188865354, 'bagging_freq': 5, 'min_child_samples': 30, 'lambda_l1': 0.012173184680805773, 'lambda_l2': 0.8028549040935768, 'max_depth': 4, 'max_bin': 2229, 'min_data_in_leaf': 128, 'extra_trees': False, 'path_smooth': 0.2014723507187632}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:48:08,453] Trial 996 finished with value: 0.26208828360517533 and parameters: {'num_leaves': 132, 'learning_rate': 0.1496341028680787, 'feature_fraction': 0.7195208531635023, 'bagging_fraction': 0.9050586004628938, 'bagging_freq': 2, 'min_child_samples': 23, 'lambda_l1': 0.005547937204760764, 'lambda_l2': 0.6336374627216633, 'max_depth': 5, 'max_bin': 2720, 'min_data_in_leaf': 140, 'extra_trees': False, 'path_smooth': 0.24637469184320804}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:48:13,704] Trial 997 finished with value: 0.2706067647351047 and parameters: {'num_leaves': 123, 'learning_rate': 0.15918196830952877, 'feature_fraction': 0.7389289062099406, 'bagging_fraction': 0.8626935825451301, 'bagging_freq': 5, 'min_child_samples': 25, 'lambda_l1': 0.07846276367558531, 'lambda_l2': 1.6064980990714528, 'max_depth': 4, 'max_bin': 2421, 'min_data_in_leaf': 125, 'extra_trees': False, 'path_smooth': 0.8418763327837779}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:48:18,608] Trial 998 finished with value: 0.2403734847007528 and parameters: {'num_leaves': 145, 'learning_rate': 0.1435875410566708, 'feature_fraction': 0.7140858042182442, 'bagging_fraction': 0.8987941607894279, 'bagging_freq': 5, 'min_child_samples': 19, 'lambda_l1': 0.008424886709069743, 'lambda_l2': 1.0345300696839814, 'max_depth': 5, 'max_bin': 2476, 'min_data_in_leaf': 133, 'extra_trees': False, 'path_smooth': 0.44441344307425223}. Best is trial 849 with value: 0.23516370205179218.
# [I 2025-07-12 14:48:24,989] Trial 999 finished with value: 0.25729499899814173 and parameters: {'num_leaves': 146, 'learning_rate': 0.1365758774229087, 'feature_fraction': 0.7053102083941, 'bagging_fraction': 0.9091040475325604, 'bagging_freq': 5, 'min_child_samples': 16, 'lambda_l1': 0.007786237505198781, 'lambda_l2': 0.9906828065380826, 'max_depth': 6, 'max_bin': 2859, 'min_data_in_leaf': 137, 'extra_trees': False, 'path_smooth': 0.5328691764584453}. Best is trial 849 with value: 0.23516370205179218.
# Mejores hiperparámetros encontrados:
# {'num_leaves': 135, 'learning_rate': 0.14611601332965418, 'feature_fraction': 0.7273001788761106, 'bagging_fraction': 0.9490069298468029, 'bagging_freq': 5, 'min_child_samples': 21, 'lambda_l1': 0.00791440152652908, 'lambda_l2': 1.2442984868483244, 'max_depth': 5, 'max_bin': 2558, 'min_data_in_leaf': 136, 'extra_trees': False, 'path_smooth': 0.8043431206300923}
# Mejor MAE: 0.2352

# %%
best_params = study.best_params.copy()
best_params.update({
    "objective": "regression",
    "metric": ["rmse", "mape"],
    "verbosity": -1,
    "n_jobs": -1,
    "seed": 42
})

model = lgb.train(
    best_params,
    lgb.Dataset(X_train, label=y_train),
    valid_sets=[lgb.Dataset(X_val, label=y_val)],
    num_boost_round=1000,
    callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
)

# Asegurar las mismas columnas
X_kgl = df_kgl[X_train.columns]  # Misma estructura

# === 9. Hacer predicción sobre nuevos datos ===
preds_kgl = model.predict(X_kgl)

# %%
result = pd.DataFrame({"product_id": X_kgl["product_id"],  "tn": preds_kgl})

result = result[result["product_id"].isin(productos_ok["product_id"])]

result
# Out:
#        product_id           tn
# 35          20001  1320.066819
# 71          20002  1110.028353
# 107         20003   862.063908
# 143         20004   576.955389
# 179         20005   593.032956
# ...           ...          ...
# 22358       20962     2.397953
# 22362       20975     2.397953
# 22366       20995     1.819153
# 22370       21087     1.819153
# 22374       21214     1.819153
#
# [780 rows x 2 columns]

# %%
result.to_csv(f"{study_name}.csv",sep=',', index=False)

# %%
import matplotlib.pyplot as plt
from lightgbm import plot_importance  # Importación específica
# Visualizar importancia de características
plot_importance(model, importance_type='gain', max_num_features=10)  # Usar la función importada
plt.show()

# %%
import webbrowser
webbrowser.open("https://www.soundhelix.com/examples/mp3/SoundHelix-Song-3.mp3")
# Out:
# True
