# %%
import pandas as pd
import gc
import numpy as np
from sklearn.preprocessing import LabelEncoder
from scipy.stats import linregress

study_name = "lightgbm7"

df = pd.read_csv("../datasets/sell-in.txt.gz", sep="\t")
productos = pd.read_csv("../datasets/tb_productos.txt", sep="\t")
productos = productos.drop_duplicates(subset=["product_id"],keep="first")  # Eliminar duplicados por si acaso
stocks = pd.read_csv("../datasets/tb_stocks.txt", sep="\t")

productos_ok = pd.read_csv("https://storage.googleapis.com/open-courses/austral2025-af91/labo3v/product_id_apredecir201912.txt", sep="\t")
df = df[df["product_id"].isin(productos_ok["product_id"])]
df = df.groupby(by=["periodo","product_id"]).agg({"tn":"sum","plan_precios_cuidados":"first"}).reset_index()


productos_list = df['product_id'].unique()
periodos = df['periodo'].unique()
idx = pd.MultiIndex.from_product([productos_list, periodos], names=['product_id', 'periodo'])
completo = idx.to_frame(index=False)
# 4 filtrar combinaciones periodo_producto
completo = completo.merge(df, on=['periodo', 'product_id'], how='left')
nacimiento_producto = df.groupby('product_id')['periodo'].min().rename('nacimiento_producto')

completo = completo.merge(nacimiento_producto, on='product_id', how='left')
completo = completo[completo['periodo'] >= completo['nacimiento_producto']]



df = pd.merge(completo, productos, how="left", on="product_id")
df = df.merge(stocks, how="left", on=["product_id", "periodo"])

df["periodo"] = pd.to_datetime(df["periodo"], format="%Y%m")

df["mes"] = df["periodo"].dt.month
df["year"] = df["periodo"].dt.year
df["quarter"] = df["periodo"].dt.quarter

# totales por cat1 por periodo
df["cat1_total"] = df.groupby(["periodo", "cat1"])["tn"].transform("sum")
# totales por cat2 por periodo
df["cat2_total"] = df.groupby(["periodo", "cat2"])["tn"].transform("sum")
# totales por cat3 por periodo
df["cat3_total"] = df.groupby(["periodo", "cat3"])["tn"].transform("sum")


# shift t-1 a t12
meses = ["tn"]
for i in range(1, 13):
    df[f"tn_t{i}"] = df.groupby("product_id")["tn"].shift(i)
    df[f"delta_t{i}"] = df[f"tn"] / df[f"tn_t{i}"]
    meses.append(f"tn_t{i}")
    df[f"cat1_t{i}"] = df.groupby("product_id")["cat1_total"].shift(i)
    df[f"cat2_t{i}"] = df.groupby("product_id")["cat2_total"].shift(i)
    df[f"cat3_t{i}"] = df.groupby("product_id")["cat3_total"].shift(i)
    
    
df["promedio_t12"] = df[meses].mean(axis=1)
df["promedio_t6"] = df[meses[:6]].mean(axis=1)

# Función para calcular la pendiente de una serie temporal
def calcular_pendiente(serie):
    datos = serie.dropna().values
    if len(datos) < 2:  # Mínimo 2 puntos para una regresión
        return np.nan
    x = np.arange(len(datos))  # [0, 1, 2, ..., n-1] (representa el tiempo)
    slope, _, _, _, _ = linregress(x, datos)
    return slope

# Aplicamos la función por grupo (producto) y reindexamos para alinear con df
df["pendiente_reg_12"] = (
    df.groupby("product_id")[meses]
    .apply(lambda grupo: grupo.apply(calcular_pendiente, axis=1))
    .reset_index(level=0, drop=True)  # Eliminamos el nivel de grupo para alinear índices
)

df['media_movil_3m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(3).mean())
df['media_movil_6m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(6).mean())
df['media_movil_12m'] = df.groupby('product_id')['tn'].transform(lambda x: x.rolling(12).mean())

# target t+2
df["target"] = df.groupby("product_id")["tn"].shift(-2)




cat_cols = ['cat1', 'cat2', 'cat3', 'brand', 'plan_precios_cuidados']
for col in cat_cols:
    if col in df.columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
        
del completo, productos, stocks
gc.collect()
df
# Out:
#        product_id    periodo          tn  plan_precios_cuidados  \
# 0           20001 2017-01-01   934.77222                      0
# 1           20001 2017-02-01   798.01620                      0
# 2           20001 2017-03-01  1303.35771                      0
# 3           20001 2017-04-01  1069.96130                      0
# 4           20001 2017-05-01  1502.20132                      0
# ...           ...        ...         ...                    ...
# 22370       21087 2019-12-01     1.02205                      0
# 22371       21214 2019-09-01     0.34250                      0
# 22372       21214 2019-10-01     0.21735                      0
# 22373       21214 2019-11-01     0.84012                      0
# 22374       21214 2019-12-01     0.24428                      0
#
#        nacimiento_producto  cat1  cat2  cat3  brand  sku_size  ...  cat1_t12  \
# 0                   201701     1    10    47      0      3000  ...       NaN
# 1                   201701     1    10    47      0      3000  ...       NaN
# 2                   201701     1    10    47      0      3000  ...       NaN
# 3                   201701     1    10    47      0      3000  ...       NaN
# 4                   201701     1    10    47      0      3000  ...       NaN
# ...                    ...   ...   ...   ...    ...       ...  ...       ...
# 22370               201909     2     3     3     23        65  ...       NaN
# 22371               201909     2     3    65     23        50  ...       NaN
# 22372               201909     2     3    65     23        50  ...       NaN
# 22373               201909     2     3    65     23        50  ...       NaN
# 22374               201909     2     3    65     23        50  ...       NaN
#
#        cat2_t12  cat3_t12  promedio_t12  promedio_t6  pendiente_reg_12  \
# 0           NaN       NaN    934.772220   934.772220               NaN
# 1           NaN       NaN    866.394210   866.394210        136.756020
# 2           NaN       NaN   1012.048710  1012.048710       -184.292745
# 3           NaN       NaN   1026.526858  1026.526858        -91.090875
# 4           NaN       NaN   1121.661750  1121.661750       -140.680330
# ...         ...       ...           ...          ...               ...
# 22370       NaN       NaN      0.907423     0.907423         -0.265787
# 22371       NaN       NaN      0.342500     0.342500               NaN
# 22372       NaN       NaN      0.279925     0.279925          0.125150
# 22373       NaN       NaN      0.466657     0.466657         -0.248810
# 22374       NaN       NaN      0.411062     0.411062         -0.032811
#
#        media_movil_3m  media_movil_6m  media_movil_12m      target
# 0                 NaN             NaN              NaN  1303.35771
# 1                 NaN             NaN              NaN  1069.96130
# 2         1012.048710             NaN              NaN  1502.20132
# 3         1057.111737             NaN              NaN  1520.06539
# 4         1291.840110             NaN              NaN  1030.67391
# ...               ...             ...              ...         ...
# 22370        1.109907             NaN              NaN         NaN
# 22371             NaN             NaN              NaN     0.84012
# 22372             NaN             NaN              NaN     0.24428
# 22373        0.466657             NaN              NaN         NaN
# 22374        0.433917             NaN              NaN         NaN
#
# [22375 rows x 84 columns]

# %%
df_kgl = df[df["periodo"] == "2019-12-01"]
df_kgl["periodo"] = df_kgl["periodo"].astype(int)
df = df[~df["periodo"].isin(["2019-11-01", "2019-12-01"])]
# Out:
# C:\Users\carre\AppData\Local\Temp\ipykernel_17024\2505419454.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kgl["periodo"] = df_kgl["periodo"].astype(int)
# C:\Users\carre\AppData\Local\Temp\ipykernel_17024\2505419454.py:3: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   df = df[~df["periodo"].isin(["2019-11-01", "2019-12-01"])]

# %%
# Separar features y target
X = df.drop(columns=["target"])
y = df["target"]
X_train = X[X["periodo"] < '2019-10-01']
X_train["periodo"] = X_train["periodo"].astype(int)
y_train = y[X["periodo"] < '2019-10-01']

X_val = X[X["periodo"] == '2019-10-01']
X_val["periodo"] = X_val["periodo"].astype(int)
y_val = y[X["periodo"] == '2019-10-01']
# Out:
# C:\Users\carre\AppData\Local\Temp\ipykernel_17024\4176657755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["periodo"] = X_train["periodo"].astype(int)
# C:\Users\carre\AppData\Local\Temp\ipykernel_17024\4176657755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_val["periodo"] = X_val["periodo"].astype(int)

# %%
import lightgbm as lgb
import optuna
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os

def custom_mape_loss(y_true, y_pred):
    numerator = np.sum(np.abs(y_true - y_pred))
    denominator = np.sum(np.abs(y_true))
    epsilon = np.finfo(float).eps  # Valor muy pequeño para evitar división por cero
    return numerator / (denominator + epsilon)

# === 2. Definición del objetivo para Optuna ===
def objective(trial):
    params = {
        "sample_weight": X_train["tn"].to_list(),
        "objective": "regression",
        "metric": ["rmse", "mape"],
        "boosting_type": "gbdt",
        "verbosity": -1,
        "n_jobs": -1,
        "seed": 42,
        "num_leaves": trial.suggest_int("num_leaves", 20, 200),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.2),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 0.9),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.7, 0.95),
        "bagging_freq": trial.suggest_int("bagging_freq", 0, 5),
        "min_child_samples": trial.suggest_int("min_child_samples", 10, 50),
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-3, 5.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-3, 5.0, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "max_bin": trial.suggest_int("max_bin", 10, 2000),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 20, 200),
        "extra_trees": trial.suggest_categorical("extra_trees", [True, False]),
        "path_smooth": trial.suggest_float("path_smooth", 0, 1),  # Nuevo parámetro útil
    }

    model = lgb.train(
        params,
        lgb.Dataset(X_train, label=y_train),
        valid_sets=[lgb.Dataset(X_val, label=y_val)],
        num_boost_round=1000,
        callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)]
    )

    preds = model.predict(X_val)
    
    
    
    mape = custom_mape_loss(y_val, preds)
    # rmse = mean_squared_error(y_val, preds)
    # rmse = np.sqrt(rmse)
    
    #rmse = mean_squared_error(y_val, preds, squared=False)
    return mape

# === 3. Configurar almacenamiento SQLite para Optuna ===
os.makedirs("optuna_storage", exist_ok=True)
DB_PATH = "optuna_storage/optuna.db"
STUDY_NAME = study_name
storage_url = f"sqlite:///{DB_PATH}"

# === 4. Crear o cargar estudio ===
study = optuna.create_study(
    study_name=STUDY_NAME,
    storage=storage_url,
    direction="minimize",
    load_if_exists=True
)

# === 5. Ejecutar optimización ===
study.optimize(objective, n_trials=150)

# === 6. Mostrar resultados ===
print("Mejores hiperparámetros encontrados:")
print(study.best_params)
print(f"Mejor MAE: {study.best_value:.4f}")
# Out:
# [I 2025-07-12 01:52:32,797] A new study created in RDB with name: lightgbm7
# [I 2025-07-12 01:52:37,339] Trial 0 finished with value: 0.2757287764662241 and parameters: {'num_leaves': 185, 'learning_rate': 0.07670438956994839, 'feature_fraction': 0.8666780597460709, 'bagging_fraction': 0.915290753193335, 'bagging_freq': 1, 'min_child_samples': 39, 'lambda_l1': 0.34887393940577843, 'lambda_l2': 3.2312397648245814, 'max_depth': 7, 'max_bin': 1878, 'min_data_in_leaf': 24, 'extra_trees': False, 'path_smooth': 0.09718751816644466}. Best is trial 0 with value: 0.2757287764662241.
# [I 2025-07-12 01:52:40,734] Trial 1 finished with value: 0.29346073886988944 and parameters: {'num_leaves': 31, 'learning_rate': 0.008288470931048725, 'feature_fraction': 0.7700632011524733, 'bagging_fraction': 0.7527160453802625, 'bagging_freq': 1, 'min_child_samples': 37, 'lambda_l1': 0.0023619365087964397, 'lambda_l2': 0.02843908368547846, 'max_depth': 4, 'max_bin': 765, 'min_data_in_leaf': 188, 'extra_trees': True, 'path_smooth': 0.8960468513104242}. Best is trial 0 with value: 0.2757287764662241.
# [I 2025-07-12 01:52:42,786] Trial 2 finished with value: 0.320539116424007 and parameters: {'num_leaves': 80, 'learning_rate': 0.12379215392267622, 'feature_fraction': 0.8346348206018307, 'bagging_fraction': 0.7199566924847204, 'bagging_freq': 1, 'min_child_samples': 41, 'lambda_l1': 0.0217083890275712, 'lambda_l2': 0.3810450009075515, 'max_depth': 6, 'max_bin': 666, 'min_data_in_leaf': 193, 'extra_trees': True, 'path_smooth': 0.46444113447928204}. Best is trial 0 with value: 0.2757287764662241.
# [I 2025-07-12 01:52:46,712] Trial 3 finished with value: 0.30380633767585385 and parameters: {'num_leaves': 111, 'learning_rate': 0.0041761467254554, 'feature_fraction': 0.6538053219428724, 'bagging_fraction': 0.9313180131994901, 'bagging_freq': 3, 'min_child_samples': 45, 'lambda_l1': 0.1099191826779457, 'lambda_l2': 1.6117095703894495, 'max_depth': 6, 'max_bin': 63, 'min_data_in_leaf': 127, 'extra_trees': False, 'path_smooth': 0.01922591284015418}. Best is trial 0 with value: 0.2757287764662241.
# [I 2025-07-12 01:52:49,205] Trial 4 finished with value: 0.3308619578740705 and parameters: {'num_leaves': 106, 'learning_rate': 0.18398893671763056, 'feature_fraction': 0.6304373890010689, 'bagging_fraction': 0.7904800935874574, 'bagging_freq': 0, 'min_child_samples': 17, 'lambda_l1': 0.1748412177637866, 'lambda_l2': 0.062220802173679854, 'max_depth': 10, 'max_bin': 1410, 'min_data_in_leaf': 150, 'extra_trees': True, 'path_smooth': 0.14509922553208665}. Best is trial 0 with value: 0.2757287764662241.
# [I 2025-07-12 01:52:51,814] Trial 5 finished with value: 0.25331591949914406 and parameters: {'num_leaves': 131, 'learning_rate': 0.17538532959104114, 'feature_fraction': 0.7752273309169004, 'bagging_fraction': 0.9154665066684275, 'bagging_freq': 0, 'min_child_samples': 32, 'lambda_l1': 0.004905748073835479, 'lambda_l2': 0.5466481718756888, 'max_depth': 5, 'max_bin': 1077, 'min_data_in_leaf': 154, 'extra_trees': False, 'path_smooth': 0.7435364027595323}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:52:57,761] Trial 6 finished with value: 0.2605742084750003 and parameters: {'num_leaves': 86, 'learning_rate': 0.01456474044321104, 'feature_fraction': 0.8687039662528412, 'bagging_fraction': 0.9306483709764327, 'bagging_freq': 4, 'min_child_samples': 36, 'lambda_l1': 0.004170757411154408, 'lambda_l2': 0.006151463748627816, 'max_depth': 7, 'max_bin': 353, 'min_data_in_leaf': 78, 'extra_trees': False, 'path_smooth': 0.5370353697790293}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:00,525] Trial 7 finished with value: 0.32748680504335076 and parameters: {'num_leaves': 71, 'learning_rate': 0.17699758717553984, 'feature_fraction': 0.6833779387613651, 'bagging_fraction': 0.9134598582942812, 'bagging_freq': 1, 'min_child_samples': 21, 'lambda_l1': 0.001362309302910846, 'lambda_l2': 1.1288279910833279, 'max_depth': 6, 'max_bin': 1600, 'min_data_in_leaf': 40, 'extra_trees': False, 'path_smooth': 0.5784942555708928}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:03,494] Trial 8 finished with value: 0.27464993293558515 and parameters: {'num_leaves': 137, 'learning_rate': 0.15437530156568077, 'feature_fraction': 0.7784876376963952, 'bagging_fraction': 0.730103644930718, 'bagging_freq': 2, 'min_child_samples': 25, 'lambda_l1': 0.12664057849983892, 'lambda_l2': 0.007157347203778817, 'max_depth': 12, 'max_bin': 379, 'min_data_in_leaf': 84, 'extra_trees': False, 'path_smooth': 0.3084513504824228}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:09,254] Trial 9 finished with value: 0.4189277123981304 and parameters: {'num_leaves': 28, 'learning_rate': 0.0019514890791689288, 'feature_fraction': 0.6280892647590078, 'bagging_fraction': 0.755314348568018, 'bagging_freq': 2, 'min_child_samples': 26, 'lambda_l1': 0.8599095171583422, 'lambda_l2': 0.004580582360257183, 'max_depth': 12, 'max_bin': 817, 'min_data_in_leaf': 80, 'extra_trees': True, 'path_smooth': 0.8909395140015015}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:12,032] Trial 10 finished with value: 0.25852487096537713 and parameters: {'num_leaves': 174, 'learning_rate': 0.0832286124203926, 'feature_fraction': 0.713511994185876, 'bagging_fraction': 0.8603127316845796, 'bagging_freq': 5, 'min_child_samples': 11, 'lambda_l1': 0.016945563812050195, 'lambda_l2': 0.29237687894318815, 'max_depth': 3, 'max_bin': 1236, 'min_data_in_leaf': 150, 'extra_trees': False, 'path_smooth': 0.7378457615903894}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:14,738] Trial 11 finished with value: 0.26214500490778264 and parameters: {'num_leaves': 177, 'learning_rate': 0.07987392793709344, 'feature_fraction': 0.7122271189737854, 'bagging_fraction': 0.8604462735127437, 'bagging_freq': 5, 'min_child_samples': 10, 'lambda_l1': 0.016872435036992043, 'lambda_l2': 0.31773079159744977, 'max_depth': 3, 'max_bin': 1218, 'min_data_in_leaf': 155, 'extra_trees': False, 'path_smooth': 0.7328248615500315}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:18,155] Trial 12 finished with value: 0.26109873398105843 and parameters: {'num_leaves': 142, 'learning_rate': 0.1190544698988644, 'feature_fraction': 0.732142072028478, 'bagging_fraction': 0.8605850401511812, 'bagging_freq': 5, 'min_child_samples': 32, 'lambda_l1': 0.01369922056874759, 'lambda_l2': 0.3114516292565769, 'max_depth': 4, 'max_bin': 1166, 'min_data_in_leaf': 154, 'extra_trees': False, 'path_smooth': 0.7612663174339299}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:22,000] Trial 13 finished with value: 0.2615165391877383 and parameters: {'num_leaves': 158, 'learning_rate': 0.04850778502588201, 'feature_fraction': 0.807418334209499, 'bagging_fraction': 0.8620053064856429, 'bagging_freq': 4, 'min_child_samples': 14, 'lambda_l1': 0.005905289907359351, 'lambda_l2': 0.13127872828926615, 'max_depth': 4, 'max_bin': 1607, 'min_data_in_leaf': 121, 'extra_trees': False, 'path_smooth': 0.6919075144186067}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:24,547] Trial 14 finished with value: 0.2616563798696715 and parameters: {'num_leaves': 195, 'learning_rate': 0.14776377779466154, 'feature_fraction': 0.7001976931283365, 'bagging_fraction': 0.8256721314257265, 'bagging_freq': 0, 'min_child_samples': 30, 'lambda_l1': 0.030603731806589023, 'lambda_l2': 0.8078806243220328, 'max_depth': 3, 'max_bin': 1046, 'min_data_in_leaf': 173, 'extra_trees': False, 'path_smooth': 0.9791690821629625}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:28,105] Trial 15 finished with value: 0.2577550234754691 and parameters: {'num_leaves': 156, 'learning_rate': 0.19926952283096136, 'feature_fraction': 0.7428886006819138, 'bagging_fraction': 0.8842037956651597, 'bagging_freq': 3, 'min_child_samples': 50, 'lambda_l1': 0.007019030192328105, 'lambda_l2': 4.806430490596418, 'max_depth': 9, 'max_bin': 1317, 'min_data_in_leaf': 134, 'extra_trees': False, 'path_smooth': 0.4166456926587714}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:32,342] Trial 16 finished with value: 0.2658846714324596 and parameters: {'num_leaves': 127, 'learning_rate': 0.19487361561831384, 'feature_fraction': 0.7599672353905123, 'bagging_fraction': 0.895836122833892, 'bagging_freq': 3, 'min_child_samples': 49, 'lambda_l1': 4.901526104642484, 'lambda_l2': 4.089918745689732, 'max_depth': 9, 'max_bin': 1965, 'min_data_in_leaf': 105, 'extra_trees': False, 'path_smooth': 0.3703644253232835}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:37,467] Trial 17 finished with value: 0.26054621922958787 and parameters: {'num_leaves': 158, 'learning_rate': 0.15926532904705062, 'feature_fraction': 0.8038903316228255, 'bagging_fraction': 0.8978599307551942, 'bagging_freq': 3, 'min_child_samples': 50, 'lambda_l1': 0.001064939761087577, 'lambda_l2': 2.240731100451697, 'max_depth': 9, 'max_bin': 1465, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.2647084355317424}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:40,260] Trial 18 finished with value: 0.335056994799689 and parameters: {'num_leaves': 118, 'learning_rate': 0.19848917817761172, 'feature_fraction': 0.7422175700185017, 'bagging_fraction': 0.8286447689090569, 'bagging_freq': 4, 'min_child_samples': 42, 'lambda_l1': 0.004916374560268825, 'lambda_l2': 0.001453362311990245, 'max_depth': 10, 'max_bin': 922, 'min_data_in_leaf': 108, 'extra_trees': True, 'path_smooth': 0.6217433432007153}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:43,178] Trial 19 finished with value: 0.2674027758041771 and parameters: {'num_leaves': 161, 'learning_rate': 0.16535999790092795, 'feature_fraction': 0.8264594713712984, 'bagging_fraction': 0.9467197780703382, 'bagging_freq': 2, 'min_child_samples': 46, 'lambda_l1': 0.006958107259191822, 'lambda_l2': 0.7735069137049337, 'max_depth': 8, 'max_bin': 628, 'min_data_in_leaf': 173, 'extra_trees': False, 'path_smooth': 0.439012911192059}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:46,440] Trial 20 finished with value: 0.26322609443533407 and parameters: {'num_leaves': 98, 'learning_rate': 0.12434407004897603, 'feature_fraction': 0.7918413093978517, 'bagging_fraction': 0.8838621758745884, 'bagging_freq': 0, 'min_child_samples': 33, 'lambda_l1': 0.05200634366692869, 'lambda_l2': 4.778021755128608, 'max_depth': 5, 'max_bin': 1710, 'min_data_in_leaf': 96, 'extra_trees': False, 'path_smooth': 0.2317109080264923}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:49,586] Trial 21 finished with value: 0.25599854121799215 and parameters: {'num_leaves': 166, 'learning_rate': 0.09157992257081396, 'feature_fraction': 0.6774205099760796, 'bagging_fraction': 0.8727060832354167, 'bagging_freq': 5, 'min_child_samples': 21, 'lambda_l1': 0.011803663519803179, 'lambda_l2': 0.1449337604639918, 'max_depth': 5, 'max_bin': 1228, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.8117938412367595}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:53,049] Trial 22 finished with value: 0.2546734883181853 and parameters: {'num_leaves': 144, 'learning_rate': 0.10264905285667546, 'feature_fraction': 0.6714010442633853, 'bagging_fraction': 0.8788792466540446, 'bagging_freq': 4, 'min_child_samples': 21, 'lambda_l1': 0.009751720875401828, 'lambda_l2': 0.10666171606860889, 'max_depth': 5, 'max_bin': 1369, 'min_data_in_leaf': 133, 'extra_trees': False, 'path_smooth': 0.836641671920798}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:53:56,957] Trial 23 finished with value: 0.2726516069049304 and parameters: {'num_leaves': 137, 'learning_rate': 0.0539422554062223, 'feature_fraction': 0.6706956526676973, 'bagging_fraction': 0.8432549492434236, 'bagging_freq': 4, 'min_child_samples': 20, 'lambda_l1': 0.050872262051946865, 'lambda_l2': 0.07017996444953574, 'max_depth': 5, 'max_bin': 1023, 'min_data_in_leaf': 170, 'extra_trees': False, 'path_smooth': 0.8386237482130603}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:00,772] Trial 24 finished with value: 0.2568325147160368 and parameters: {'num_leaves': 146, 'learning_rate': 0.09797557868291351, 'feature_fraction': 0.6534784844954286, 'bagging_fraction': 0.7990825772665325, 'bagging_freq': 5, 'min_child_samples': 24, 'lambda_l1': 0.002958408152611831, 'lambda_l2': 0.028938523104154436, 'max_depth': 5, 'max_bin': 1444, 'min_data_in_leaf': 141, 'extra_trees': False, 'path_smooth': 0.832914926648532}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:04,355] Trial 25 finished with value: 0.2612149461033358 and parameters: {'num_leaves': 200, 'learning_rate': 0.04935702230634546, 'feature_fraction': 0.6143438799818042, 'bagging_fraction': 0.8010547887221462, 'bagging_freq': 4, 'min_child_samples': 28, 'lambda_l1': 0.010357518310529615, 'lambda_l2': 0.14787630511288197, 'max_depth': 5, 'max_bin': 1111, 'min_data_in_leaf': 116, 'extra_trees': False, 'path_smooth': 0.9968415971093862}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:06,774] Trial 26 finished with value: 0.3171806297854061 and parameters: {'num_leaves': 125, 'learning_rate': 0.10672899930398276, 'feature_fraction': 0.6869306148554603, 'bagging_fraction': 0.8787826988025526, 'bagging_freq': 5, 'min_child_samples': 20, 'lambda_l1': 0.0021681601022727134, 'lambda_l2': 0.03253656297318909, 'max_depth': 6, 'max_bin': 909, 'min_data_in_leaf': 164, 'extra_trees': True, 'path_smooth': 0.6518508912490925}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:09,593] Trial 27 finished with value: 0.2644793412189868 and parameters: {'num_leaves': 50, 'learning_rate': 0.13367348070759105, 'feature_fraction': 0.8972513709194969, 'bagging_fraction': 0.9068145201084225, 'bagging_freq': 4, 'min_child_samples': 16, 'lambda_l1': 0.03775247305609589, 'lambda_l2': 0.14627248263103076, 'max_depth': 4, 'max_bin': 1772, 'min_data_in_leaf': 59, 'extra_trees': False, 'path_smooth': 0.8126544849734969}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:16,339] Trial 28 finished with value: 0.2609887240377267 and parameters: {'num_leaves': 165, 'learning_rate': 0.03173009771818547, 'feature_fraction': 0.7091845327190867, 'bagging_fraction': 0.9471246103738835, 'bagging_freq': 5, 'min_child_samples': 22, 'lambda_l1': 0.009361606121123394, 'lambda_l2': 0.01644045430839411, 'max_depth': 7, 'max_bin': 1317, 'min_data_in_leaf': 184, 'extra_trees': False, 'path_smooth': 0.9312844477504635}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:22,447] Trial 29 finished with value: 0.2541671009106474 and parameters: {'num_leaves': 183, 'learning_rate': 0.06477403333354283, 'feature_fraction': 0.6534210610534134, 'bagging_fraction': 0.920617182724789, 'bagging_freq': 2, 'min_child_samples': 28, 'lambda_l1': 0.4181651805257351, 'lambda_l2': 0.5104755978989788, 'max_depth': 8, 'max_bin': 1513, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.7928995991506256}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:28,818] Trial 30 finished with value: 0.2738126819982812 and parameters: {'num_leaves': 184, 'learning_rate': 0.06410742642669667, 'feature_fraction': 0.6075146918614803, 'bagging_fraction': 0.9263391499191597, 'bagging_freq': 2, 'min_child_samples': 34, 'lambda_l1': 0.6497916161162384, 'lambda_l2': 0.5572319230815557, 'max_depth': 8, 'max_bin': 1508, 'min_data_in_leaf': 200, 'extra_trees': False, 'path_smooth': 0.6434676681750956}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:32,805] Trial 31 finished with value: 0.2687158074251092 and parameters: {'num_leaves': 170, 'learning_rate': 0.09383750985369503, 'feature_fraction': 0.6550353627053853, 'bagging_fraction': 0.918478526264796, 'bagging_freq': 0, 'min_child_samples': 29, 'lambda_l1': 2.4536193449757384, 'lambda_l2': 0.14068335240186997, 'max_depth': 8, 'max_bin': 1799, 'min_data_in_leaf': 137, 'extra_trees': False, 'path_smooth': 0.7981047663186548}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:37,681] Trial 32 finished with value: 0.25698841823749274 and parameters: {'num_leaves': 189, 'learning_rate': 0.06674288018874018, 'feature_fraction': 0.6710317673657402, 'bagging_fraction': 0.9072636896766907, 'bagging_freq': 1, 'min_child_samples': 26, 'lambda_l1': 0.32975862755784474, 'lambda_l2': 0.21831211319986812, 'max_depth': 7, 'max_bin': 1326, 'min_data_in_leaf': 124, 'extra_trees': False, 'path_smooth': 0.7040827960844468}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:41,908] Trial 33 finished with value: 0.2647256171510827 and parameters: {'num_leaves': 148, 'learning_rate': 0.1106394153328916, 'feature_fraction': 0.6387167252133317, 'bagging_fraction': 0.8816626870887706, 'bagging_freq': 3, 'min_child_samples': 17, 'lambda_l1': 0.32242836054559565, 'lambda_l2': 0.5278247253392513, 'max_depth': 6, 'max_bin': 1620, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.9055917796134816}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:44,093] Trial 34 finished with value: 0.3214891587161832 and parameters: {'num_leaves': 181, 'learning_rate': 0.13698494973432887, 'feature_fraction': 0.6886087198943264, 'bagging_fraction': 0.8951206310664518, 'bagging_freq': 1, 'min_child_samples': 23, 'lambda_l1': 0.0258377202821917, 'lambda_l2': 0.04576557880052946, 'max_depth': 5, 'max_bin': 1127, 'min_data_in_leaf': 158, 'extra_trees': True, 'path_smooth': 0.8910901845372923}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:48,651] Trial 35 finished with value: 0.2729232204028293 and parameters: {'num_leaves': 131, 'learning_rate': 0.03453010932229278, 'feature_fraction': 0.7687502571355592, 'bagging_fraction': 0.8457397322433479, 'bagging_freq': 1, 'min_child_samples': 39, 'lambda_l1': 0.07894431753300031, 'lambda_l2': 0.09540106458763876, 'max_depth': 6, 'max_bin': 701, 'min_data_in_leaf': 182, 'extra_trees': False, 'path_smooth': 0.7746909975712748}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:52,144] Trial 36 finished with value: 0.26812729605521646 and parameters: {'num_leaves': 146, 'learning_rate': 0.09273991443349146, 'feature_fraction': 0.7328191053211384, 'bagging_fraction': 0.9277395443952183, 'bagging_freq': 4, 'min_child_samples': 28, 'lambda_l1': 0.002610282338743409, 'lambda_l2': 1.6011629264786804, 'max_depth': 7, 'max_bin': 1365, 'min_data_in_leaf': 97, 'extra_trees': False, 'path_smooth': 0.5383865252605359}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:54:54,753] Trial 37 finished with value: 0.2565796675360712 and parameters: {'num_leaves': 119, 'learning_rate': 0.07060525806654011, 'feature_fraction': 0.6631674920328743, 'bagging_fraction': 0.9397977576223272, 'bagging_freq': 2, 'min_child_samples': 31, 'lambda_l1': 1.2809925102775201, 'lambda_l2': 0.4699595245141262, 'max_depth': 4, 'max_bin': 1528, 'min_data_in_leaf': 21, 'extra_trees': True, 'path_smooth': 0.8734357190372776}. Best is trial 5 with value: 0.25331591949914406.
# [I 2025-07-12 01:55:00,482] Trial 38 finished with value: 0.2403512572887128 and parameters: {'num_leaves': 103, 'learning_rate': 0.0853432148260185, 'feature_fraction': 0.6416786509776304, 'bagging_fraction': 0.8738054832631006, 'bagging_freq': 3, 'min_child_samples': 19, 'lambda_l1': 0.2408488277548435, 'lambda_l2': 0.016328068146628127, 'max_depth': 10, 'max_bin': 958, 'min_data_in_leaf': 143, 'extra_trees': False, 'path_smooth': 0.9448376071461212}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:08,985] Trial 39 finished with value: 0.2632758344398197 and parameters: {'num_leaves': 103, 'learning_rate': 0.018221579039899044, 'feature_fraction': 0.6307356632331698, 'bagging_fraction': 0.9186015157862543, 'bagging_freq': 3, 'min_child_samples': 37, 'lambda_l1': 0.16387095366225968, 'lambda_l2': 0.014744097714017043, 'max_depth': 11, 'max_bin': 950, 'min_data_in_leaf': 116, 'extra_trees': False, 'path_smooth': 0.9712387123292361}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:12,045] Trial 40 finished with value: 0.29679010507862646 and parameters: {'num_leaves': 91, 'learning_rate': 0.05861349988974738, 'feature_fraction': 0.6451746536888199, 'bagging_fraction': 0.8390702078527034, 'bagging_freq': 3, 'min_child_samples': 13, 'lambda_l1': 0.2689621567155246, 'lambda_l2': 0.01532733724049314, 'max_depth': 10, 'max_bin': 817, 'min_data_in_leaf': 129, 'extra_trees': True, 'path_smooth': 0.9392725818679559}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:16,235] Trial 41 finished with value: 0.2596996700583874 and parameters: {'num_leaves': 67, 'learning_rate': 0.08683678190563927, 'feature_fraction': 0.6213416821725327, 'bagging_fraction': 0.8703728876499509, 'bagging_freq': 4, 'min_child_samples': 19, 'lambda_l1': 0.5366185994749142, 'lambda_l2': 0.2007540797707219, 'max_depth': 11, 'max_bin': 489, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.8460463343051452}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:23,131] Trial 42 finished with value: 0.25256690118407565 and parameters: {'num_leaves': 111, 'learning_rate': 0.07581907642160389, 'feature_fraction': 0.6739806245453808, 'bagging_fraction': 0.9022080209318482, 'bagging_freq': 2, 'min_child_samples': 15, 'lambda_l1': 0.19301034288469138, 'lambda_l2': 0.0550539987728733, 'max_depth': 11, 'max_bin': 1262, 'min_data_in_leaf': 164, 'extra_trees': False, 'path_smooth': 0.766035336297773}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:25,750] Trial 43 finished with value: 0.2693819678038276 and parameters: {'num_leaves': 111, 'learning_rate': 0.07639627045724634, 'feature_fraction': 0.6927316926789799, 'bagging_fraction': 0.9008454890025515, 'bagging_freq': 2, 'min_child_samples': 14, 'lambda_l1': 0.09544466444202473, 'lambda_l2': 0.046751656602278466, 'max_depth': 11, 'max_bin': 131, 'min_data_in_leaf': 162, 'extra_trees': False, 'path_smooth': 0.7027876662133088}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:29,341] Trial 44 finished with value: 0.2626736170574972 and parameters: {'num_leaves': 82, 'learning_rate': 0.10553473435578258, 'feature_fraction': 0.642974730318046, 'bagging_fraction': 0.9371420676561929, 'bagging_freq': 2, 'min_child_samples': 26, 'lambda_l1': 0.2013793966185844, 'lambda_l2': 0.009353136320888836, 'max_depth': 10, 'max_bin': 1081, 'min_data_in_leaf': 149, 'extra_trees': False, 'path_smooth': 0.5774319585810888}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:36,994] Trial 45 finished with value: 0.2585048106850884 and parameters: {'num_leaves': 113, 'learning_rate': 0.043050396633801606, 'feature_fraction': 0.6001057580392914, 'bagging_fraction': 0.9143217739980276, 'bagging_freq': 1, 'min_child_samples': 18, 'lambda_l1': 0.131942186202627, 'lambda_l2': 0.003645271785659197, 'max_depth': 12, 'max_bin': 1181, 'min_data_in_leaf': 176, 'extra_trees': False, 'path_smooth': 0.7594675505044025}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:43,596] Trial 46 finished with value: 0.2625037727636239 and parameters: {'num_leaves': 100, 'learning_rate': 0.07281969915981293, 'feature_fraction': 0.7195958641792274, 'bagging_fraction': 0.8930821597596597, 'bagging_freq': 3, 'min_child_samples': 16, 'lambda_l1': 1.0621930108455118, 'lambda_l2': 0.07819030027357048, 'max_depth': 11, 'max_bin': 1406, 'min_data_in_leaf': 165, 'extra_trees': False, 'path_smooth': 0.031176528197685127}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:47,730] Trial 47 finished with value: 0.26550864462403057 and parameters: {'num_leaves': 72, 'learning_rate': 0.17949005717065356, 'feature_fraction': 0.8431510129139362, 'bagging_fraction': 0.7543274388720624, 'bagging_freq': 2, 'min_child_samples': 35, 'lambda_l1': 0.6115656381448796, 'lambda_l2': 0.0200342099350343, 'max_depth': 9, 'max_bin': 1274, 'min_data_in_leaf': 154, 'extra_trees': False, 'path_smooth': 0.929554943552224}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:51,940] Trial 48 finished with value: 0.2559787863333401 and parameters: {'num_leaves': 92, 'learning_rate': 0.11671888423021237, 'feature_fraction': 0.6591778672268052, 'bagging_fraction': 0.9267428166910112, 'bagging_freq': 0, 'min_child_samples': 12, 'lambda_l1': 0.22232553123975832, 'lambda_l2': 1.1864781521394223, 'max_depth': 10, 'max_bin': 1666, 'min_data_in_leaf': 125, 'extra_trees': False, 'path_smooth': 0.8608536846686072}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:56,567] Trial 49 finished with value: 0.2683362638069641 and parameters: {'num_leaves': 134, 'learning_rate': 0.08271872447703202, 'feature_fraction': 0.7865336085893236, 'bagging_fraction': 0.8552412518360438, 'bagging_freq': 1, 'min_child_samples': 15, 'lambda_l1': 0.46471667247803206, 'lambda_l2': 2.632881847530304, 'max_depth': 12, 'max_bin': 836, 'min_data_in_leaf': 192, 'extra_trees': False, 'path_smooth': 0.7162545442754773}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:55:59,829] Trial 50 finished with value: 0.3169324287100407 and parameters: {'num_leaves': 124, 'learning_rate': 0.06168292174432866, 'feature_fraction': 0.7589848663931132, 'bagging_fraction': 0.8137944289055671, 'bagging_freq': 3, 'min_child_samples': 10, 'lambda_l1': 0.057869868715585, 'lambda_l2': 0.2534327198179244, 'max_depth': 8, 'max_bin': 1543, 'min_data_in_leaf': 149, 'extra_trees': True, 'path_smooth': 0.6600444693494125}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:06,195] Trial 51 finished with value: 0.25563053246071593 and parameters: {'num_leaves': 94, 'learning_rate': 0.11305954934486911, 'feature_fraction': 0.661855320098626, 'bagging_fraction': 0.9242321095642247, 'bagging_freq': 0, 'min_child_samples': 13, 'lambda_l1': 0.24196941644296274, 'lambda_l2': 1.1235187527641681, 'max_depth': 10, 'max_bin': 1622, 'min_data_in_leaf': 129, 'extra_trees': False, 'path_smooth': 0.8778925221167742}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:11,491] Trial 52 finished with value: 0.2544861929674222 and parameters: {'num_leaves': 106, 'learning_rate': 0.10114336321081738, 'feature_fraction': 0.6358631881892592, 'bagging_fraction': 0.7703155600264263, 'bagging_freq': 0, 'min_child_samples': 12, 'lambda_l1': 0.42101310733725883, 'lambda_l2': 0.8368506980023505, 'max_depth': 9, 'max_bin': 1923, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.7891816431627154}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:16,511] Trial 53 finished with value: 0.25909087410479475 and parameters: {'num_leaves': 105, 'learning_rate': 0.17008773713110686, 'feature_fraction': 0.63158532410319, 'bagging_fraction': 0.7151930592144897, 'bagging_freq': 0, 'min_child_samples': 18, 'lambda_l1': 0.43039672425950565, 'lambda_l2': 0.38105823279655093, 'max_depth': 9, 'max_bin': 1822, 'min_data_in_leaf': 135, 'extra_trees': False, 'path_smooth': 0.7695948863536142}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:21,135] Trial 54 finished with value: 0.26284502184584085 and parameters: {'num_leaves': 118, 'learning_rate': 0.100958262989583, 'feature_fraction': 0.6189469927511274, 'bagging_fraction': 0.7675513828020318, 'bagging_freq': 0, 'min_child_samples': 11, 'lambda_l1': 0.8104265184273131, 'lambda_l2': 0.7364268231967357, 'max_depth': 9, 'max_bin': 1914, 'min_data_in_leaf': 116, 'extra_trees': False, 'path_smooth': 0.7916615943739718}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:24,762] Trial 55 finished with value: 0.2512052124277408 and parameters: {'num_leaves': 111, 'learning_rate': 0.14397294219866497, 'feature_fraction': 0.7019988325217482, 'bagging_fraction': 0.8874902032100928, 'bagging_freq': 1, 'min_child_samples': 24, 'lambda_l1': 0.13561541001310365, 'lambda_l2': 1.8936420390849358, 'max_depth': 8, 'max_bin': 985, 'min_data_in_leaf': 157, 'extra_trees': False, 'path_smooth': 0.6000412865487152}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:27,499] Trial 56 finished with value: 0.26943719814439043 and parameters: {'num_leaves': 110, 'learning_rate': 0.18814113124519408, 'feature_fraction': 0.7026834528313356, 'bagging_fraction': 0.7382377926319164, 'bagging_freq': 1, 'min_child_samples': 24, 'lambda_l1': 0.13301267580234966, 'lambda_l2': 2.878924688817304, 'max_depth': 8, 'max_bin': 1029, 'min_data_in_leaf': 158, 'extra_trees': False, 'path_smooth': 0.5997189826448778}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:30,839] Trial 57 finished with value: 0.26267339896085296 and parameters: {'num_leaves': 84, 'learning_rate': 0.15086183807702638, 'feature_fraction': 0.6408353167940963, 'bagging_fraction': 0.782546889296637, 'bagging_freq': 1, 'min_child_samples': 27, 'lambda_l1': 2.082619088083636, 'lambda_l2': 1.378139447677939, 'max_depth': 9, 'max_bin': 963, 'min_data_in_leaf': 168, 'extra_trees': False, 'path_smooth': 0.6778377842021268}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:34,010] Trial 58 finished with value: 0.25370280342589824 and parameters: {'num_leaves': 77, 'learning_rate': 0.12575807012075624, 'feature_fraction': 0.7232871293034514, 'bagging_fraction': 0.9050182447376923, 'bagging_freq': 0, 'min_child_samples': 31, 'lambda_l1': 0.1022818949865267, 'lambda_l2': 2.0169167838438145, 'max_depth': 8, 'max_bin': 729, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.5895839310350911}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:37,472] Trial 59 finished with value: 0.2781405716361908 and parameters: {'num_leaves': 52, 'learning_rate': 0.1408338458231089, 'feature_fraction': 0.7217895868433313, 'bagging_fraction': 0.9082758697480241, 'bagging_freq': 2, 'min_child_samples': 31, 'lambda_l1': 0.10102295716530996, 'lambda_l2': 2.1497890088542406, 'max_depth': 8, 'max_bin': 624, 'min_data_in_leaf': 177, 'extra_trees': False, 'path_smooth': 0.49827615829634786}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:40,234] Trial 60 finished with value: 0.2810401449204976 and parameters: {'num_leaves': 58, 'learning_rate': 0.12364277661721898, 'feature_fraction': 0.7465738033916385, 'bagging_fraction': 0.8874142877051511, 'bagging_freq': 1, 'min_child_samples': 32, 'lambda_l1': 0.07879590497228797, 'lambda_l2': 3.382139802207928, 'max_depth': 7, 'max_bin': 735, 'min_data_in_leaf': 34, 'extra_trees': False, 'path_smooth': 0.5202826730478491}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:43,217] Trial 61 finished with value: 0.2658458814609361 and parameters: {'num_leaves': 76, 'learning_rate': 0.13104115203099048, 'feature_fraction': 0.6991485095073158, 'bagging_fraction': 0.9369467530683423, 'bagging_freq': 0, 'min_child_samples': 30, 'lambda_l1': 0.164795551821629, 'lambda_l2': 2.0097517056610457, 'max_depth': 9, 'max_bin': 531, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.730127684078381}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:46,581] Trial 62 finished with value: 0.2648156369802289 and parameters: {'num_leaves': 96, 'learning_rate': 0.15831094929174844, 'feature_fraction': 0.6755494222547529, 'bagging_fraction': 0.8701904462455606, 'bagging_freq': 0, 'min_child_samples': 29, 'lambda_l1': 0.3308202141547105, 'lambda_l2': 0.9989508945040891, 'max_depth': 8, 'max_bin': 875, 'min_data_in_leaf': 154, 'extra_trees': False, 'path_smooth': 0.6282878014760455}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:50,260] Trial 63 finished with value: 0.2577697581566199 and parameters: {'num_leaves': 86, 'learning_rate': 0.14399860699379372, 'feature_fraction': 0.7328226527398704, 'bagging_fraction': 0.9040841896169811, 'bagging_freq': 0, 'min_child_samples': 37, 'lambda_l1': 0.037857754078766626, 'lambda_l2': 0.8615843930044841, 'max_depth': 9, 'max_bin': 778, 'min_data_in_leaf': 138, 'extra_trees': False, 'path_smooth': 0.575833398687452}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:55,967] Trial 64 finished with value: 0.2641319572212709 and parameters: {'num_leaves': 107, 'learning_rate': 0.1711616128278426, 'feature_fraction': 0.6512227994954576, 'bagging_fraction': 0.8952489319983549, 'bagging_freq': 0, 'min_child_samples': 35, 'lambda_l1': 0.16761706582436672, 'lambda_l2': 1.7051506570294672, 'max_depth': 10, 'max_bin': 1995, 'min_data_in_leaf': 160, 'extra_trees': False, 'path_smooth': 0.37362843119327666}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:56:59,898] Trial 65 finished with value: 0.28252974242326173 and parameters: {'num_leaves': 37, 'learning_rate': 0.12843406612193478, 'feature_fraction': 0.7556215533672734, 'bagging_fraction': 0.7042388696613383, 'bagging_freq': 2, 'min_child_samples': 25, 'lambda_l1': 0.39767395171768866, 'lambda_l2': 0.6571702477454202, 'max_depth': 8, 'max_bin': 1092, 'min_data_in_leaf': 149, 'extra_trees': False, 'path_smooth': 0.7438447930659332}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:06,005] Trial 66 finished with value: 0.2581994404962678 and parameters: {'num_leaves': 152, 'learning_rate': 0.07654910516663395, 'feature_fraction': 0.681557707574746, 'bagging_fraction': 0.9154173857088114, 'bagging_freq': 0, 'min_child_samples': 33, 'lambda_l1': 0.2533993093406865, 'lambda_l2': 0.36289069775739075, 'max_depth': 11, 'max_bin': 1241, 'min_data_in_leaf': 142, 'extra_trees': False, 'path_smooth': 0.6768082233916217}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:09,185] Trial 67 finished with value: 0.28379872964474884 and parameters: {'num_leaves': 117, 'learning_rate': 0.08821955188077182, 'feature_fraction': 0.772624519814934, 'bagging_fraction': 0.8906312906819049, 'bagging_freq': 1, 'min_child_samples': 22, 'lambda_l1': 0.11888573101416836, 'lambda_l2': 0.0018848319385976178, 'max_depth': 7, 'max_bin': 1183, 'min_data_in_leaf': 171, 'extra_trees': False, 'path_smooth': 0.47712118795208014}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:12,223] Trial 68 finished with value: 0.27593148599367157 and parameters: {'num_leaves': 138, 'learning_rate': 0.09701217802460076, 'feature_fraction': 0.8025025081438542, 'bagging_fraction': 0.8535814682913745, 'bagging_freq': 0, 'min_child_samples': 15, 'lambda_l1': 0.06500083127427084, 'lambda_l2': 0.048398587589273484, 'max_depth': 8, 'max_bin': 878, 'min_data_in_leaf': 103, 'extra_trees': True, 'path_smooth': 0.6220983122090206}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:17,339] Trial 69 finished with value: 0.272316066828975 and parameters: {'num_leaves': 123, 'learning_rate': 0.11941360839407787, 'feature_fraction': 0.6655382159829635, 'bagging_fraction': 0.7703450372951484, 'bagging_freq': 1, 'min_child_samples': 27, 'lambda_l1': 0.040546354443710644, 'lambda_l2': 0.009439761366495443, 'max_depth': 9, 'max_bin': 983, 'min_data_in_leaf': 152, 'extra_trees': False, 'path_smooth': 0.8105215770260068}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:22,735] Trial 70 finished with value: 0.2632759845966358 and parameters: {'num_leaves': 130, 'learning_rate': 0.05585727393396604, 'feature_fraction': 0.7227788239378657, 'bagging_fraction': 0.9206186256171282, 'bagging_freq': 2, 'min_child_samples': 20, 'lambda_l1': 0.7912463138734704, 'lambda_l2': 3.558943681833771, 'max_depth': 7, 'max_bin': 651, 'min_data_in_leaf': 132, 'extra_trees': False, 'path_smooth': 0.5408151405982167}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:25,638] Trial 71 finished with value: 0.2639872367119869 and parameters: {'num_leaves': 141, 'learning_rate': 0.10802527668827487, 'feature_fraction': 0.7048822756663073, 'bagging_fraction': 0.8757585919866752, 'bagging_freq': 0, 'min_child_samples': 22, 'lambda_l1': 0.014140689913758645, 'lambda_l2': 0.02125453860271373, 'max_depth': 3, 'max_bin': 1153, 'min_data_in_leaf': 121, 'extra_trees': False, 'path_smooth': 0.8297298282729947}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:30,987] Trial 72 finished with value: 0.2467739062429807 and parameters: {'num_leaves': 103, 'learning_rate': 0.10296667179665812, 'feature_fraction': 0.6896054720367835, 'bagging_fraction': 0.8842722945693668, 'bagging_freq': 2, 'min_child_samples': 18, 'lambda_l1': 0.0015695675681778735, 'lambda_l2': 0.4544540611808995, 'max_depth': 6, 'max_bin': 1419, 'min_data_in_leaf': 137, 'extra_trees': False, 'path_smooth': 0.9583508614884847}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:39,378] Trial 73 finished with value: 0.25454506817115335 and parameters: {'num_leaves': 103, 'learning_rate': 0.0825411517441462, 'feature_fraction': 0.6885975584919337, 'bagging_fraction': 0.9101885779971979, 'bagging_freq': 2, 'min_child_samples': 18, 'lambda_l1': 0.001609362254216592, 'lambda_l2': 0.4630639033425061, 'max_depth': 10, 'max_bin': 1728, 'min_data_in_leaf': 146, 'extra_trees': False, 'path_smooth': 0.9770031682848794}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:43,550] Trial 74 finished with value: 0.26031591610857346 and parameters: {'num_leaves': 87, 'learning_rate': 0.08949872724614347, 'feature_fraction': 0.6954107176388293, 'bagging_fraction': 0.8866282715072443, 'bagging_freq': 2, 'min_child_samples': 16, 'lambda_l1': 0.001455096390726686, 'lambda_l2': 1.4135339138292662, 'max_depth': 6, 'max_bin': 1459, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.9173951028504024}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:48,779] Trial 75 finished with value: 0.26926185022699217 and parameters: {'num_leaves': 100, 'learning_rate': 0.09735471649994534, 'feature_fraction': 0.6500247674765856, 'bagging_fraction': 0.89986629229902, 'bagging_freq': 3, 'min_child_samples': 14, 'lambda_l1': 0.0011405557290161703, 'lambda_l2': 0.5901346316156649, 'max_depth': 8, 'max_bin': 1279, 'min_data_in_leaf': 158, 'extra_trees': False, 'path_smooth': 0.9559446600273342}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:52,406] Trial 76 finished with value: 0.2680735064090954 and parameters: {'num_leaves': 114, 'learning_rate': 0.07099399647294183, 'feature_fraction': 0.6833143085211117, 'bagging_fraction': 0.7386004743993821, 'bagging_freq': 2, 'min_child_samples': 29, 'lambda_l1': 0.0043023166829608325, 'lambda_l2': 0.17763391858361313, 'max_depth': 6, 'max_bin': 1036, 'min_data_in_leaf': 167, 'extra_trees': False, 'path_smooth': 0.9963398580985094}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:56,170] Trial 77 finished with value: 0.2860375145525665 and parameters: {'num_leaves': 65, 'learning_rate': 0.1613790405586085, 'feature_fraction': 0.7136321486252821, 'bagging_fraction': 0.8628536476705699, 'bagging_freq': 3, 'min_child_samples': 24, 'lambda_l1': 0.0032423662630071625, 'lambda_l2': 0.8658143941679186, 'max_depth': 7, 'max_bin': 1878, 'min_data_in_leaf': 61, 'extra_trees': False, 'path_smooth': 0.8967010470370379}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:57:59,182] Trial 78 finished with value: 0.26447222797623765 and parameters: {'num_leaves': 78, 'learning_rate': 0.12438309081505669, 'feature_fraction': 0.6704480237152899, 'bagging_fraction': 0.9358366986888565, 'bagging_freq': 2, 'min_child_samples': 12, 'lambda_l1': 0.28940781009425376, 'lambda_l2': 0.43897902190384347, 'max_depth': 4, 'max_bin': 1352, 'min_data_in_leaf': 130, 'extra_trees': False, 'path_smooth': 0.171373091277765}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:58:02,522] Trial 79 finished with value: 0.27962972860183843 and parameters: {'num_leaves': 90, 'learning_rate': 0.06619199067841176, 'feature_fraction': 0.740023055556283, 'bagging_fraction': 0.9012205204297492, 'bagging_freq': 1, 'min_child_samples': 17, 'lambda_l1': 0.19896132280426593, 'lambda_l2': 1.7848284205047638, 'max_depth': 9, 'max_bin': 1429, 'min_data_in_leaf': 121, 'extra_trees': True, 'path_smooth': 0.7867456012096589}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:58:06,042] Trial 80 finished with value: 0.2731565699300039 and parameters: {'num_leaves': 108, 'learning_rate': 0.18880041676686563, 'feature_fraction': 0.6325691154998059, 'bagging_fraction': 0.8165408890430029, 'bagging_freq': 0, 'min_child_samples': 32, 'lambda_l1': 0.0017771007437495053, 'lambda_l2': 0.2695642471398355, 'max_depth': 10, 'max_bin': 1089, 'min_data_in_leaf': 182, 'extra_trees': False, 'path_smooth': 0.7497545991946537}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:58:13,361] Trial 81 finished with value: 0.251058683253318 and parameters: {'num_leaves': 100, 'learning_rate': 0.08419625745737175, 'feature_fraction': 0.6858456771300624, 'bagging_fraction': 0.909756853924761, 'bagging_freq': 2, 'min_child_samples': 18, 'lambda_l1': 0.0019625926868268714, 'lambda_l2': 0.3331771709966597, 'max_depth': 10, 'max_bin': 1760, 'min_data_in_leaf': 146, 'extra_trees': False, 'path_smooth': 0.9548258711813515}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:58:22,296] Trial 82 finished with value: 0.24592047983446855 and parameters: {'num_leaves': 100, 'learning_rate': 0.07970881464588538, 'feature_fraction': 0.6774852123578339, 'bagging_fraction': 0.9137935810992549, 'bagging_freq': 2, 'min_child_samples': 19, 'lambda_l1': 0.0020244154086408463, 'lambda_l2': 0.337730031909318, 'max_depth': 11, 'max_bin': 1856, 'min_data_in_leaf': 163, 'extra_trees': False, 'path_smooth': 0.8477370375840215}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:58:29,248] Trial 83 finished with value: 0.2566249054587219 and parameters: {'num_leaves': 99, 'learning_rate': 0.08092409897912983, 'feature_fraction': 0.7099161808079715, 'bagging_fraction': 0.9149439534641971, 'bagging_freq': 2, 'min_child_samples': 21, 'lambda_l1': 0.0019359641088015113, 'lambda_l2': 0.12031768093697436, 'max_depth': 11, 'max_bin': 1579, 'min_data_in_leaf': 163, 'extra_trees': False, 'path_smooth': 0.9557212863832805}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:58:38,860] Trial 84 finished with value: 0.24630851713440724 and parameters: {'num_leaves': 114, 'learning_rate': 0.049533615109092814, 'feature_fraction': 0.6767460189809067, 'bagging_fraction': 0.9087183439768969, 'bagging_freq': 2, 'min_child_samples': 19, 'lambda_l1': 0.0010160016954854404, 'lambda_l2': 0.30869476115310357, 'max_depth': 12, 'max_bin': 1729, 'min_data_in_leaf': 154, 'extra_trees': False, 'path_smooth': 0.8485470569415736}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:58:48,679] Trial 85 finished with value: 0.2676655560182082 and parameters: {'num_leaves': 120, 'learning_rate': 0.04126603531762704, 'feature_fraction': 0.6801042207857659, 'bagging_fraction': 0.8809366669032924, 'bagging_freq': 2, 'min_child_samples': 19, 'lambda_l1': 0.0011513154949923748, 'lambda_l2': 0.29712869752929144, 'max_depth': 12, 'max_bin': 1764, 'min_data_in_leaf': 176, 'extra_trees': False, 'path_smooth': 0.8734906240337615}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:58:58,643] Trial 86 finished with value: 0.2542249338288265 and parameters: {'num_leaves': 113, 'learning_rate': 0.05156878891895013, 'feature_fraction': 0.6926393938685992, 'bagging_fraction': 0.9074375981449871, 'bagging_freq': 2, 'min_child_samples': 19, 'lambda_l1': 0.0024975744473104823, 'lambda_l2': 0.19545440942203593, 'max_depth': 12, 'max_bin': 1668, 'min_data_in_leaf': 155, 'extra_trees': False, 'path_smooth': 0.9051018332766733}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:59:13,963] Trial 87 finished with value: 0.24874724445259833 and parameters: {'num_leaves': 128, 'learning_rate': 0.026335388203198723, 'feature_fraction': 0.7261840599310467, 'bagging_fraction': 0.8905430537339372, 'bagging_freq': 2, 'min_child_samples': 17, 'lambda_l1': 0.0034402550935651276, 'lambda_l2': 0.3475594737465838, 'max_depth': 11, 'max_bin': 1859, 'min_data_in_leaf': 147, 'extra_trees': False, 'path_smooth': 0.8512114855964843}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:59:29,793] Trial 88 finished with value: 0.265731565218693 and parameters: {'num_leaves': 128, 'learning_rate': 0.015920092941027128, 'feature_fraction': 0.6747876780128442, 'bagging_fraction': 0.8673174307597992, 'bagging_freq': 2, 'min_child_samples': 16, 'lambda_l1': 0.0037596033423242495, 'lambda_l2': 0.37183287732075565, 'max_depth': 11, 'max_bin': 1856, 'min_data_in_leaf': 165, 'extra_trees': False, 'path_smooth': 0.8543808118002969}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 01:59:40,213] Trial 89 finished with value: 0.26232748364678393 and parameters: {'num_leaves': 134, 'learning_rate': 0.028344837883341762, 'feature_fraction': 0.7153489886284368, 'bagging_fraction': 0.9317226038339316, 'bagging_freq': 3, 'min_child_samples': 17, 'lambda_l1': 0.006083070180983397, 'lambda_l2': 0.2375959189644729, 'max_depth': 11, 'max_bin': 1839, 'min_data_in_leaf': 158, 'extra_trees': False, 'path_smooth': 0.9420164621986232}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:00:04,606] Trial 90 finished with value: 0.2796970134146198 and parameters: {'num_leaves': 122, 'learning_rate': 0.006573525643498043, 'feature_fraction': 0.7060316498307797, 'bagging_fraction': 0.8882277066496971, 'bagging_freq': 2, 'min_child_samples': 19, 'lambda_l1': 0.002165412146722747, 'lambda_l2': 0.08641813558743866, 'max_depth': 12, 'max_bin': 1953, 'min_data_in_leaf': 173, 'extra_trees': False, 'path_smooth': 0.9178324337530555}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:00:14,059] Trial 91 finished with value: 0.2540028443311985 and parameters: {'num_leaves': 115, 'learning_rate': 0.044620807039262515, 'feature_fraction': 0.7254019841408224, 'bagging_fraction': 0.8964571404855319, 'bagging_freq': 2, 'min_child_samples': 20, 'lambda_l1': 0.003311768017959158, 'lambda_l2': 0.3170759633405919, 'max_depth': 11, 'max_bin': 1711, 'min_data_in_leaf': 147, 'extra_trees': False, 'path_smooth': 0.8350669689931404}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:00:31,817] Trial 92 finished with value: 0.25359961552887456 and parameters: {'num_leaves': 102, 'learning_rate': 0.020945682083748026, 'feature_fraction': 0.7299854718634826, 'bagging_fraction': 0.9117638899814104, 'bagging_freq': 3, 'min_child_samples': 15, 'lambda_l1': 0.0013981550831389667, 'lambda_l2': 0.03300814032325269, 'max_depth': 12, 'max_bin': 1781, 'min_data_in_leaf': 151, 'extra_trees': False, 'path_smooth': 0.8758678343916596}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:00:41,922] Trial 93 finished with value: 0.25010212438073837 and parameters: {'num_leaves': 103, 'learning_rate': 0.038680001790581536, 'feature_fraction': 0.7381923034208651, 'bagging_fraction': 0.912926850541665, 'bagging_freq': 3, 'min_child_samples': 15, 'lambda_l1': 0.0012842934811597671, 'lambda_l2': 0.03656427746784137, 'max_depth': 12, 'max_bin': 1771, 'min_data_in_leaf': 150, 'extra_trees': False, 'path_smooth': 0.8833750746245063}. Best is trial 38 with value: 0.2403512572887128.
# ...
# [I 2025-07-12 02:05:35,642] Trial 120 finished with value: 0.25646656564407677 and parameters: {'num_leaves': 88, 'learning_rate': 0.05712800830195828, 'feature_fraction': 0.8183261738544136, 'bagging_fraction': 0.9322988966718202, 'bagging_freq': 2, 'min_child_samples': 19, 'lambda_l1': 0.0016393442891773013, 'lambda_l2': 0.23332058726626362, 'max_depth': 12, 'max_bin': 1990, 'min_data_in_leaf': 110, 'extra_trees': False, 'path_smooth': 0.9455405612327897}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:05:43,420] Trial 121 finished with value: 0.24751672177696607 and parameters: {'num_leaves': 93, 'learning_rate': 0.07447880865014105, 'feature_fraction': 0.8475108666149503, 'bagging_fraction': 0.8950680986644095, 'bagging_freq': 3, 'min_child_samples': 20, 'lambda_l1': 0.0024533359162339854, 'lambda_l2': 0.18392267162840362, 'max_depth': 11, 'max_bin': 1709, 'min_data_in_leaf': 139, 'extra_trees': False, 'path_smooth': 0.9997606583186551}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:05:51,883] Trial 122 finished with value: 0.25029805478638056 and parameters: {'num_leaves': 95, 'learning_rate': 0.06124573910950699, 'feature_fraction': 0.8475295718126591, 'bagging_fraction': 0.9196537111345069, 'bagging_freq': 3, 'min_child_samples': 21, 'lambda_l1': 0.0036066399720503725, 'lambda_l2': 0.1552003211330907, 'max_depth': 11, 'max_bin': 1731, 'min_data_in_leaf': 131, 'extra_trees': False, 'path_smooth': 0.9980484044128923}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:06:00,763] Trial 123 finished with value: 0.24827536417113943 and parameters: {'num_leaves': 108, 'learning_rate': 0.07518084719059083, 'feature_fraction': 0.8695426754837156, 'bagging_fraction': 0.9234797397147605, 'bagging_freq': 3, 'min_child_samples': 19, 'lambda_l1': 0.0028307733360461314, 'lambda_l2': 0.12395124263965487, 'max_depth': 11, 'max_bin': 1930, 'min_data_in_leaf': 146, 'extra_trees': False, 'path_smooth': 0.9744855184242552}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:06:08,463] Trial 124 finished with value: 0.2424357907842497 and parameters: {'num_leaves': 108, 'learning_rate': 0.07427939301717931, 'feature_fraction': 0.836632331305998, 'bagging_fraction': 0.8920523626209466, 'bagging_freq': 3, 'min_child_samples': 19, 'lambda_l1': 0.0047209974131718745, 'lambda_l2': 0.11266609005547074, 'max_depth': 11, 'max_bin': 1911, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.9719198745731014}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:06:16,720] Trial 125 finished with value: 0.2568955024412955 and parameters: {'num_leaves': 109, 'learning_rate': 0.07393660327040666, 'feature_fraction': 0.8360332917586497, 'bagging_fraction': 0.8839829542313676, 'bagging_freq': 3, 'min_child_samples': 21, 'lambda_l1': 0.004354835014010141, 'lambda_l2': 0.12695015143967187, 'max_depth': 11, 'max_bin': 1936, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.981292827126421}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:06:25,582] Trial 126 finished with value: 0.25090400086931963 and parameters: {'num_leaves': 100, 'learning_rate': 0.07935491638873705, 'feature_fraction': 0.8654948708160515, 'bagging_fraction': 0.9056157164598323, 'bagging_freq': 3, 'min_child_samples': 19, 'lambda_l1': 0.006659382202178975, 'lambda_l2': 0.07953910511065858, 'max_depth': 11, 'max_bin': 1898, 'min_data_in_leaf': 154, 'extra_trees': False, 'path_smooth': 0.9260888954565251}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:06:32,647] Trial 127 finished with value: 0.2579450513034659 and parameters: {'num_leaves': 106, 'learning_rate': 0.0774262593846, 'feature_fraction': 0.8257039914454001, 'bagging_fraction': 0.9234407812123046, 'bagging_freq': 3, 'min_child_samples': 18, 'lambda_l1': 0.005068724942635914, 'lambda_l2': 0.10628948069584464, 'max_depth': 10, 'max_bin': 1817, 'min_data_in_leaf': 160, 'extra_trees': False, 'path_smooth': 0.9648115126284761}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:06:41,156] Trial 128 finished with value: 0.250437171361095 and parameters: {'num_leaves': 115, 'learning_rate': 0.08507281916104815, 'feature_fraction': 0.8439132699748177, 'bagging_fraction': 0.8991931371728358, 'bagging_freq': 3, 'min_child_samples': 21, 'lambda_l1': 0.0027892650496938332, 'lambda_l2': 0.13554347967692398, 'max_depth': 11, 'max_bin': 1955, 'min_data_in_leaf': 134, 'extra_trees': False, 'path_smooth': 0.998799870032263}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:06:50,006] Trial 129 finished with value: 0.24144775471615162 and parameters: {'num_leaves': 110, 'learning_rate': 0.06898354520472498, 'feature_fraction': 0.8514872328091336, 'bagging_fraction': 0.9088030820145165, 'bagging_freq': 4, 'min_child_samples': 20, 'lambda_l1': 0.0018944854708796924, 'lambda_l2': 0.005334368160846251, 'max_depth': 11, 'max_bin': 1789, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.9102747864988158}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:06:56,643] Trial 130 finished with value: 0.2630303607548438 and parameters: {'num_leaves': 119, 'learning_rate': 0.0691875328563215, 'feature_fraction': 0.850484335964275, 'bagging_fraction': 0.9102659587759716, 'bagging_freq': 4, 'min_child_samples': 20, 'lambda_l1': 0.0019255564385471718, 'lambda_l2': 0.003807508263512002, 'max_depth': 12, 'max_bin': 1610, 'min_data_in_leaf': 143, 'extra_trees': False, 'path_smooth': 0.9072798961978691}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:07:04,622] Trial 131 finished with value: 0.2509943385494414 and parameters: {'num_leaves': 113, 'learning_rate': 0.07362084128073729, 'feature_fraction': 0.8601226713204377, 'bagging_fraction': 0.9162202984781991, 'bagging_freq': 4, 'min_child_samples': 19, 'lambda_l1': 0.002323015454371914, 'lambda_l2': 0.002306465187252248, 'max_depth': 11, 'max_bin': 1840, 'min_data_in_leaf': 148, 'extra_trees': False, 'path_smooth': 0.9749745082034751}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:07:11,363] Trial 132 finished with value: 0.272308697606667 and parameters: {'num_leaves': 109, 'learning_rate': 0.0643675940535817, 'feature_fraction': 0.8729030711433603, 'bagging_fraction': 0.9035292930276501, 'bagging_freq': 4, 'min_child_samples': 20, 'lambda_l1': 0.0015906742622944037, 'lambda_l2': 0.007633587164391015, 'max_depth': 11, 'max_bin': 1780, 'min_data_in_leaf': 152, 'extra_trees': False, 'path_smooth': 0.9259488099534894}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:07:21,544] Trial 133 finished with value: 0.24928888545306152 and parameters: {'num_leaves': 101, 'learning_rate': 0.055098105242554006, 'feature_fraction': 0.8296596446681539, 'bagging_fraction': 0.8931895981956268, 'bagging_freq': 3, 'min_child_samples': 18, 'lambda_l1': 0.0030391153028078866, 'lambda_l2': 0.18092812596285351, 'max_depth': 11, 'max_bin': 1900, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.9516206676497245}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:07:28,891] Trial 134 finished with value: 0.27109539901183693 and parameters: {'num_leaves': 105, 'learning_rate': 0.09157259985889549, 'feature_fraction': 0.8379356350734025, 'bagging_fraction': 0.908233207017663, 'bagging_freq': 4, 'min_child_samples': 22, 'lambda_l1': 0.001927673790907711, 'lambda_l2': 0.005795684921143858, 'max_depth': 10, 'max_bin': 1757, 'min_data_in_leaf': 138, 'extra_trees': False, 'path_smooth': 0.9741649454144388}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:07:37,186] Trial 135 finished with value: 0.25842631779597397 and parameters: {'num_leaves': 93, 'learning_rate': 0.068434955776241, 'feature_fraction': 0.8871017153116676, 'bagging_fraction': 0.8990101425618757, 'bagging_freq': 3, 'min_child_samples': 16, 'lambda_l1': 0.0010007861445554542, 'lambda_l2': 0.14696523535505535, 'max_depth': 12, 'max_bin': 1998, 'min_data_in_leaf': 156, 'extra_trees': False, 'path_smooth': 0.943539720099446}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:07:44,471] Trial 136 finished with value: 0.2692495446569719 and parameters: {'num_leaves': 98, 'learning_rate': 0.05166956674420456, 'feature_fraction': 0.8145064036346205, 'bagging_fraction': 0.9249635854352821, 'bagging_freq': 3, 'min_child_samples': 17, 'lambda_l1': 0.0025618010105227136, 'lambda_l2': 0.27186517210079825, 'max_depth': 11, 'max_bin': 1653, 'min_data_in_leaf': 148, 'extra_trees': False, 'path_smooth': 0.9110883008226235}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:07:51,387] Trial 137 finished with value: 0.2631290213471138 and parameters: {'num_leaves': 111, 'learning_rate': 0.07890175952489567, 'feature_fraction': 0.8663571777698426, 'bagging_fraction': 0.9191766827389265, 'bagging_freq': 3, 'min_child_samples': 19, 'lambda_l1': 0.0039440495186608224, 'lambda_l2': 0.09265102264676181, 'max_depth': 12, 'max_bin': 1741, 'min_data_in_leaf': 128, 'extra_trees': False, 'path_smooth': 0.9666587238360361}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:08:00,895] Trial 138 finished with value: 0.2516458661478441 and parameters: {'num_leaves': 106, 'learning_rate': 0.07268090532864895, 'feature_fraction': 0.8548198908099327, 'bagging_fraction': 0.9128987170603846, 'bagging_freq': 3, 'min_child_samples': 44, 'lambda_l1': 0.0014893421471045608, 'lambda_l2': 0.11490503728717036, 'max_depth': 11, 'max_bin': 1870, 'min_data_in_leaf': 152, 'extra_trees': False, 'path_smooth': 0.9282990933738489}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:08:06,022] Trial 139 finished with value: 0.2917105593293428 and parameters: {'num_leaves': 117, 'learning_rate': 0.05993157998838157, 'feature_fraction': 0.8047606141627165, 'bagging_fraction': 0.8837687273018893, 'bagging_freq': 5, 'min_child_samples': 21, 'lambda_l1': 0.0022134075352404346, 'lambda_l2': 0.0012481930006382654, 'max_depth': 12, 'max_bin': 1791, 'min_data_in_leaf': 140, 'extra_trees': True, 'path_smooth': 0.9986151895080349}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:08:11,603] Trial 140 finished with value: 0.2621186077297652 and parameters: {'num_leaves': 102, 'learning_rate': 0.08656075182412046, 'feature_fraction': 0.8308456916214704, 'bagging_fraction': 0.8353798559989649, 'bagging_freq': 3, 'min_child_samples': 18, 'lambda_l1': 0.0017815470500437247, 'lambda_l2': 0.0712394290950183, 'max_depth': 10, 'max_bin': 1939, 'min_data_in_leaf': 160, 'extra_trees': False, 'path_smooth': 0.8993057942779733}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:08:19,934] Trial 141 finished with value: 0.2528960906523045 and parameters: {'num_leaves': 124, 'learning_rate': 0.06499754034617924, 'feature_fraction': 0.8403330750802872, 'bagging_fraction': 0.8922256320725825, 'bagging_freq': 2, 'min_child_samples': 17, 'lambda_l1': 0.0031585215297049497, 'lambda_l2': 0.3320397362268687, 'max_depth': 11, 'max_bin': 1861, 'min_data_in_leaf': 148, 'extra_trees': False, 'path_smooth': 0.8678865781728112}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:08:30,668] Trial 142 finished with value: 0.24853106571144798 and parameters: {'num_leaves': 95, 'learning_rate': 0.04309750797211197, 'feature_fraction': 0.8496249075027059, 'bagging_fraction': 0.8910903624233157, 'bagging_freq': 2, 'min_child_samples': 17, 'lambda_l1': 0.004818374100110037, 'lambda_l2': 0.6157327463645815, 'max_depth': 11, 'max_bin': 1825, 'min_data_in_leaf': 145, 'extra_trees': False, 'path_smooth': 0.8414056288461058}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:08:40,739] Trial 143 finished with value: 0.2504971099179507 and parameters: {'num_leaves': 96, 'learning_rate': 0.04743941831371948, 'feature_fraction': 0.8468680303936424, 'bagging_fraction': 0.8755302420395586, 'bagging_freq': 2, 'min_child_samples': 19, 'lambda_l1': 0.00547905619817682, 'lambda_l2': 0.5920902063553967, 'max_depth': 11, 'max_bin': 1821, 'min_data_in_leaf': 133, 'extra_trees': False, 'path_smooth': 0.955820329107135}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:08:47,311] Trial 144 finished with value: 0.258526563071208 and parameters: {'num_leaves': 91, 'learning_rate': 0.09508880938801012, 'feature_fraction': 0.7967812588031961, 'bagging_fraction': 0.9020768168942174, 'bagging_freq': 2, 'min_child_samples': 22, 'lambda_l1': 0.008310935273233707, 'lambda_l2': 0.15613037054307935, 'max_depth': 11, 'max_bin': 1924, 'min_data_in_leaf': 89, 'extra_trees': False, 'path_smooth': 0.9773228190702463}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:08:55,382] Trial 145 finished with value: 0.2543096864166821 and parameters: {'num_leaves': 110, 'learning_rate': 0.08038162211846904, 'feature_fraction': 0.7785539728946822, 'bagging_fraction': 0.9068211232937964, 'bagging_freq': 2, 'min_child_samples': 18, 'lambda_l1': 0.004721137943337089, 'lambda_l2': 0.22112848680059663, 'max_depth': 12, 'max_bin': 1795, 'min_data_in_leaf': 144, 'extra_trees': False, 'path_smooth': 0.9339919837472538}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:09:02,784] Trial 146 finished with value: 0.25392959788209024 and parameters: {'num_leaves': 83, 'learning_rate': 0.07666317777548312, 'feature_fraction': 0.8579915922972353, 'bagging_fraction': 0.8967296824164767, 'bagging_freq': 2, 'min_child_samples': 20, 'lambda_l1': 0.02466569513992874, 'lambda_l2': 0.6841184243308822, 'max_depth': 11, 'max_bin': 1876, 'min_data_in_leaf': 165, 'extra_trees': False, 'path_smooth': 0.8248679190470761}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:09:14,418] Trial 147 finished with value: 0.24964814233235283 and parameters: {'num_leaves': 101, 'learning_rate': 0.04435835488771688, 'feature_fraction': 0.8693457564112607, 'bagging_fraction': 0.8887356190174797, 'bagging_freq': 3, 'min_child_samples': 17, 'lambda_l1': 0.002617155995137135, 'lambda_l2': 0.4549184066366444, 'max_depth': 12, 'max_bin': 1688, 'min_data_in_leaf': 141, 'extra_trees': False, 'path_smooth': 0.881108689691221}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:09:22,873] Trial 148 finished with value: 0.26117540023574837 and parameters: {'num_leaves': 98, 'learning_rate': 0.05437094766112549, 'feature_fraction': 0.852804857354978, 'bagging_fraction': 0.9157144420592552, 'bagging_freq': 2, 'min_child_samples': 24, 'lambda_l1': 0.0022094583944730593, 'lambda_l2': 0.0027031583228421022, 'max_depth': 10, 'max_bin': 1735, 'min_data_in_leaf': 137, 'extra_trees': False, 'path_smooth': 0.910738968275669}. Best is trial 38 with value: 0.2403512572887128.
# [I 2025-07-12 02:09:29,997] Trial 149 finished with value: 0.2516378185946294 and parameters: {'num_leaves': 107, 'learning_rate': 0.05956822509953249, 'feature_fraction': 0.8200073219399578, 'bagging_fraction': 0.8807575883858343, 'bagging_freq': 2, 'min_child_samples': 20, 'lambda_l1': 0.0034022844390663985, 'lambda_l2': 0.10127522053549058, 'max_depth': 11, 'max_bin': 1582, 'min_data_in_leaf': 156, 'extra_trees': False, 'path_smooth': 0.9557961359557864}. Best is trial 38 with value: 0.2403512572887128.
# Mejores hiperparámetros encontrados:
# {'num_leaves': 103, 'learning_rate': 0.0853432148260185, 'feature_fraction': 0.6416786509776304, 'bagging_fraction': 0.8738054832631006, 'bagging_freq': 3, 'min_child_samples': 19, 'lambda_l1': 0.2408488277548435, 'lambda_l2': 0.016328068146628127, 'max_depth': 10, 'max_bin': 958, 'min_data_in_leaf': 143, 'extra_trees': False, 'path_smooth': 0.9448376071461212}
# Mejor MAE: 0.2404

# %%
best_params = study.best_params.copy()
best_params.update({
    "objective": "regression",
    "metric": ["rmse", "mape"],
    "verbosity": -1,
    "n_jobs": -1,
    "seed": 42
})

model = lgb.train(
    best_params,
    lgb.Dataset(X_train, label=y_train),
    valid_sets=[lgb.Dataset(X_val, label=y_val)],
    num_boost_round=1000,
    callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
)

# Asegurar las mismas columnas
X_kgl = df_kgl[X_train.columns]  # Misma estructura

# === 9. Hacer predicción sobre nuevos datos ===
preds_kgl = model.predict(X_kgl)

# %%
result = pd.DataFrame({"product_id": X_kgl["product_id"],  "tn": preds_kgl})

result = result[result["product_id"].isin(productos_ok["product_id"])]

result
# Out:
#        product_id           tn
# 35          20001  1298.819178
# 71          20002  1108.197256
# 107         20003   886.444030
# 143         20004   661.420856
# 179         20005   639.854462
# ...           ...          ...
# 22358       20962     2.343861
# 22362       20975     2.247746
# 22366       20995     2.224461
# 22370       21087     1.484249
# 22374       21214     0.853308
#
# [780 rows x 2 columns]

# %%
result.to_csv(f"{study_name}.csv",sep=',', index=False)

# %%
import matplotlib.pyplot as plt
from lightgbm import plot_importance  # Importación específica
# Visualizar importancia de características
plot_importance(model, importance_type='gain', max_num_features=10)  # Usar la función importada
plt.show()
